# %% [markdown]
# # ASR Assignment 2022-23
#
# This notebook has been provided as a template to get you started on the assignment.  Feel free to use it for your development, or do your development directly in Python.
#
# You can find a full description of the assignment [here](http://www.inf.ed.ac.uk/teaching/courses/asr/2022-23/coursework.pdf).
#
# You are provided with two Python modules `observation_model.py` and `wer.py`.  The first was described in [Lab 3](https://github.com/ZhaoZeyu1995/asr_labs/blob/master/asr_lab3_4.ipynb).  The second can be used to compute the number of substitution, deletion and insertion errors between ASR output and a reference text.
#
# It can be used as follows:
#
# ```python
# import wer
#
# my_refence = 'A B C'
# my_output = 'A C C D'
#
# wer.compute_alignment_errors(my_reference, my_output)
# ```
#
# This produces a tuple $(s,d,i)$ giving counts of substitution,
# deletion and insertion errors respectively - in this example (1, 0, 1).  The function accepts either two strings, as in the example above, or two lists.  Matching is case sensitive.
#
# ## Template code
#
# Assuming that you have already made a function to generate an WFST, `create_wfst()` and a decoder class, `MyViterbiDecoder`, you can perform recognition on all the audio files as follows:

# %%
import glob
import os
import wer
import observation_model
import openfst_python as fst

# ... (add your code to create WFSTs and Viterbi Decoder)
import observation_model
import math
import openfst_python as fst
import time

class MyViterbiDecoder:
    
    NLL_ZERO = 1e10  # define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    
    def __init__(self, f, audio_file_name):
        """Set up the decoder class with an audio file and WFST f
        """
        self.om = observation_model.ObservationModel()
        self.f = f
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
        
        forward_computations = 0
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                for arc in self.f.arcs(i):
                    
                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        forward_computations += 1
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            self.V[t][j] = prob
                            self.B[t][j] = i
                            
                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
        return forward_computations
                            
    
    def finalise_decoding(self):
        """ this incorporates the probability of terminating at each state
        """
        
        for state in self.f.states():
            final_weight = float(self.f.final(state))
            if self.V[-1][state] != self.NLL_ZERO:
                if final_weight == math.inf:
                    self.V[-1][state] = self.NLL_ZERO  # effectively says that we can't end in this state
                else:
                    self.V[-1][state] += final_weight
                    
        # get a list of all states where there was a path ending with non-zero probability
        finished = [x for x in self.V[-1] if x < self.NLL_ZERO]
        if not finished:  # if empty
            print("No path got to the end of the observations.")
        
        
    def decode(self):
        forward_computations = 0
        initial = time.time()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            forward_computations += self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            t += 1
        self.finalise_decoding()
        final=time.time()
        return (forward_computations, (final - initial))
    
    def backtrace(self):
        
        initial = time.time()
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        
        
        final = time.time()
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence =' '.join([ self.f.output_symbols().find(label) for label in best_out_sequence])
        return (best_state_sequence, best_out_sequence,(final-initial))
import openfst_python as fst

def parse_lexicon(lex_file):
    """
    Parse the lexicon file and return it in dictionary form.
    
    Args:
        lex_file (str): filename of lexicon file with structure '<word> <phone1> <phone2>...'
                        eg. peppers p eh p er z

    Returns:
        lex (dict): dictionary mapping words to list of phones
    """
    
    lex = {}  # create a dictionary for the lexicon entries (this could be a problem with larger lexica)
    with open(lex_file, 'r') as f:
        for line in f:
            line = line.split()  # split at each space
            lex[line[0]] = line[1:]  # first field the word, the rest is the phones
    return lex

def generate_symbol_tables(lexicon, n=3):
    '''
    Return word, phone and state symbol tables based on the supplied lexicon
        
    Args:
        lexicon (dict): lexicon to use, created from the parse_lexicon() function
        n (int): number of states for each phone HMM
        
    Returns:
        word_table (fst.SymbolTable): table of words
        phone_table (fst.SymbolTable): table of phones
        state_table (fst.SymbolTable): table of HMM phone-state IDs
    '''
    
    state_table = fst.SymbolTable()
    phone_table = fst.SymbolTable()
    word_table = fst.SymbolTable()
    
    # add empty <eps> symbol to all tables
    state_table.add_symbol('<eps>')
    phone_table.add_symbol('<eps>')
    word_table.add_symbol('<eps>')
    
    for word, phones  in lexicon.items():
        
        word_table.add_symbol(word)
        
        for p in phones: # for each phone
            
            phone_table.add_symbol(p)
            for i in range(1,n+1): # for each state 1 to n
                state_table.add_symbol('{}_{}'.format(p, i))
            
    return word_table, phone_table, state_table


# call these two functions
lex = parse_lexicon('lexicon.txt')
word_table, phone_table, state_table = generate_symbol_tables(lex)
def generate_phone_wfst(f, start_state, phone, n, next_state_prob):
    """
    Generate a WFST representing an n-state left-to-right phone HMM.
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assumed to exist already
        phone (str): the phone label 
        n (int): number of states of the HMM excluding start and end
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
    
        in_label = state_table.find('{}_{}'.format(phone, i))
        sl_weight = fst.Weight('log', -math.log(1-next_state_prob))
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, sl_weight, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        
        out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        next_weight = fst.Weight('log', -math.log(next_state_prob))
        f.add_arc(current_state, fst.Arc(in_label, out_label, next_weight, next_state))    
       
        current_state = next_state
    return current_state



def create_wfst(n, probabilities=None, next_state_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs.
        This will currently output phone labels.  
    
    Args:
        
        start_state (int): the index of the first state, assumed to exist already
        word (str): the word to generate
        n (int): states per phone HMM
        
    Returns:
        the constructed WFST
    
    """
    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
        # note: new current_state is now set to the final state of the previous phone WFST
        
        next_weight = fst.Weight('log', -math.log(1))
        out_label = word_table.find(word)
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))
    f.set_input_symbols(state_table)
    f.set_output_symbols(word_table)

    return f




    


def read_transcription(wav_file):
    """
    Get the transcription corresponding to wav_file.
    """
    
    transcription_file = os.path.splitext(wav_file)[0] + '.txt'
    
    with open(transcription_file, 'r') as f:
        transcription = f.readline().strip()
    
    return transcription


f = create_wfst(3)

print([x for x in lex.values()])

def num_states(f):
    counter = 0
    for x in f.states():
        counter += 1
    return counter

def total_num_arcs(f):
    return sum(f.num_arcs(s) for s in f.states())

def draw_fst(f):
    from subprocess import check_call
    from IPython.display import Image
    f.draw('tmp.dot', portrait=True)
    check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
    return Image(filename='tmp.png')




draw_fst(f)
# Out:
# [['ey'], ['ah', 'v'], ['p', 'eh', 'k'], ['p', 'eh', 'p', 'er', 'z'], ['p', 'iy', 't', 'er'], ['p', 'ih', 'k', 't'], ['p', 'ih', 'k', 'ah', 'l', 'd'], ['p', 'ay', 'p', 'er'], ['dh', 'iy'], ['w', 'eh', 'r', 'z']]

# %%
#TASK 1

# !pip install pandas
import pandas as pd
results_df=[]
import wer

print(num_states(f))
print(total_num_arcs(f))
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    break
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('resulto.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
from collections import defaultdict
word_count=defaultdict(int)

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    transcription = read_transcription(wav_file)
    for word in transcription.split(" "):
        word_count[word]+=1
total_words = sum(word_count.values())
probabilities ={word:count/total_words for word,count in word_count.items()}
print(word_count,probabilities)
# Out:
# defaultdict(<class 'int'>, {'peter': 338, 'piper': 289, 'picked': 286, 'a': 138, 'peck': 264, 'of': 246, 'pickled': 285, 'peppers': 321, "where's": 118, 'the': 137}) {'peter': 0.13955408753096615, 'piper': 0.11932287365813378, 'picked': 0.1180842279108175, 'a': 0.05697770437654831, 'peck': 0.10900082576383155, 'of': 0.10156895127993394, 'pickled': 0.11767134599504542, 'peppers': 0.13253509496284063, "where's": 0.04872006606110652, 'the': 0.056564822460776217}

# %%
#TASK 2, using the above probabilities to change the word probabilties
# !pip install pandas
import pandas as pd
results_df=[]
import wer
f= create_wfst(3,probabilities)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                     # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_unary.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
#TASK 2, changing self-loop probabilities
# !pip install pandas
import pandas as pd
results_df=[]
import wer
f= create_wfst(3,next_state_prob=0.7)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                                                               # audio files
    
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_0.7.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
#task2 silent states between states

# %%
from copy import deepcopy



def create_wfst_silent(n, probabilities=None, next_state_prob=0.5, sil_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs."""
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))


    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            last_state = current_state
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
            
        weight = fst.Weight('log',-math.log(1-sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,start_state))
        weight = fst.Weight('log',-math.log(sil_prob*(1-next_state_prob)))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'),0,weight,current_state))
        next_state =f.add_state()
        weight = fst.Weight('log',-math.log(sil_prob*((next_state_prob))))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'),0,weight,next_state))
        current_state=next_state
        
        
        for i in range(2,6):
            weight = fst.Weight('log',-math.log(1-next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
            next_state =f.add_state()
            weight = fst.Weight('log',-math.log(next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
            current_state=next_state
        

            
            
            
            
            
        
        
        
        next_weight = fst.Weight('log', -math.log(1))
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))
    f.set_input_symbols(silent_state_table)
    f.set_output_symbols(word_table)


    return f

# %%
f=create_wfst_silent(3,sil_prob=0.6)

# %%
draw_fst(f)

# %%
#TASK 2, changing self-loop probabilities
# !pip install pandas
import pandas as pd
results_df=[]
import wer
f= create_wfst_silent(3,sil_prob=0.5)
print(num_states(f))
print(total_num_arcs(f))

results_df=[]

f= create_wfst_silent(3,sil_prob=0.1)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                          # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_silent_0.1.csv')
results_df=[]

f= create_wfst_silent(3,sil_prob=0.2)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                          # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_silent_0.2.csv')
results_df=[]

f= create_wfst_silent(3,sil_prob=0.3)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                          # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_silent_0.3.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 166
# 340
# 166
# 340
# 7.833009481430054
# 0.0022835731506347656
# {'Filename': '0000.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.11764705882352941, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "pickled peter piper picked a the peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Decode speed': 7.833009481430054, 'Backtrace speed': 0.0022835731506347656, 'Forward computations': 354068}
# 4.422242164611816
# 0.0007348060607910156
# {'Filename': '0001.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': 'pickled a peter picked the of peck of pickled peppers', 'Decode speed': 4.422242164611816, 'Backtrace speed': 0.0007348060607910156, 'Forward computations': 200618}
# 3.3436083793640137
# 0.0005788803100585938
# {'Filename': '0002.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.16666666666666666, 'Word Count': 6, 'transcription': 'a peck of pickled peppers picked', 'Viterbi transcription': 'pickled peck of pickled peppers picked', 'Decode speed': 3.3436083793640137, 'Backtrace speed': 0.0005788803100585938, 'Forward computations': 150398}
# 2.4579923152923584
# 0.0005795955657958984
# {'Filename': '0003.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peter piper peter piper', 'Viterbi transcription': 'pickled peter piper peter piper', 'Decode speed': 2.4579923152923584, 'Backtrace speed': 0.0005795955657958984, 'Forward computations': 110718}
# 3.1639201641082764
# 0.0003809928894042969
# {'Filename': '0004.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': "where's the peck of pickled peppers picked", 'Viterbi transcription': "pickled where's the pickled pickled peppers picked", 'Decode speed': 3.1639201641082764, 'Backtrace speed': 0.0003809928894042969, 'Forward computations': 145128}
# 1.9006266593933105
# 0.0003237724304199219
# {'Filename': '0005.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 4, 'transcription': 'peter piper pickled peppers', 'Viterbi transcription': 'peter piper pickled peppers', 'Decode speed': 1.9006266593933105, 'Backtrace speed': 0.0003237724304199219, 'Forward computations': 86848}
# 1.1401188373565674
# 9.226799011230469e-05
# {'Filename': '0006.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 2, 'transcription': "where's peter", 'Viterbi transcription': "where's peter", 'Decode speed': 1.1401188373565674, 'Backtrace speed': 9.226799011230469e-05, 'Forward computations': 52438}
# 1.8827612400054932
# 0.00015020370483398438
# {'Filename': '0007.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'piper picked peppers of peter', 'Viterbi transcription': 'a piper picked peppers of peter', 'Decode speed': 1.8827612400054932, 'Backtrace speed': 0.00015020370483398438, 'Forward computations': 86848}
# 2.1246094703674316
# 0.0005664825439453125
# {'Filename': '0008.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 6, 'transcription': 'peter peppers picked piper of peck', 'Viterbi transcription': 'peter peppers picked piper of peck', 'Decode speed': 2.1246094703674316, 'Backtrace speed': 0.0005664825439453125, 'Forward computations': 97388}
# 2.7183923721313477
# 0.0002655982971191406
# {'Filename': '0009.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.125, 'Word Count': 8, 'transcription': 'a peck of pickled peppers peter piper pickled', 'Viterbi transcription': 'a peck of picked peppers peter piper pickled', 'Decode speed': 2.7183923721313477, 'Backtrace speed': 0.0002655982971191406, 'Forward computations': 124048}
# 1.2059588432312012
# 0.0001232624053955078
# {'Filename': '0010.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'picked', 'Viterbi transcription': 'a picked', 'Decode speed': 1.2059588432312012, 'Backtrace speed': 0.0001232624053955078, 'Forward computations': 55228}
# 1.025686264038086
# 8.702278137207031e-05
# {'Filename': '0011.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'pickled', 'Viterbi transcription': 'a pickled', 'Decode speed': 1.025686264038086, 'Backtrace speed': 8.702278137207031e-05, 'Forward computations': 47168}
# 1.8119821548461914
# 0.00045990943908691406
# {'Filename': '0012.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'peppers', 'Viterbi transcription': 'a peppers', 'Decode speed': 1.8119821548461914, 'Backtrace speed': 0.00045990943908691406, 'Forward computations': 81578}
# 1.6411502361297607
# 0.0001499652862548828
# {'Filename': '0013.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'piper', 'Viterbi transcription': 'a piper', 'Decode speed': 1.6411502361297607, 'Backtrace speed': 0.0001499652862548828, 'Forward computations': 73518}
# 1.4531679153442383
# 0.00010395050048828125
# {'Filename': '0014.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'peter', 'Viterbi transcription': 'a peter', 'Decode speed': 1.4531679153442383, 'Backtrace speed': 0.00010395050048828125, 'Forward computations': 65768}
# 2.660726547241211
# 0.0002357959747314453
# {'Filename': '0015.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's the peck of the pickled peppers", 'Decode speed': 2.660726547241211, 'Backtrace speed': 0.0002357959747314453, 'Forward computations': 121258}
# 1.6476175785064697
# 0.0001919269561767578
# {'Filename': '0016.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'a peter piper the picked', 'Decode speed': 1.6476175785064697, 'Backtrace speed': 0.0001919269561767578, 'Forward computations': 76308}
# 3.717543363571167
# 0.0005242824554443359
# {'Filename': '0017.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter of piper picked picked of peck of pickled peppers', 'Decode speed': 3.717543363571167, 'Backtrace speed': 0.0005242824554443359, 'Forward computations': 168998}
# 1.8235118389129639
# 0.00010323524475097656
# {'Filename': '0018.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'picked a peck of pickled peppers', 'Viterbi transcription': "a picked the peck of pickled peck where's", 'Decode speed': 1.8235118389129639, 'Backtrace speed': 0.00010323524475097656, 'Forward computations': 84368}
# 3.3420143127441406
# 0.00020503997802734375
# {'Filename': '0019.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'a the peck piper a picked', 'Decode speed': 3.3420143127441406, 'Backtrace speed': 0.00020503997802734375, 'Forward computations': 152878}
# 4.559187173843384
# 0.0007774829864501953
# {'Filename': '0020.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': "peppers picked peter piper where's the peck", 'Viterbi transcription': "a peppers picked peter of piper the a where's the the peck", 'Decode speed': 4.559187173843384, 'Backtrace speed': 0.0007774829864501953, 'Forward computations': 208678}
# 6.495176076889038
# 0.0008502006530761719
# {'Filename': '0021.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 10, 'transcription': 'peter picked a peck piper pickled peppers of pickled peppers', 'Viterbi transcription': 'a peter peck picked of peck piper the of pickled the peppers of pickled peppers', 'Decode speed': 6.495176076889038, 'Backtrace speed': 0.0008502006530761719, 'Forward computations': 295788}
# 4.888552904129028
# 0.0010166168212890625
# {'Filename': '0022.wav', 'Insertions': 11, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.5, 'Word Count': 8, 'transcription': 'peter piper piper peter peter peter piper piper', 'Viterbi transcription': 'a the picked peck piper the of piper the peter picked peter of peter of piper the of piper', 'Decode speed': 4.888552904129028, 'Backtrace speed': 0.0010166168212890625, 'Forward computations': 221698}
# 3.1724321842193604
# 0.0001971721649169922
# {'Filename': '0023.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.75, 'Word Count': 4, 'transcription': 'peter picked piper peppers', 'Viterbi transcription': 'a peter of picked piper of peppers', 'Decode speed': 3.1724321842193604, 'Backtrace speed': 0.0001971721649169922, 'Forward computations': 143888}
# 3.5478298664093018
# 0.00026154518127441406
# {'Filename': '0024.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'peter peter peter peter peter peter', 'Viterbi transcription': 'a peter peck peter peter peck peter picked pickled', 'Decode speed': 3.5478298664093018, 'Backtrace speed': 0.00026154518127441406, 'Forward computations': 160938}
# 3.645892381668091
# 0.0002837181091308594
# {'Filename': '0025.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': 'piper picked a peck of peter peppers', 'Viterbi transcription': 'a a picked picked of peck of peter peppers a', 'Decode speed': 3.645892381668091, 'Backtrace speed': 0.0002837181091308594, 'Forward computations': 166208}
# 3.5415878295898438
# 0.0006237030029296875
# {'Filename': '0026.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'pickled peppers peter piper picked a peck of', 'Viterbi transcription': "a pickled of where's peter piper picked the peck of a", 'Decode speed': 3.5415878295898438, 'Backtrace speed': 0.0006237030029296875, 'Forward computations': 160938}
# 4.259039878845215
# 0.0003204345703125
# {'Filename': '0027.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'of peppers of picked a peter piper of', 'Viterbi transcription': "a of of where's of picked of peter piper of a", 'Decode speed': 4.259039878845215, 'Backtrace speed': 0.0003204345703125, 'Forward computations': 195348}
# 2.7183454036712646
# 0.00016808509826660156
# {'Filename': '0028.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 5, 'transcription': 'pickled peppers peter piper picked', 'Viterbi transcription': 'a pickled peppers picked of piper of peck', 'Decode speed': 2.7183454036712646, 'Backtrace speed': 0.00016808509826660156, 'Forward computations': 124048}
# 2.7666027545928955
# 0.00016689300537109375
# {'Filename': '0029.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': 'a a picked picked of peck of pickled peppers', 'Decode speed': 2.7666027545928955, 'Backtrace speed': 0.00016689300537109375, 'Forward computations': 126528}
# 2.9721338748931885
# 0.00025081634521484375
# {'Filename': '0030.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': "where's a peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's of peck pickled peppers peter piper picked", 'Decode speed': 2.9721338748931885, 'Backtrace speed': 0.00025081634521484375, 'Forward computations': 134588}
# 1.7409656047821045
# 9.489059448242188e-05
# {'Filename': '0031.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peter piper picked the peppers', 'Viterbi transcription': 'a picked piper of picked of peppers', 'Decode speed': 1.7409656047821045, 'Backtrace speed': 9.489059448242188e-05, 'Forward computations': 79098}
# 1.9736583232879639
# 0.0004057884216308594
# {'Filename': '0032.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'pickled peppers picked peter piper', 'Viterbi transcription': 'a pickled peck picked a picked piper', 'Decode speed': 1.9736583232879639, 'Backtrace speed': 0.0004057884216308594, 'Forward computations': 89638}
# 2.0290729999542236
# 0.00011014938354492188
# {'Filename': '0033.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 5, 'transcription': 'a peck of pickled peppers', 'Viterbi transcription': 'a peck of pickled peppers', 'Decode speed': 2.0290729999542236, 'Backtrace speed': 0.00011014938354492188, 'Forward computations': 92118}
# 1.5054638385772705
# 8.296966552734375e-05
# {'Filename': '0034.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': "where's the peck peter picked", 'Viterbi transcription': "a where's the peck peter picked", 'Decode speed': 1.5054638385772705, 'Backtrace speed': 8.296966552734375e-05, 'Forward computations': 68248}
# 2.783893346786499
# 0.00018525123596191406
# {'Filename': '0035.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'pickled peppers piper picked', 'Viterbi transcription': 'a pickled peppers piper picked', 'Decode speed': 2.783893346786499, 'Backtrace speed': 0.00018525123596191406, 'Forward computations': 126528}
# 1.553682565689087
# 0.00014090538024902344
# {'Filename': '0036.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': 'a peter picked peppers', 'Decode speed': 1.553682565689087, 'Backtrace speed': 0.00014090538024902344, 'Forward computations': 71038}
# 2.5853466987609863
# 0.00036072731018066406
# {'Filename': '0037.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter piper picked peck of pickled peppers', 'Decode speed': 2.5853466987609863, 'Backtrace speed': 0.00036072731018066406, 'Forward computations': 118778}
# 2.528008460998535
# 0.00016736984252929688
# {'Filename': '0038.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter picked a picked picked picked pickled peppers', 'Decode speed': 2.528008460998535, 'Backtrace speed': 0.00016736984252929688, 'Forward computations': 115988}
# 2.2461886405944824
# 0.00012135505676269531
# {'Filename': '0039.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': 'peppers pickled peter of the piper peck', 'Viterbi transcription': 'a peppers pickled peter of the piper peck', 'Decode speed': 2.2461886405944824, 'Backtrace speed': 0.00012135505676269531, 'Forward computations': 102658}
# 3.0929923057556152
# 0.00018286705017089844
# {'Filename': '0040.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': "piper peter picked where's the pickled peppers peter", 'Viterbi transcription': "a peck peter picked where's the pickled peppers peter a", 'Decode speed': 3.0929923057556152, 'Backtrace speed': 0.00018286705017089844, 'Forward computations': 142338}
# 2.427464246749878
# 0.0005757808685302734
# {'Filename': '0041.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'peck pickled piper of the peter peppers', 'Viterbi transcription': 'a peck pickled picked of the peter peppers', 'Decode speed': 2.427464246749878, 'Backtrace speed': 0.0005757808685302734, 'Forward computations': 110718}
# 2.994286060333252
# 0.00016689300537109375
# {'Filename': '0042.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.09090909090909091, 'Word Count': 11, 'transcription': 'a peck of pickled peter picked the peppers of the peck', 'Viterbi transcription': 'a peck of pickled peter peck the peppers of the peck', 'Decode speed': 2.994286060333252, 'Backtrace speed': 0.00016689300537109375, 'Forward computations': 137068}
# 2.537412166595459
# 0.0001342296600341797
# {'Filename': '0043.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': "where's the peck of peppers piper pickled", 'Viterbi transcription': "a where's of a of peppers piper of pickled", 'Decode speed': 2.537412166595459, 'Backtrace speed': 0.0001342296600341797, 'Forward computations': 115988}
# 2.9431984424591064
# 0.00016355514526367188
# {'Filename': '0044.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'piper pickled peppers of the peck peter picked', 'Viterbi transcription': 'a piper of pickled peppers of the piper peter peck', 'Decode speed': 2.9431984424591064, 'Backtrace speed': 0.00016355514526367188, 'Forward computations': 134588}
# 2.884209632873535
# 0.00016379356384277344
# {'Filename': '0045.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'piper peter picked pickled piper peppers', 'Viterbi transcription': "a pickled the where's pickled picked peppers", 'Decode speed': 2.884209632873535, 'Backtrace speed': 0.00016379356384277344, 'Forward computations': 131798}
# 3.1028833389282227
# 0.0001842975616455078
# {'Filename': '0046.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.9090909090909091, 'Word Count': 11, 'transcription': 'peter picked peppers of the pickled peck of peppers of piper', 'Viterbi transcription': "a the the of where's of the of pickled peck of peck where's of of the", 'Decode speed': 3.1028833389282227, 'Backtrace speed': 0.0001842975616455078, 'Forward computations': 142338}
# 5.452108860015869
# 0.000461578369140625
# {'Filename': '0047.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.4117647058823529, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a the pickled piper picked peck of picked of peppers where's the peck of picked peppers peter piper picked", 'Decode speed': 5.452108860015869, 'Backtrace speed': 0.000461578369140625, 'Forward computations': 248358}
# 3.0178027153015137
# 0.00031876564025878906
# {'Filename': '0048.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter piper picked the peck of pickled peppers', 'Decode speed': 3.0178027153015137, 'Backtrace speed': 0.00031876564025878906, 'Forward computations': 137068}
# 2.483398675918579
# 0.0007050037384033203
# {'Filename': '0049.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's the peck of picked of peppers peter piper picked", 'Decode speed': 2.483398675918579, 'Backtrace speed': 0.0007050037384033203, 'Forward computations': 113198}
# 2.3362021446228027
# 0.0002601146697998047
# {'Filename': '0050.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'pickled peppers pickled peter piper', 'Viterbi transcription': "a pickled of where's pickled picked piper", 'Decode speed': 2.3362021446228027, 'Backtrace speed': 0.0002601146697998047, 'Forward computations': 107928}
# 3.5837628841400146
# 0.00040268898010253906
# {'Filename': '0051.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.36363636363636365, 'Word Count': 11, 'transcription': 'peter piper picked a peck of pickled peppers peter piper pickled', 'Viterbi transcription': "a peter piper picked picked of pickled where's peter piper pickled", 'Decode speed': 3.5837628841400146, 'Backtrace speed': 0.00040268898010253906, 'Forward computations': 163728}
# 2.3379287719726562
# 0.0002605915069580078
# {'Filename': '0052.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a peter of piper picked peck of pickled where's", 'Decode speed': 2.3379287719726562, 'Backtrace speed': 0.0002605915069580078, 'Forward computations': 107928}
# 2.170146942138672
# 0.0002276897430419922
# {'Filename': '0053.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's of peck of pickled peppers", 'Decode speed': 2.170146942138672, 'Backtrace speed': 0.0002276897430419922, 'Forward computations': 97388}
# 1.9180998802185059
# 0.0002117156982421875
# {'Filename': '0054.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.75, 'Word Count': 4, 'transcription': 'piper peter peppers pickled', 'Viterbi transcription': "a piper of peter where's pickled", 'Decode speed': 1.9180998802185059, 'Backtrace speed': 0.0002117156982421875, 'Forward computations': 86848}
# 2.4477362632751465
# 0.0002636909484863281
# {'Filename': '0055.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.7777777777777778, 'Word Count': 9, 'transcription': 'peter piper picked peter piper picked peter piper picked', 'Viterbi transcription': 'a peter of piper of picked peter of of of picked peter piper of picked', 'Decode speed': 2.4477362632751465, 'Backtrace speed': 0.0002636909484863281, 'Forward computations': 110718}
# 2.0301473140716553
# 0.00018095970153808594
# {'Filename': '0056.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "where's the peck of peter piper peppers", 'Viterbi transcription': "a where's the peck of peter piper where's", 'Decode speed': 2.0301473140716553, 'Backtrace speed': 0.00018095970153808594, 'Forward computations': 92118}
# 3.3465075492858887
# 0.0003001689910888672
# {'Filename': '0057.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a picked piper pickled peck the pickled peppers', 'Decode speed': 3.3465075492858887, 'Backtrace speed': 0.0003001689910888672, 'Forward computations': 152878}
# 2.476045846939087
# 0.0002422332763671875
# {'Filename': '0058.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'the peck of pickled peppers picked peter piper', 'Viterbi transcription': "a the peck of the pickled of where's peck peter piper", 'Decode speed': 2.476045846939087, 'Backtrace speed': 0.0002422332763671875, 'Forward computations': 113198}
# 3.0070137977600098
# 0.00025725364685058594
# {'Filename': '0059.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'piper picked peter the pickled peppers', 'Viterbi transcription': "a piper of picked peter the pickled picked where's", 'Decode speed': 3.0070137977600098, 'Backtrace speed': 0.00025725364685058594, 'Forward computations': 137068}
# 2.1423869132995605
# 0.000247955322265625
# {'Filename': '0060.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': 'peck piper peter pickled picked', 'Viterbi transcription': 'a peck piper peter of pickled peck', 'Decode speed': 2.1423869132995605, 'Backtrace speed': 0.000247955322265625, 'Forward computations': 97388}
# 2.4081971645355225
# 0.0006463527679443359
# {'Filename': '0061.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'peck peppers pickled peter piper', 'Viterbi transcription': 'a peck peppers pickled peter piper', 'Decode speed': 2.4081971645355225, 'Backtrace speed': 0.0006463527679443359, 'Forward computations': 110718}
# 6.111138820648193
# 0.0006589889526367188
# {'Filename': '0062.wav', 'Insertions': 5, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.5294117647058824, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter of piper a picked of picked of pickled peppers where's peck of pickled peppers picked of piper a picked", 'Decode speed': 6.111138820648193, 'Backtrace speed': 0.0006589889526367188, 'Forward computations': 279048}
# 3.4499759674072266
# 0.00037384033203125
# {'Filename': '0063.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8571428571428571, 'Word Count': 7, 'transcription': "peter piper picked where's the peck of", 'Viterbi transcription': "a picked of piper a where's of peck pickled", 'Decode speed': 3.4499759674072266, 'Backtrace speed': 0.00037384033203125, 'Forward computations': 158148}
# 5.023608684539795
# 0.0005087852478027344
# {'Filename': '0064.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.5, 'Word Count': 12, 'transcription': 'pickled peppers pickled peppers peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a pickled where's pickled peppers picked of piper a of a peck of pickled peppers", 'Decode speed': 5.023608684539795, 'Backtrace speed': 0.0005087852478027344, 'Forward computations': 230068}
# 3.663235902786255
# 0.00038242340087890625
# {'Filename': '0065.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'the peck of pickled peppers peter piper picked', 'Viterbi transcription': 'a the of a of pickled peppers peter of piper a', 'Decode speed': 3.663235902786255, 'Backtrace speed': 0.00038242340087890625, 'Forward computations': 166828}
# 3.401219129562378
# 0.00036835670471191406
# {'Filename': '0066.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a the the of piper picked of peck of pickled peppers', 'Decode speed': 3.401219129562378, 'Backtrace speed': 0.00036835670471191406, 'Forward computations': 155358}
# 5.10956335067749
# 0.0004825592041015625
# {'Filename': '0067.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'pickled peter peppers pickled peppers piper of piper', 'Viterbi transcription': 'a picked of peter the peppers pickled peppers piper of piper', 'Decode speed': 5.10956335067749, 'Backtrace speed': 0.0004825592041015625, 'Forward computations': 232238}
# 3.094247579574585
# 0.00031065940856933594
# {'Filename': '0068.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': "pickled where's peck peck peppers", 'Viterbi transcription': "a pickled where's peck picked peppers", 'Decode speed': 3.094247579574585, 'Backtrace speed': 0.00031065940856933594, 'Forward computations': 142338}
# 4.454547882080078
# 0.0004220008850097656
# {'Filename': '0069.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': 'picked pickled a pickled peter of peppers peppers piper', 'Viterbi transcription': 'a pickled pickled of pickled peter of of peppers peppers piper', 'Decode speed': 4.454547882080078, 'Backtrace speed': 0.0004220008850097656, 'Forward computations': 203408}
# 2.5522940158843994
# 0.0003113746643066406
# {'Filename': '0070.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peck peppers picked piper', 'Viterbi transcription': 'a peck peppers picked piper', 'Decode speed': 2.5522940158843994, 'Backtrace speed': 0.0003113746643066406, 'Forward computations': 115988}
# 2.854459047317505
# 0.0002713203430175781
# {'Filename': '0071.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'a peter pickled pickled picked', 'Viterbi transcription': 'a of peter of pickled pickled picked', 'Decode speed': 2.854459047317505, 'Backtrace speed': 0.0002713203430175781, 'Forward computations': 129318}
# 4.658879280090332
# 0.00044536590576171875
# {'Filename': '0072.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.6666666666666666, 'Word Count': 9, 'transcription': 'peck peppers picked a picked peter a picked peppers', 'Viterbi transcription': "a peck where's picked of picked peter of pickled where's", 'Decode speed': 4.658879280090332, 'Backtrace speed': 0.00044536590576171875, 'Forward computations': 213018}
# 3.7761151790618896
# 0.00035834312438964844
# {'Filename': '0073.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': "peck picked peppers peck picked where's of pickled", 'Viterbi transcription': "a peck picked where's peck picked where's of pickled", 'Decode speed': 3.7761151790618896, 'Backtrace speed': 0.00035834312438964844, 'Forward computations': 172718}
# 3.074089765548706
# 0.0002624988555908203
# {'Filename': '0074.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': "a peter where's piper the picked picked peppers", 'Viterbi transcription': "a of peter where's piper the pickled picked peppers", 'Decode speed': 3.074089765548706, 'Backtrace speed': 0.0002624988555908203, 'Forward computations': 140788}
# 3.7115914821624756
# 0.000347137451171875
# {'Filename': '0075.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'piper peck of peck pickled picked pickled of peter', 'Viterbi transcription': 'a piper of piper of peck pickled picked pickled of peter', 'Decode speed': 3.7115914821624756, 'Backtrace speed': 0.000347137451171875, 'Forward computations': 169618}
# 4.123913288116455
# 0.00035953521728515625
# {'Filename': '0076.wav', 'Insertions': 4, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': 'peck of peter peppers pickled peppers of picked peter', 'Viterbi transcription': "a peck of the the of peck where's pickled where's of picked", 'Decode speed': 4.123913288116455, 'Backtrace speed': 0.00035953521728515625, 'Forward computations': 189768}
# 4.892451286315918
# 0.0006008148193359375
# {'Filename': '0077.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2222222222222222, 'Word Count': 9, 'transcription': 'peppers peck of peck peter picked a of peppers', 'Viterbi transcription': 'a peppers peck of peck peck peter picked a of peppers', 'Decode speed': 4.892451286315918, 'Backtrace speed': 0.0006008148193359375, 'Forward computations': 221698}
# 3.8847687244415283
# 0.00044798851013183594
# {'Filename': '0078.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.1111111111111111, 'Word Count': 9, 'transcription': 'a peck of the pickled peppers peter piper picked', 'Viterbi transcription': 'a of peck of the pickled peppers peter piper picked', 'Decode speed': 3.8847687244415283, 'Backtrace speed': 0.00044798851013183594, 'Forward computations': 176748}
# 2.7943947315216064
# 0.00021028518676757812
# {'Filename': '0079.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.16666666666666666, 'Word Count': 6, 'transcription': 'piper picked peter of the peck', 'Viterbi transcription': 'a piper picked peter of the peck', 'Decode speed': 2.7943947315216064, 'Backtrace speed': 0.00021028518676757812, 'Forward computations': 129318}
# 3.6203839778900146
# 0.0002627372741699219
# {'Filename': '0080.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.125, 'Word Count': 8, 'transcription': 'a peter picked peck of picked pickled piper', 'Viterbi transcription': 'a peck peter picked peck of picked pickled piper', 'Decode speed': 3.6203839778900146, 'Backtrace speed': 0.0002627372741699219, 'Forward computations': 166208}
# 2.798335075378418
# 0.00022792816162109375
# {'Filename': '0081.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': "where's peck peppers of piper", 'Viterbi transcription': "a where's peck peppers of piper", 'Decode speed': 2.798335075378418, 'Backtrace speed': 0.00022792816162109375, 'Forward computations': 126528}
# 3.355327844619751
# 0.0005023479461669922
# {'Filename': '0082.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 3, 'transcription': 'piper of peppers', 'Viterbi transcription': "a piper picked where's", 'Decode speed': 3.355327844619751, 'Backtrace speed': 0.0005023479461669922, 'Forward computations': 152878}
# 2.494548797607422
# 0.0001590251922607422
# {'Filename': '0083.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter picked piper', 'Viterbi transcription': 'a peter picked picked piper a', 'Decode speed': 2.494548797607422, 'Backtrace speed': 0.0001590251922607422, 'Forward computations': 113198}
# 1.6839563846588135
# 0.00010967254638671875
# {'Filename': '0084.wav', 'Insertions': 1, 'Deletions': 4, 'Substitutions': 0, 'WER': 0.5555555555555556, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': 'pickled peppers peter of piper picked', 'Decode speed': 1.6839563846588135, 'Backtrace speed': 0.00010967254638671875, 'Forward computations': 76308}
# 2.289933443069458
# 0.00018930435180664062
# {'Filename': '0085.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.5454545454545454, 'Word Count': 11, 'transcription': 'the peck of pickled peppers picked a peck of pickled peppers', 'Viterbi transcription': "peck of pickled peppers picked of peck of peck of peck where's", 'Decode speed': 2.289933443069458, 'Backtrace speed': 0.00018930435180664062, 'Forward computations': 105448}
# 2.911550998687744
# 0.0003170967102050781
# {'Filename': '0086.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': "peter piper where's the peck of pickled peppers", 'Viterbi transcription': "peter of piper where's of peck of pickled peppers peter piper", 'Decode speed': 2.911550998687744, 'Backtrace speed': 0.0003170967102050781, 'Forward computations': 131798}
# 3.3168394565582275
# 0.00040459632873535156
# {'Filename': '0087.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': 'peter piper peter piper a peck of pickled peppers', 'Viterbi transcription': "peter piper peter piper picked of pickled peck where's", 'Decode speed': 3.3168394565582275, 'Backtrace speed': 0.00040459632873535156, 'Forward computations': 150398}
# 3.44309139251709
# 0.00034880638122558594
# {'Filename': '0088.wav', 'Insertions': 0, 'Deletions': 4, 'Substitutions': 2, 'WER': 0.35294117647058826, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "piper picked peck pickled peppers where's the peck pickled where's peter picked picked", 'Decode speed': 3.44309139251709, 'Backtrace speed': 0.00034880638122558594, 'Forward computations': 155668}
# 4.055296182632446
# 0.0004107952117919922
# {'Filename': '0089.wav', 'Insertions': 4, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a picked of of the picked peck of pickled peppers where's the peck of picked a peppers peter piper picked", 'Decode speed': 4.055296182632446, 'Backtrace speed': 0.0004107952117919922, 'Forward computations': 184808}
# 6.009756088256836
# 0.0006940364837646484
# {'Filename': '0090.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.23529411764705882, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter piper picked a peck of pickled peppers where's the peck of pickled picked where's peter piper peck picked", 'Decode speed': 6.009756088256836, 'Backtrace speed': 0.0006940364837646484, 'Forward computations': 271918}
# 1.4564201831817627
# 8.630752563476562e-05
# {'Filename': '0091.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 4, 'transcription': "where's the peck of", 'Viterbi transcription': "a where's of peck of", 'Decode speed': 1.4564201831817627, 'Backtrace speed': 8.630752563476562e-05, 'Forward computations': 65768}
# 1.6030077934265137
# 0.00017404556274414062
# {'Filename': '0092.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'picked a peck of pickled', 'Viterbi transcription': 'a picked peck of pickled', 'Decode speed': 1.6030077934265137, 'Backtrace speed': 0.00017404556274414062, 'Forward computations': 73518}
# 1.904947280883789
# 0.0001404285430908203
# {'Filename': '0093.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': "pickled peppers where's the peck", 'Viterbi transcription': "a pickled peppers where's the peck", 'Decode speed': 1.904947280883789, 'Backtrace speed': 0.0001404285430908203, 'Forward computations': 86848}
# 1.5497918128967285
# 0.00021982192993164062
# {'Filename': '0094.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': "a peter picked peck where's", 'Decode speed': 1.5497918128967285, 'Backtrace speed': 0.00021982192993164062, 'Forward computations': 71038}
# 2.1018872261047363
# 0.00019502639770507812
# {'Filename': '0095.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'peter pickled a picked peck', 'Viterbi transcription': 'a peter pickled picked peck', 'Decode speed': 2.1018872261047363, 'Backtrace speed': 0.00019502639770507812, 'Forward computations': 94908}
# 2.0840108394622803
# 0.0001537799835205078
# {'Filename': '0096.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': 'peter picked the peck of peppers', 'Viterbi transcription': 'a peter picked the peck peck of peppers', 'Decode speed': 2.0840108394622803, 'Backtrace speed': 0.0001537799835205078, 'Forward computations': 94908}
# 2.7703325748443604
# 0.000213623046875
# {'Filename': '0097.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': 'peter picked a peck of the pickled peppers', 'Viterbi transcription': 'a peter piper picked the peck of the pickled peppers', 'Decode speed': 2.7703325748443604, 'Backtrace speed': 0.000213623046875, 'Forward computations': 126528}
# 1.9925332069396973
# 0.0001652240753173828
# {'Filename': '0098.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': 'the peck of peppers peter piper pickled', 'Viterbi transcription': "a the peck of peck where's peter piper pickled", 'Decode speed': 1.9925332069396973, 'Backtrace speed': 0.0001652240753173828, 'Forward computations': 92118}
# 5.3114914894104
# 0.00055694580078125
# {'Filename': '0099.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.36363636363636365, 'Word Count': 11, 'transcription': "the peck pickled peppers picked pickled peter of piper a where's", 'Viterbi transcription': "a the picked piper pickled peppers picked peck pickled peter of piper a where's", 'Decode speed': 5.3114914894104, 'Backtrace speed': 0.00055694580078125, 'Forward computations': 243088}
# 3.8217527866363525
# 0.001116037368774414
# {'Filename': '0100.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 10, 'transcription': 'the picked of piper picked of pickled a peter piper', 'Viterbi transcription': 'a the picked of piper picked of pickled a the peter piper', 'Decode speed': 3.8217527866363525, 'Backtrace speed': 0.001116037368774414, 'Forward computations': 174268}
# 6.049494981765747
# 0.0006277561187744141
# {'Filename': '0101.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.2857142857142857, 'Word Count': 14, 'transcription': "peck piper picked of picked pickled of where's a peppers peter peppers peter pickled", 'Viterbi transcription': "a picked piper picked of peter pickled of where's a the peppers peter peppers peter pickled", 'Decode speed': 6.049494981765747, 'Backtrace speed': 0.0006277561187744141, 'Forward computations': 277498}
# 2.364044666290283
# 0.0001494884490966797
# {'Filename': '0102.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peppers peck peter pickled', 'Viterbi transcription': 'a peppers peck peter pickled', 'Decode speed': 2.364044666290283, 'Backtrace speed': 0.0001494884490966797, 'Forward computations': 107928}
# 3.1549432277679443
# 0.00026416778564453125
# {'Filename': '0103.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "where's piper picked piper a pickled peppers", 'Viterbi transcription': "a where's piper picked piper pickled peppers", 'Decode speed': 3.1549432277679443, 'Backtrace speed': 0.00026416778564453125, 'Forward computations': 145128}
# 3.1950736045837402
# 0.00021123886108398438
# {'Filename': '0104.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 6, 'transcription': 'peter picked peppers of pickled peppers', 'Viterbi transcription': 'a peter picked a peck peppers of pickled picked picked a', 'Decode speed': 3.1950736045837402, 'Backtrace speed': 0.00021123886108398438, 'Forward computations': 146678}
# 3.9452552795410156
# 0.00029921531677246094
# {'Filename': '0105.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'peter peppers picked piper a peck of pickled peppers', 'Viterbi transcription': 'a peter peppers a piper peck of pickled peppers', 'Decode speed': 3.9452552795410156, 'Backtrace speed': 0.00029921531677246094, 'Forward computations': 181088}
# 3.504460096359253
# 0.00025725364685058594
# {'Filename': '0106.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a peter piper peck picked peck of pickled where's", 'Decode speed': 3.504460096359253, 'Backtrace speed': 0.00025725364685058594, 'Forward computations': 160938}
# 3.249488353729248
# 0.00021839141845703125
# {'Filename': '0107.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': "where's the peck of peppers peter piper picked", 'Viterbi transcription': "a where's the picked of peppers peter piper a picked", 'Decode speed': 3.249488353729248, 'Backtrace speed': 0.00021839141845703125, 'Forward computations': 149468}
# 2.6778061389923096
# 0.0001614093780517578
# {'Filename': '0108.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'the peck of pickled peter piper pickled', 'Viterbi transcription': 'a peck of pickled peter piper of pickled', 'Decode speed': 2.6778061389923096, 'Backtrace speed': 0.0001614093780517578, 'Forward computations': 123738}
# 2.770387649536133
# 0.0001823902130126953
# {'Filename': '0109.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 6, 'transcription': 'piper peter picked peppers of piper', 'Viterbi transcription': 'a piper peter picked peppers of piper of a', 'Decode speed': 2.770387649536133, 'Backtrace speed': 0.0001823902130126953, 'Forward computations': 126528}
# 2.5057573318481445
# 0.00014853477478027344
# {'Filename': '0110.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': 'peter peppers picked a piper of the peck', 'Viterbi transcription': 'a peter of peppers picked of piper of the peck', 'Decode speed': 2.5057573318481445, 'Backtrace speed': 0.00014853477478027344, 'Forward computations': 115988}
# 2.253239631652832
# 0.00012755393981933594
# {'Filename': '0111.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'peck of picked peter piper picked', 'Viterbi transcription': 'a picked of picked peter of piper of picked', 'Decode speed': 2.253239631652832, 'Backtrace speed': 0.00012755393981933594, 'Forward computations': 102658}
# 2.192660331726074
# 0.0002002716064453125
# {'Filename': '0112.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': 'picked the peppers peter pickled', 'Viterbi transcription': 'a a the peppers peter of pickled', 'Decode speed': 2.192660331726074, 'Backtrace speed': 0.0002002716064453125, 'Forward computations': 100178}
# 2.5339529514312744
# 0.00015974044799804688
# {'Filename': '0113.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'the piper of peck peppers peter picked', 'Viterbi transcription': 'a the piper of peck peppers peter of picked', 'Decode speed': 2.5339529514312744, 'Backtrace speed': 0.00015974044799804688, 'Forward computations': 115988}
# 5.808996915817261
# 0.0005283355712890625
# {'Filename': '0114.wav', 'Insertions': 0, 'Deletions': 5, 'Substitutions': 2, 'WER': 0.875, 'Word Count': 8, 'transcription': 'piper picked peter a pickled peck of peppers', 'Viterbi transcription': "a where's where's", 'Decode speed': 5.808996915817261, 'Backtrace speed': 0.0005283355712890625, 'Forward computations': 266648}
# 2.712385892868042
# 0.00017714500427246094
# {'Filename': '0115.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': "where's peter piper", 'Viterbi transcription': "a where's the the piper pickled", 'Decode speed': 2.712385892868042, 'Backtrace speed': 0.00017714500427246094, 'Forward computations': 124048}
# 3.570803165435791
# 0.0003077983856201172
# {'Filename': '0116.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 6, 'WER': 1.0, 'Word Count': 9, 'transcription': 'piper picked the peck of pickled peppers peter picked', 'Viterbi transcription': "a of a picked picked of peck pickled of where's picked picked", 'Decode speed': 3.570803165435791, 'Backtrace speed': 0.0003077983856201172, 'Forward computations': 163728}
# 3.0368497371673584
# 0.00022459030151367188
# ...
# 4.443538427352905
# 0.0003235340118408203
# {'Filename': '0199.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 7, 'WER': 0.7647058823529411, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a of of peppers picked of peck of pickled peppers where's picked of peck of pickled peck picked a the peck peck picked", 'Decode speed': 4.443538427352905, 'Backtrace speed': 0.0003235340118408203, 'Forward computations': 203408}
# 4.465100526809692
# 0.00032138824462890625
# {'Filename': '0200.wav', 'Insertions': 5, 'Deletions': 1, 'Substitutions': 9, 'WER': 0.8823529411764706, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "the of the of of picked peck peck pickled peck where's where's piper peck of picked peck picked picked peck picked", 'Decode speed': 4.465100526809692, 'Backtrace speed': 0.00032138824462890625, 'Forward computations': 203408}
# 4.1161723136901855
# 0.0009455680847167969
# {'Filename': '0201.wav', 'Insertions': 2, 'Deletions': 3, 'Substitutions': 4, 'WER': 0.5294117647058824, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': 'a pickled peck picked pickled picked peppers picked of peck of pickled peppers peter peck picked', 'Decode speed': 4.1161723136901855, 'Backtrace speed': 0.0009455680847167969, 'Forward computations': 187288}
# 3.113295316696167
# 0.00017976760864257812
# {'Filename': '0202.wav', 'Insertions': 1, 'Deletions': 2, 'Substitutions': 0, 'WER': 0.3, 'Word Count': 10, 'transcription': 'peppers picked a peck of peter a pickled peter piper', 'Viterbi transcription': 'a peppers picked peck of peter pickled peter piper', 'Decode speed': 3.113295316696167, 'Backtrace speed': 0.00017976760864257812, 'Forward computations': 142338}
# 4.73361611366272
# 0.0003552436828613281
# {'Filename': '0203.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.11764705882352941, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter piper picked peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Decode speed': 4.73361611366272, 'Backtrace speed': 0.0003552436828613281, 'Forward computations': 216428}
# 2.838679075241089
# 0.00016355514526367188
# {'Filename': '0204.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': 'peck of pickled peppers peter piper picked', 'Viterbi transcription': 'a peck of pickled peppers peter piper picked', 'Decode speed': 2.838679075241089, 'Backtrace speed': 0.00016355514526367188, 'Forward computations': 129318}
# 2.615156888961792
# 0.00016880035400390625
# {'Filename': '0205.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': 'peter piper peck peppers picked peter peppers', 'Viterbi transcription': 'a peter piper peck peppers picked peter peppers', 'Decode speed': 2.615156888961792, 'Backtrace speed': 0.00016880035400390625, 'Forward computations': 121258}
# 2.762787103652954
# 0.00015687942504882812
# {'Filename': '0206.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 8, 'transcription': 'pickled peter piper a peck the peppers picked', 'Viterbi transcription': 'a pickled peter piper peck the peppers picked', 'Decode speed': 2.762787103652954, 'Backtrace speed': 0.00015687942504882812, 'Forward computations': 126528}
# 2.620579957962036
# 0.0002961158752441406
# {'Filename': '0207.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a peter of piper picked of peck of pickled where's", 'Decode speed': 2.620579957962036, 'Backtrace speed': 0.0002961158752441406, 'Forward computations': 121258}
# 2.75909161567688
# 0.00015616416931152344
# {'Filename': '0208.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.7777777777777778, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's of of of picked peppers picked of of picked", 'Decode speed': 2.75909161567688, 'Backtrace speed': 0.00015616416931152344, 'Forward computations': 126528}
# 2.5965652465820312
# 0.0001373291015625
# {'Filename': '0209.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': "peter picked piper where's the peck", 'Viterbi transcription': "a peter picked piper where's of peck", 'Decode speed': 2.5965652465820312, 'Backtrace speed': 0.0001373291015625, 'Forward computations': 118778}
# 2.104926347732544
# 0.00011730194091796875
# {'Filename': '0210.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 6, 'WER': 1.125, 'Word Count': 8, 'transcription': "pickled peter the peppers a piper where's picked", 'Viterbi transcription': "a a of picked of of of where's of where's picked", 'Decode speed': 2.104926347732544, 'Backtrace speed': 0.00011730194091796875, 'Forward computations': 97388}
# 2.62371563911438
# 0.0001480579376220703
# {'Filename': '0211.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': "piper pickled peppers where's a peter picked a peck", 'Viterbi transcription': "a piper of peppers where's of peter picked peck", 'Decode speed': 2.62371563911438, 'Backtrace speed': 0.0001480579376220703, 'Forward computations': 118778}
# 6.4457738399505615
# 0.0005586147308349609
# {'Filename': '0212.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 7, 'WER': 0.5882352941176471, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter piper of a peck of pickled peppers where's of pickled pickled peck where's the of peter of a", 'Decode speed': 6.4457738399505615, 'Backtrace speed': 0.0005586147308349609, 'Forward computations': 293308}
# 6.327200412750244
# 0.0007555484771728516
# {'Filename': '0213.wav', 'Insertions': 3, 'Deletions': 2, 'Substitutions': 8, 'WER': 0.8125, 'Word Count': 16, 'transcription': 'the peck of pickled peppers peter piper picked peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a a pickled pickled peck where's the of piper a pickled piper picked peck pickled peck where's", 'Decode speed': 6.327200412750244, 'Backtrace speed': 0.0007555484771728516, 'Forward computations': 288038}
# 7.8638951778411865
# 0.0007336139678955078
# {'Filename': '0214.wav', 'Insertions': 2, 'Deletions': 2, 'Substitutions': 6, 'WER': 0.7142857142857143, 'Word Count': 14, 'transcription': "a peck of pickled peppers peter piper picked where's the peck of pickled peppers", 'Viterbi transcription': "a where's pickled pickled where's picked of piper of a where's of pickled where's", 'Decode speed': 7.8638951778411865, 'Backtrace speed': 0.0007336139678955078, 'Forward computations': 359338}
# 7.826870918273926
# 0.0019614696502685547
# {'Filename': '0215.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 9, 'WER': 1.0, 'Word Count': 16, 'transcription': "a peck of pickled peppers picked peter piper where's peter piper peck of pickled peppers picked", 'Viterbi transcription': "a pickled a of of the pickled where's the of piper where's where's the of peter picked of peck pickled peck where's a", 'Decode speed': 7.826870918273926, 'Backtrace speed': 0.0019614696502685547, 'Forward computations': 354068}
# 8.480810165405273
# 0.0010266304016113281
# {'Filename': '0216.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 9, 'WER': 0.75, 'Word Count': 16, 'transcription': "a peck of peppers pickled picked peter piper where's peter piper peppers pickled the peck picked", 'Viterbi transcription': "a pickled a picked a where's pickled the of piper where's peter where's pickled of piper a", 'Decode speed': 8.480810165405273, 'Backtrace speed': 0.0010266304016113281, 'Forward computations': 383208}
# 5.521463871002197
# 0.0007226467132568359
# {'Filename': '0217.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.2727272727272727, 'Word Count': 11, 'transcription': "peter where's a peter picked of piper piper peck pickled picked", 'Viterbi transcription': "a pickled where's of peter picked of piper piper peck pickled picked", 'Decode speed': 5.521463871002197, 'Backtrace speed': 0.0007226467132568359, 'Forward computations': 250838}
# 4.229861497879028
# 0.0005466938018798828
# {'Filename': '0218.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'pickled peter pickled of peck', 'Viterbi transcription': 'a pickled peter pickled of peck', 'Decode speed': 4.229861497879028, 'Backtrace speed': 0.0005466938018798828, 'Forward computations': 192558}
# 5.853121042251587
# 0.0004775524139404297
# {'Filename': '0219.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.5, 'Word Count': 12, 'transcription': 'peppers peppers piper the peck peter picked pickled of pickled piper picked', 'Viterbi transcription': "a where's of where's piper the of peck peter picked pickled of picked piper picked", 'Decode speed': 5.853121042251587, 'Backtrace speed': 0.0004775524139404297, 'Forward computations': 266648}
# 3.131300926208496
# 0.00023651123046875
# {'Filename': '0220.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5555555555555556, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's the of peck of pickled peter peter of piper of picked", 'Decode speed': 3.131300926208496, 'Backtrace speed': 0.00023651123046875, 'Forward computations': 142338}
# 6.830211639404297
# 0.0006871223449707031
# {'Filename': '0221.wav', 'Insertions': 5, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "peck a piper pickled peter of of the peck peter picked piper where's peppers pickled peppers picked", 'Viterbi transcription': "a peck of piper pickled peter of pickled of peck peter peck picked piper where's of where's the pickled peppers picked", 'Decode speed': 6.830211639404297, 'Backtrace speed': 0.0006871223449707031, 'Forward computations': 309118}
# 1.9431843757629395
# 0.00011467933654785156
# {'Filename': '0222.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 6, 'transcription': 'peppers of piper pickled the peter', 'Viterbi transcription': "a where's of piper pickled peter", 'Decode speed': 1.9431843757629395, 'Backtrace speed': 0.00011467933654785156, 'Forward computations': 89638}
# 2.1099772453308105
# 0.00012946128845214844
# {'Filename': '0223.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': "piper picked peter pickled where's the peppers", 'Viterbi transcription': "a piper picked peter pickled where's the peppers", 'Decode speed': 2.1099772453308105, 'Backtrace speed': 0.00012946128845214844, 'Forward computations': 97388}
# 1.5925617218017578
# 9.894371032714844e-05
# {'Filename': '0224.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.16666666666666666, 'Word Count': 6, 'transcription': 'the peck of piper peter picked', 'Viterbi transcription': 'a the peck of piper peter picked', 'Decode speed': 1.5925617218017578, 'Backtrace speed': 9.894371032714844e-05, 'Forward computations': 73518}
# 2.268439769744873
# 0.0001418590545654297
# {'Filename': '0225.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': 'piper peter peter piper picked the peppers', 'Viterbi transcription': 'a piper peter peter piper picked the peppers', 'Decode speed': 2.268439769744873, 'Backtrace speed': 0.0001418590545654297, 'Forward computations': 102658}
# 1.980825424194336
# 0.00014400482177734375
# {'Filename': '0226.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 6, 'transcription': "where's the piper of peck peter", 'Viterbi transcription': "a where's peppers of peck peter", 'Decode speed': 1.980825424194336, 'Backtrace speed': 0.00014400482177734375, 'Forward computations': 89638}
# 2.2668163776397705
# 0.00013780593872070312
# {'Filename': '0227.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8571428571428571, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': "a the of picked the peck of picked where's", 'Decode speed': 2.2668163776397705, 'Backtrace speed': 0.00013780593872070312, 'Forward computations': 102658}
# 2.0339438915252686
# 0.0001227855682373047
# {'Filename': '0228.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': 'peter piper picked a peck of peppers', 'Viterbi transcription': 'a the of piper the the peck of peppers', 'Decode speed': 2.0339438915252686, 'Backtrace speed': 0.0001227855682373047, 'Forward computations': 92118}
# 1.972242832183838
# 0.00010967254638671875
# {'Filename': '0229.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.2, 'Word Count': 5, 'transcription': "where's the peppers peter picked", 'Viterbi transcription': "a where's picked of where's picked of picked", 'Decode speed': 1.972242832183838, 'Backtrace speed': 0.00010967254638671875, 'Forward computations': 89638}
# 1.9114036560058594
# 0.0001437664031982422
# {'Filename': '0230.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.0, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's picked peck of the the peck where's", 'Decode speed': 1.9114036560058594, 'Backtrace speed': 0.0001437664031982422, 'Forward computations': 86848}
# 2.295311689376831
# 0.00015783309936523438
# {'Filename': '0231.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.0, 'Word Count': 7, 'transcription': "where's the pickled peppers peter piper picked", 'Viterbi transcription': "a where's the the of peppers picked of piper of the", 'Decode speed': 2.295311689376831, 'Backtrace speed': 0.00015783309936523438, 'Forward computations': 105448}
# 4.384667873382568
# 0.0005083084106445312
# {'Filename': '0232.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.23529411764705882, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter of piper peck of peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Decode speed': 4.384667873382568, 'Backtrace speed': 0.0005083084106445312, 'Forward computations': 198138}
# 4.919937372207642
# 0.0004928112030029297
# {'Filename': '0233.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.29411764705882354, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a a where's piper peck of peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Decode speed': 4.919937372207642, 'Backtrace speed': 0.0004928112030029297, 'Forward computations': 224488}
# 3.253070592880249
# 0.0002627372741699219
# {'Filename': '0234.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 6, 'transcription': 'peter peter peter peter piper peter', 'Viterbi transcription': 'a peter of peter peter peter piper peter of', 'Decode speed': 3.253070592880249, 'Backtrace speed': 0.0002627372741699219, 'Forward computations': 147608}

# %%
#task 3 pruning

#attempt using beam search
"""
what is beam search?




"""
class PrunedViterbiDecoder:
    
    
    NLL_ZERO = 1e10# define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    
    def __init__(self, f, audio_file_name,beam=30, beam_type = "size"):
        """Set up the decoder class with an audio file and WFST f
        """
        self.NLL_ZERO = 1e10
        self.om = observation_model.ObservationModel()
        self.f = f
        self.beam = beam
        self.beam_type = beam_type
        if beam_type != "size" and beam_type != "width":
            raise Exception("beam_type must be of size or width")
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
        
        forward_computations = 0
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                for arc in self.f.arcs(i):
                    
                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        forward_computations += 1
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            self.V[t][j] = prob
                            self.B[t][j] = i
                            
                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
                                
        if self.beam_type == "width":
            minimum_state_value = min(self.V[t])
            print(minimum_state_value)
            for j in range(self.f.num_states()):
                if self.V[t][j] > -math.log(self.beam) + minimum_state_value:
                    self.V[t][j] = self.NLL_ZERO 
            print(minimum_state_value)
        
        if self.beam_type == "size": 
            sorted_values = sorted(self.V[t])
            beam = min(self.beam, len(self.V[t]))
            threshold = sorted_values[self.beam - 1]
            for j in range(f.num_states()):
                if self.V[t][j] > threshold:
                    self.V[t][j] = self.NLL_ZERO 
        
                                
        return forward_computations
                            
    
    def finalise_decoding(self):
        """ this incorporates the probability of terminating at each state
        """
        
        for state in self.f.states():
            final_weight = float(self.f.final(state))
            if self.V[-1][state] != self.NLL_ZERO:
                if final_weight == math.inf:
                    self.V[-1][state] = self.NLL_ZERO  # effectively says that we can't end in this state
                else:
                    self.V[-1][state] += final_weight
                    
        # get a list of all states where there was a path ending with non-zero probability
        finished = [x for x in self.V[-1] if x < self.NLL_ZERO]
        if not finished:  # if empty
            print("No path got to the end of the observations.")
        
        
    def decode(self):
        forward_computations = 0
        initial = time.time()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            forward_computations += self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            t += 1
        self.finalise_decoding()
        final=time.time()
        return (forward_computations, (final - initial))
    
    def backtrace(self):
        
        initial = time.time()
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        
        
        final = time.time()
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence =' '.join([ self.f.output_symbols().find(label) for label in best_out_sequence])
        
        return (best_state_sequence, best_out_sequence,(final-initial))

# %%
f=create_wfst(3)
draw_fst(f)

# %%
#TASK 2, changing self-loop probabilities


# print(num_states(f))
# print(total_num_arcs(f))
# f=create_wfst_silent(3,probabilities,next_state_prob=0.1,sil_prob=0.5)
# results_df=[]
# for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'): 
#     break# replace path if using your own
#                                                                       # audio files
#     decoder = PrunedViterbiDecoder(f, wav_file,beam=50,beam_type="size")
    
#     forward_computations, decode_speed = decoder.decode()
#     print(decode_speed)
#     (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
#     # to return the words along the best path
#     print(backtrace_speed)
    
#     transcription = read_transcription(wav_file)
    
#     word_count = len(transcription.split())
    



    
#     error_counts = wer.compute_alignment_errors(transcription, words)
#     word_count = len(transcription.split())
#     worderror = sum(error_counts)/word_count
#          # you'll need to accumulate these to produce an overall Word Error Rate
#     filename = wav_file.split('/')[-1]
#     row = {
#         'Filename': filename,
#         'Insertions': error_counts[2],
#         'Deletions': error_counts[1],
#         'Substitutions': error_counts[0],
#         'WER': worderror,
#         'Word Count': word_count,
#         'transcription':transcription,
#         'Viterbi transcription':words,
#         'Decode speed': decode_speed,
#         'Backtrace speed': backtrace_speed,
#         'Forward computations': forward_computations
#     }
#     print(row)
    
    
#     # Append results to the DataFrame
#     results_df.append(row)
    
    
# results_df = pd.DataFrame(results_df)
# # Save the DataFrame to a CSV file
# # results_df.to_csv('result_pruned_size_50.csv')

# %%
#task 4
#Bigram Probabilities

from collections import defaultdict
bigram_count=defaultdict(int)
word_count = defaultdict(int)


for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    transcription = read_transcription(wav_file)
    transcription = "<s> "+ str(transcription)+" </s>"
    transcription = transcription.split(" ")
    for i in range(0,len(transcription)-1):
        bigram = transcription[i]+ " "+transcription[i+1]
        bigram_count[bigram]+=1
        word_count[transcription[i]]+=1
bigram_prob = {}

for bigram in bigram_count.keys():
    word = bigram.split()[0]

    bigram_prob[bigram]= bigram_count[bigram] / word_count[word]
bigram_prob

# probabilities ={bigram:count/total_words for word,count in word_count.items()}
# print(word_count,bigram_probabilities)
# Out:
# {'<s> peter': 0.3677811550151976,
#  'peter piper': 0.5384615384615384,
#  'piper picked': 0.5501730103806228,
#  'picked a': 0.2972027972027972,
#  'a peck': 0.7608695652173914,
#  'peck of': 0.7083333333333334,
#  'of pickled': 0.6219512195121951,
#  'pickled peppers': 0.6947368421052632,
#  "peppers where's": 0.09968847352024922,
#  "where's the": 0.6864406779661016,
#  'the peck': 0.6861313868613139,
#  'peppers peter': 0.24922118380062305,
#  'picked </s>': 0.34265734265734266,
#  'peter picked': 0.17751479289940827,
#  'peppers </s>': 0.3707165109034268,
#  '<s> a': 0.07598784194528875,
#  'peppers picked': 0.07476635514018691,
#  'piper peter': 0.0657439446366782,
#  'piper </s>': 0.12802768166089964,
#  "<s> where's": 0.1762917933130699,
#  'piper pickled': 0.07958477508650519,
#  "where's peter": 0.1440677966101695,
#  'peter </s>': 0.08284023668639054,
#  '<s> piper': 0.1033434650455927,
#  'picked peppers': 0.09090909090909091,
#  'peppers of': 0.056074766355140186,
#  'of peter': 0.04878048780487805,
#  'peter peppers': 0.04142011834319527,
#  'picked piper': 0.045454545454545456,
#  'piper of': 0.04152249134948097,
#  'of peck': 0.044715447154471545,
#  'peck </s>': 0.07954545454545454,
#  'pickled </s>': 0.06666666666666667,
#  '<s> picked': 0.030395136778115502,
#  '<s> pickled': 0.0851063829787234,
#  '<s> peppers': 0.0364741641337386,
#  'picked peter': 0.08041958041958042,
#  "piper where's": 0.031141868512110725,
#  'peck piper': 0.01893939393939394,
#  'piper piper': 0.01384083044982699,
#  'peter peter': 0.05029585798816568,
#  'piper peppers': 0.02768166089965398,
#  'of </s>': 0.02032520325203252,
#  '<s> of': 0.0121580547112462,
#  'of peppers': 0.11788617886178862,
#  'of picked': 0.032520325203252036,
#  'a peter': 0.07971014492753623,
#  "where's a": 0.0423728813559322,
#  'picked the': 0.03496503496503497,
#  'the peppers': 0.10948905109489052,
#  'peck peter': 0.045454545454545456,
#  'peppers piper': 0.04672897196261682,
#  'peppers pickled': 0.04672897196261682,
#  'pickled peter': 0.08421052631578947,
#  'peter of': 0.026627218934911243,
#  'of the': 0.044715447154471545,
#  'the piper': 0.043795620437956206,
#  'piper peck': 0.031141868512110725,
#  "picked where's": 0.017482517482517484,
#  'the pickled': 0.10948905109489052,
#  '<s> peck': 0.060790273556231005,
#  'peck pickled': 0.041666666666666664,
#  'pickled piper': 0.031578947368421054,
#  'the peter': 0.014598540145985401,
#  'picked pickled': 0.06293706293706294,
#  'pickled peck': 0.017543859649122806,
#  'of piper': 0.04065040650406504,
#  '<s> the': 0.05167173252279635,
#  'peter the': 0.008875739644970414,
#  'peter pickled': 0.03550295857988166,
#  'pickled picked': 0.031578947368421054,
#  'peck peppers': 0.03409090909090909,
#  "pickled where's": 0.007017543859649123,
#  "where's peck": 0.025423728813559324,
#  'peck peck': 0.003787878787878788,
#  'pickled a': 0.021052631578947368,
#  'a pickled': 0.043478260869565216,
#  'peppers peppers': 0.018691588785046728,
#  'pickled pickled': 0.007017543859649123,
#  'a picked': 0.028985507246376812,
#  'peter a': 0.011834319526627219,
#  'peck picked': 0.026515151515151516,
#  'peppers peck': 0.028037383177570093,
#  "where's of": 0.01694915254237288,
#  "peter where's": 0.014792899408284023,
#  "where's piper": 0.025423728813559324,
#  'piper the': 0.01384083044982699,
#  'the picked': 0.021897810218978103,
#  'picked picked': 0.0034965034965034965,
#  'pickled of': 0.021052631578947368,
#  'a of': 0.007246376811594203,
#  'picked peck': 0.01048951048951049,
#  'piper a': 0.01730103806228374,
#  "a where's": 0.007246376811594203,
#  "where's </s>": 0.01694915254237288,
#  'picked of': 0.013986013986013986,
#  "of where's": 0.012195121951219513,
#  'a peppers': 0.014492753623188406,
#  'a piper': 0.057971014492753624,
#  'of a': 0.008130081300813009,
#  "where's pickled": 0.01694915254237288,
#  "peck where's": 0.011363636363636364,
#  'peter peck': 0.011834319526627219,
#  'the of': 0.0072992700729927005,
#  'pickled the': 0.017543859649122806,
#  'peck the': 0.01893939393939394,
#  'the a': 0.0072992700729927005,
#  'of of': 0.008130081300813009,
#  "where's peppers": 0.01694915254237288,
#  'peppers a': 0.006230529595015576,
#  "where's picked": 0.00847457627118644,
#  'peck a': 0.011363636363636364,
#  'peppers the': 0.003115264797507788}

# %%
#task 4 reducing the number of states in wfst by having silence be connected for all
def create_wfst_silent_2(n, probabilities=None, next_state_prob=0.5, sil_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs."""
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))


    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    
    this_state = f.add_state()
    first_sil = this_state
    for i in range(1,6):
        weight = fst.Weight('log',-math.log(1-next_state_prob))
        
        f.add_arc(this_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0, weight, this_state))
        next_state= f.add_state()
        weight = fst.Weight('log',-math.log(next_state_prob))
        f.add_arc(this_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
        this_state=next_state
    
    weight = fst.Weight('log',-math.log(1))
    f.add_arc(this_state,fst.Arc(0,0, weight, start_state))

    
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            last_state = current_state
            current_state = generate_phone_wfst(f, current_state, phone, n, 0.5)
            
        weight = fst.Weight('log',-math.log(1-sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,start_state))
        weight = fst.Weight('log',-math.log(sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,first_sil))
        
        

        

            
            
            

    f.set_input_symbols(silent_state_table)
    f.set_output_symbols(word_table)


    return f

    
f=create_wfst_silent_2(3)
draw_fst(f)

# %%
print(num_states(f))
print(total_num_arcs(f))
f=create_wfst_silent(3,probabilities,next_state_prob=0.1,sil_prob=0.5)
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                                                                  # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_silent_new.csv')
# Out:
# 122
# 251

# %%
#task 4 tree structure diagrams
def generate_phone_wfst_tree(f, start_state, phone, n, next_state_prob=0.5, sil_prob=0.5):
    """
    Generate a WFST representing an n-state left-to-right phone HMM.
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assumed to exist already
        phone (str): the phone label 
        n (int): number of states of the HMM excluding start and end
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
    
        in_label = state_table.find('{}_{}'.format(phone, i))
        sl_weight = fst.Weight('log', -math.log(1-next_state_prob))
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, sl_weight, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        
        out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        next_weight = fst.Weight('log', -math.log(next_state_prob))
        f.add_arc(current_state, fst.Arc(in_label, out_label, next_weight, next_state))    
       
        current_state = next_state
    return current_state


def generate_tree_wfst(lex,sil_prob=0.5,next_state_prob=0.5):
    """Express the  in WFST form.

    Args:
        lex (dict): lexicon to use, created from the parse_lexicon() function.
    
    Returns:
        the constructed lexicon WFST.
    """
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))

    L = fst.Fst('log')
    
    # Create a single start state
    start_state = L.add_state()
    L.set_start(start_state)
    L.set_final(start_state)
    
    # Dictionary to check if an arc already exists (current_state, phone) -> next_state
    state_transitions = {}
    
    for word, pron in lex.items():
        
        
        current_state = start_state
        for i, phone in enumerate(pron):
            # Check if this (state, phone) pair has an existing next state
            if (current_state, phone) in state_transitions:
                next_state = state_transitions[(current_state, phone)]
            else:
                next_state= L.add_state()
                L.add_arc(current_state, fst.Arc(0,0, fst.Weight('log',-math.log(1)), next_state))
                c_state=next_state
                
                next_state = generate_phone_wfst_tree(L, c_state, phone, 3)
                state_transitions[(current_state, phone)] = next_state
                
                
            
            current_state = next_state
                          
        
        L.add_arc(current_state, fst.Arc(0,word_table.find(word) , fst.Weight('log',-math.log(1)), start_state))  
        weight = fst.Weight('log',-math.log(sil_prob*(1)))
         
        L.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'),0,weight,current_state))
        next_state =L.add_state()
        weight = fst.Weight('log',-math.log(sil_prob*((1))))
        L.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'),0,weight,next_state))
        current_state=next_state
        
        
        for i in range(2,6):
            weight = fst.Weight('log',-math.log(1))
            L.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
            next_state =L.add_state()
            weight = fst.Weight('log',-math.log(1))
            L.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
            current_state=next_state
        print(word, word_table.find(word))

            
            
            
            
            
        
        
        
        next_weight = fst.Weight('log', -math.log(1))
        L.add_arc(current_state, fst.Arc(0, word_table.find(word),next_weight , start_state))
        
        
        
        
    L.set_input_symbols(silent_state_table)
    L.set_output_symbols(word_table)                      
    
    return L

L = generate_tree_wfst(lex)
L.arcsort()

def generate_probability_tree(lex, probabilities):
    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(out_label, 0,start_weight , current_state))
        
        
        # note: new current_state is now set to the final state of the previous phone WFST
        
        next_weight = fst.Weight('log', -math.log(1))
        
        f.add_arc(current_state, fst.Arc(0, 0,next_weight , start_state))

    f.set_input_symbols(word_table)
    f.set_output_symbols(word_table)

    return f



d = generate_probability_tree(lex,probabilities)
draw_fst(d)
# Out:
# a 1
# of 2
# peck 3
# peppers 4
# peter 5
# picked 6
# pickled 7
# piper 8
# the 9
# where's 10

# %%
#u=fst.compose(L,d)
draw_fst(f)

# %%
draw_fst(L)

# %%
Ldet = fst.determinize(L)
draw_fst(Ldet)

# %%
f=create_wfst(3)
print(lex)
# Out:
# {'a': ['ey'], 'of': ['ah', 'v'], 'peck': ['p', 'eh', 'k'], 'peppers': ['p', 'eh', 'p', 'er', 'z'], 'peter': ['p', 'iy', 't', 'er'], 'picked': ['p', 'ih', 'k', 't'], 'pickled': ['p', 'ih', 'k', 'ah', 'l', 'd'], 'piper': ['p', 'ay', 'p', 'er'], 'the': ['dh', 'iy'], "where's": ['w', 'eh', 'r', 'z']}

# %%
print(num_states(f))
print(total_num_arcs(f))
L=generate_tree_wfst(lex)
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                      # audio files
    decoder = PrunedViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_tree.csv')
# Out:
# 116
# 230
# a 1
# of 2
# peck 3
# peppers 4
# peter 5
# picked 6
# pickled 7
# piper 8
# the 9
# where's 10
# 1.9456264972686768
# 0.0012030601501464844
# {'Filename': '0000.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.23529411764705882, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "where's the peter piper picked the peck of pickled peppers where's the peck of pickled peppers peter piper picked the", 'Decode speed': 1.9456264972686768, 'Backtrace speed': 0.0012030601501464844, 'Forward computations': 72038}
# 1.0780696868896484
# 0.0010709762573242188
# {'Filename': '0001.wav', 'Insertions': 8, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.4285714285714286, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': "where's the a the the peter picked the of peck of pickled peck where's the", 'Decode speed': 1.0780696868896484, 'Backtrace speed': 0.0010709762573242188, 'Forward computations': 41046}
# 0.8450534343719482
# 0.0003197193145751953
# {'Filename': '0002.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'a peck of pickled peppers picked', 'Viterbi transcription': "where's the peck of pickled of of picked the", 'Decode speed': 0.8450534343719482, 'Backtrace speed': 0.0003197193145751953, 'Forward computations': 31336}
# 0.6232833862304688
# 0.0001971721649169922
# {'Filename': '0003.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.25, 'Word Count': 4, 'transcription': 'peter piper peter piper', 'Viterbi transcription': "where's the picked piper picked piper the", 'Decode speed': 0.6232833862304688, 'Backtrace speed': 0.0001971721649169922, 'Forward computations': 23078}
# 0.8351001739501953
# 0.0010099411010742188
# {'Filename': '0004.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': "where's the peck of pickled peppers picked", 'Viterbi transcription': "where's the where's the pickled pickled peppers picked the", 'Decode speed': 0.8351001739501953, 'Backtrace speed': 0.0010099411010742188, 'Forward computations': 30076}
# 0.44461727142333984
# 0.0002422332763671875
# {'Filename': '0005.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peter piper pickled peppers', 'Viterbi transcription': 'peter piper pickled peppers the', 'Decode speed': 0.44461727142333984, 'Backtrace speed': 0.0002422332763671875, 'Forward computations': 17924}
# 0.32992982864379883
# 0.00016307830810546875
# {'Filename': '0006.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 2, 'transcription': "where's peter", 'Viterbi transcription': "where's peter the", 'Decode speed': 0.32992982864379883, 'Backtrace speed': 0.00016307830810546875, 'Forward computations': 11012}
# 0.5183799266815186
# 0.0002701282501220703
# {'Filename': '0007.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': 'piper picked peppers of peter', 'Viterbi transcription': 'the picked peppers of peter the', 'Decode speed': 0.5183799266815186, 'Backtrace speed': 0.0002701282501220703, 'Forward computations': 18172}
# 0.5835750102996826
# 0.0002751350402832031
# {'Filename': '0008.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.16666666666666666, 'Word Count': 6, 'transcription': 'peter peppers picked piper of peck', 'Viterbi transcription': 'peter peppers picked piper of peck the', 'Decode speed': 0.5835750102996826, 'Backtrace speed': 0.0002751350402832031, 'Forward computations': 20184}
# 0.7117278575897217
# 0.000396728515625
# {'Filename': '0009.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'a peck of pickled peppers peter piper pickled', 'Viterbi transcription': 'picked peck picked peppers peter piper pickled the', 'Decode speed': 0.7117278575897217, 'Backtrace speed': 0.000396728515625, 'Forward computations': 25902}
# 0.3021118640899658
# 0.00016617774963378906
# {'Filename': '0010.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'picked', 'Viterbi transcription': 'the picked', 'Decode speed': 0.3021118640899658, 'Backtrace speed': 0.00016617774963378906, 'Forward computations': 11548}
# 0.2460317611694336
# 0.00013065338134765625
# {'Filename': '0011.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 4.0, 'Word Count': 1, 'transcription': 'pickled', 'Viterbi transcription': 'the a of the', 'Decode speed': 0.2460317611694336, 'Backtrace speed': 0.00013065338134765625, 'Forward computations': 9962}
# 0.4137449264526367
# 8.249282836914062e-05
# {'Filename': '0012.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 4.0, 'Word Count': 1, 'transcription': 'peppers', 'Viterbi transcription': 'the peter the the', 'Decode speed': 0.4137449264526367, 'Backtrace speed': 8.249282836914062e-05, 'Forward computations': 17122}
# 0.4154064655303955
# 0.00010919570922851562
# {'Filename': '0013.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 2.0, 'Word Count': 1, 'transcription': 'piper', 'Viterbi transcription': 'the piper the', 'Decode speed': 0.4154064655303955, 'Backtrace speed': 0.00010919570922851562, 'Forward computations': 15456}
# 0.33504271507263184
# 0.00011396408081054688
# {'Filename': '0014.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 2.0, 'Word Count': 1, 'transcription': 'peter', 'Viterbi transcription': 'the peter the', 'Decode speed': 0.33504271507263184, 'Backtrace speed': 0.00011396408081054688, 'Forward computations': 13768}
# 0.6111485958099365
# 0.0001728534698486328
# {'Filename': '0015.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "the where's the peck the of the pickled peck picked the", 'Decode speed': 0.6111485958099365, 'Backtrace speed': 0.0001728534698486328, 'Forward computations': 25168}
# 0.3762838840484619
# 7.915496826171875e-05
# {'Filename': '0016.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'the peter piper the picked the', 'Decode speed': 0.3762838840484619, 'Backtrace speed': 7.915496826171875e-05, 'Forward computations': 15810}
# 0.8567571640014648
# 0.0003807544708251953
# {'Filename': '0017.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'the peter piper picked of peck of pickled of picked the', 'Decode speed': 0.8567571640014648, 'Backtrace speed': 0.0003807544708251953, 'Forward computations': 34758}
# 0.4370908737182617
# 0.00020623207092285156
# {'Filename': '0018.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'picked a peck of pickled peppers', 'Viterbi transcription': "the picked the peck of pickled peck where's the", 'Decode speed': 0.4370908737182617, 'Backtrace speed': 0.00020623207092285156, 'Forward computations': 17780}
# 0.767308235168457
# 0.00020432472229003906
# {'Filename': '0019.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'the peter piper the a picked the', 'Decode speed': 0.767308235168457, 'Backtrace speed': 0.00020432472229003906, 'Forward computations': 31016}
# 1.0862741470336914
# 0.0005409717559814453
# {'Filename': '0020.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 7, 'transcription': "peppers picked peter piper where's the peck", 'Viterbi transcription': "the peppers picked the picked piper the a picked where's the peck the", 'Decode speed': 1.0862741470336914, 'Backtrace speed': 0.0005409717559814453, 'Forward computations': 42752}
# 1.5398573875427246
# 0.0005660057067871094
# {'Filename': '0021.wav', 'Insertions': 10, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.4, 'Word Count': 10, 'transcription': 'peter picked a peck piper pickled peppers of pickled peppers', 'Viterbi transcription': "the peter where's picked of peck the piper the of pickled the of picked of the picked peck picked the", 'Decode speed': 1.5398573875427246, 'Backtrace speed': 0.0005660057067871094, 'Forward computations': 60882}
# 1.147613286972046
# 0.000982522964477539
# {'Filename': '0022.wav', 'Insertions': 8, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.125, 'Word Count': 8, 'transcription': 'peter piper piper peter peter peter piper piper', 'Viterbi transcription': "the where's piper the of piper the peter peter peter of piper the of piper the", 'Decode speed': 1.147613286972046, 'Backtrace speed': 0.000982522964477539, 'Forward computations': 45698}
# 0.7343592643737793
# 0.0004012584686279297
# {'Filename': '0023.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 4, 'transcription': 'peter picked piper peppers', 'Viterbi transcription': 'the the of picked piper peppers the', 'Decode speed': 0.7343592643737793, 'Backtrace speed': 0.0004012584686279297, 'Forward computations': 29548}
# 0.8218960762023926
# 0.00034499168395996094
# {'Filename': '0024.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'peter peter peter peter peter peter', 'Viterbi transcription': 'the peter peter the peter peter peter peter a the', 'Decode speed': 0.8218960762023926, 'Backtrace speed': 0.00034499168395996094, 'Forward computations': 32962}
# No path got to the end of the observations.
# 1.0034513473510742
# 0.00045228004455566406
# {'Filename': '0025.wav', 'Insertions': 0, 'Deletions': 7, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 7, 'transcription': 'piper picked a peck of peter peppers', 'Viterbi transcription': '', 'Decode speed': 1.0034513473510742, 'Backtrace speed': 0.00045228004455566406, 'Forward computations': 34114}
# 0.9825334548950195
# 0.0004901885986328125
# {'Filename': '0026.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.125, 'Word Count': 8, 'transcription': 'pickled peppers peter piper picked a peck of', 'Viterbi transcription': 'a the pickled of picked piper picked picked the peck of the picked the', 'Decode speed': 0.9825334548950195, 'Backtrace speed': 0.0004901885986328125, 'Forward computations': 34048}
# 1.3546409606933594
# 0.001953125
# {'Filename': '0027.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 8, 'transcription': 'of peppers of picked a peter piper of', 'Viterbi transcription': 'the of of picked of picked of peter piper of the picked', 'Decode speed': 1.3546409606933594, 'Backtrace speed': 0.001953125, 'Forward computations': 40120}
# 0.653449535369873
# 0.0003581047058105469
# {'Filename': '0028.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.8, 'Word Count': 5, 'transcription': 'pickled peppers peter piper picked', 'Viterbi transcription': 'the pickled of of the picked of piper of peck the', 'Decode speed': 0.653449535369873, 'Backtrace speed': 0.0003581047058105469, 'Forward computations': 25732}
# 0.6567144393920898
# 0.00030231475830078125
# {'Filename': '0029.wav', 'Insertions': 7, 'Deletions': 1, 'Substitutions': 1, 'WER': 1.2857142857142858, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': 'picked the a of peck of of of pickled peck of picked the', 'Decode speed': 0.6567144393920898, 'Backtrace speed': 0.00030231475830078125, 'Forward computations': 26294}
# 0.6812248229980469
# 0.00022983551025390625
# {'Filename': '0030.wav', 'Insertions': 3, 'Deletions': 2, 'Substitutions': 2, 'WER': 0.7777777777777778, 'Word Count': 9, 'transcription': "where's a peck of pickled peppers peter piper picked", 'Viterbi transcription': "the where's peck pickled of of peter piper peck the", 'Decode speed': 0.6812248229980469, 'Backtrace speed': 0.00022983551025390625, 'Forward computations': 27602}
# 0.428882360458374
# 0.00012683868408203125
# {'Filename': '0031.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.2, 'Word Count': 5, 'transcription': 'peter piper picked the peppers', 'Viterbi transcription': 'the picked piper of picked of of the', 'Decode speed': 0.428882360458374, 'Backtrace speed': 0.00012683868408203125, 'Forward computations': 16580}
# 0.5791747570037842
# 0.00026726722717285156
# {'Filename': '0032.wav', 'Insertions': 6, 'Deletions': 1, 'Substitutions': 1, 'WER': 1.6, 'Word Count': 5, 'transcription': 'pickled peppers picked peter piper', 'Viterbi transcription': 'the peck of the peppers a picked piper of picked', 'Decode speed': 0.5791747570037842, 'Backtrace speed': 0.00026726722717285156, 'Forward computations': 18564}
# 0.5720021724700928
# 0.0002739429473876953
# {'Filename': '0033.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': 'a peck of pickled peppers', 'Viterbi transcription': 'the peck of pickled peppers the', 'Decode speed': 0.5720021724700928, 'Backtrace speed': 0.0002739429473876953, 'Forward computations': 18936}
# 0.5323002338409424
# 0.00016021728515625
# {'Filename': '0034.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': "where's the peck peter picked", 'Viterbi transcription': "the where's the peck peter picked the", 'Decode speed': 0.5323002338409424, 'Backtrace speed': 0.00016021728515625, 'Forward computations': 14142}
# 0.7350265979766846
# 0.0002818107604980469
# {'Filename': '0035.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 4, 'transcription': 'pickled peppers piper picked', 'Viterbi transcription': "the pickled peppers piper picked where's", 'Decode speed': 0.7350265979766846, 'Backtrace speed': 0.0002818107604980469, 'Forward computations': 26146}
# 0.44573330879211426
# 0.00015878677368164062
# {'Filename': '0036.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': 'picked the peter picked peppers the', 'Decode speed': 0.44573330879211426, 'Backtrace speed': 0.00015878677368164062, 'Forward computations': 14908}
# 0.6926162242889404
# 0.00027632713317871094
# {'Filename': '0037.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'picked the peter piper picked peck of pickled peppers the', 'Decode speed': 0.6926162242889404, 'Backtrace speed': 0.00027632713317871094, 'Forward computations': 24476}
# No path got to the end of the observations.
# 0.7247958183288574
# 0.0005500316619873047
# {'Filename': '0038.wav', 'Insertions': 0, 'Deletions': 8, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': '', 'Decode speed': 0.7247958183288574, 'Backtrace speed': 0.0005500316619873047, 'Forward computations': 24188}
# 0.6564137935638428
# 0.0002760887145996094
# {'Filename': '0039.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'peppers pickled peter of the piper peck', 'Viterbi transcription': 'peppers picked peter of the piper peck the', 'Decode speed': 0.6564137935638428, 'Backtrace speed': 0.0002760887145996094, 'Forward computations': 21136}
# 0.8429760932922363
# 0.00040841102600097656
# {'Filename': '0040.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 8, 'transcription': "piper peter picked where's the pickled peppers peter", 'Viterbi transcription': "picked the peck peter picked where's the picked peppers peter a the", 'Decode speed': 0.8429760932922363, 'Backtrace speed': 0.00040841102600097656, 'Forward computations': 29176}
# 0.6891293525695801
# 0.0003261566162109375
# {'Filename': '0041.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': 'peck pickled piper of the peter peppers', 'Viterbi transcription': 'peck the peck the picked of the peter peppers the', 'Decode speed': 0.6891293525695801, 'Backtrace speed': 0.0003261566162109375, 'Forward computations': 22966}
# 0.7924022674560547
# 0.0004127025604248047
# {'Filename': '0042.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.5454545454545454, 'Word Count': 11, 'transcription': 'a peck of pickled peter picked the peppers of the peck', 'Viterbi transcription': 'picked of peck of pickled peter peck the peck picked of the peck the', 'Decode speed': 0.7924022674560547, 'Backtrace speed': 0.0004127025604248047, 'Forward computations': 28088}
# 0.7291431427001953
# 0.00030517578125
# {'Filename': '0043.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.4285714285714286, 'Word Count': 7, 'transcription': "where's the peck of peppers piper pickled", 'Viterbi transcription': "the where's the the a of the of where's piper of peter the the", 'Decode speed': 0.7291431427001953, 'Backtrace speed': 0.00030517578125, 'Forward computations': 23802}
# 0.8167695999145508
# 0.00044417381286621094
# {'Filename': '0044.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.75, 'Word Count': 8, 'transcription': 'piper pickled peppers of the peck peter picked', 'Viterbi transcription': 'the piper pickled peck the of the piper peter peck the', 'Decode speed': 0.8167695999145508, 'Backtrace speed': 0.00044417381286621094, 'Forward computations': 27946}
# 0.7777154445648193
# 0.0003662109375
# {'Filename': '0045.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 5, 'WER': 2.0, 'Word Count': 6, 'transcription': 'piper peter picked pickled piper peppers', 'Viterbi transcription': "the where's the where's the the where's the picked peck of the the", 'Decode speed': 0.7777154445648193, 'Backtrace speed': 0.0003662109375, 'Forward computations': 27404}
# 0.852363109588623
# 0.00041675567626953125
# {'Filename': '0046.wav', 'Insertions': 8, 'Deletions': 0, 'Substitutions': 5, 'WER': 1.1818181818181819, 'Word Count': 11, 'transcription': 'peter picked peppers of the pickled peck of peppers of piper', 'Viterbi transcription': 'a the the of the piper the of the pickled peck of peck of of of the of the', 'Decode speed': 0.852363109588623, 'Backtrace speed': 0.00041675567626953125, 'Forward computations': 29416}
# 1.6034719944000244
# 0.0020089149475097656
# {'Filename': '0047.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 4, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "picked of piper picked peck the pickled piper the where's the peck of picked peppers peter piper picked the", 'Decode speed': 1.6034719944000244, 'Backtrace speed': 0.0020089149475097656, 'Forward computations': 52362}
# 0.8471405506134033
# 0.00039649009704589844
# {'Filename': '0048.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'picked the peter piper picked the peck of pickled peppers the', 'Decode speed': 0.8471405506134033, 'Backtrace speed': 0.00039649009704589844, 'Forward computations': 28716}
# 0.6428120136260986
# 0.000316619873046875
# {'Filename': '0049.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.1111111111111111, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "where's the peck of pickled peppers peter piper picked the", 'Decode speed': 0.6428120136260986, 'Backtrace speed': 0.000316619873046875, 'Forward computations': 23324}
# 0.6052699089050293
# 0.00030612945556640625
# {'Filename': '0050.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.2, 'Word Count': 5, 'transcription': 'pickled peppers pickled peter piper', 'Viterbi transcription': 'the the of of picked pickled peter piper the', 'Decode speed': 0.6052699089050293, 'Backtrace speed': 0.00030612945556640625, 'Forward computations': 22496}
# 0.8780162334442139
# 0.0003521442413330078
# {'Filename': '0051.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.5454545454545454, 'Word Count': 11, 'transcription': 'peter piper picked a peck of pickled peppers peter piper pickled', 'Viterbi transcription': "the peter piper picked of picked of pickled of where's peter piper pickled the", 'Decode speed': 0.8780162334442139, 'Backtrace speed': 0.0003521442413330078, 'Forward computations': 33868}
# 0.5889167785644531
# 0.00014472007751464844
# {'Filename': '0052.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'the peter piper picked peck of pickled of picked the', 'Decode speed': 0.5889167785644531, 'Backtrace speed': 0.00014472007751464844, 'Forward computations': 22490}
# 0.5055994987487793
# 0.00010776519775390625
# {'Filename': '0053.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "the where's of peck of pickled peppers the", 'Decode speed': 0.5055994987487793, 'Backtrace speed': 0.00010776519775390625, 'Forward computations': 20396}
# 0.44378089904785156
# 0.00021910667419433594
# {'Filename': '0054.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 4, 'transcription': 'piper peter peppers pickled', 'Viterbi transcription': 'the piper of peter of peppers pickled the', 'Decode speed': 0.44378089904785156, 'Backtrace speed': 0.00021910667419433594, 'Forward computations': 18322}
# No path got to the end of the observations.
# 0.5626497268676758
# 0.00023031234741210938
# {'Filename': '0055.wav', 'Insertions': 0, 'Deletions': 9, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 9, 'transcription': 'peter piper picked peter piper picked peter piper picked', 'Viterbi transcription': '', 'Decode speed': 0.5626497268676758, 'Backtrace speed': 0.00023031234741210938, 'Forward computations': 22980}
# 0.5035266876220703
# 0.0002410411834716797
# {'Filename': '0056.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "where's the peck of peter piper peppers", 'Viterbi transcription': "the where's the peck of peter piper peppers the", 'Decode speed': 0.5035266876220703, 'Backtrace speed': 0.0002410411834716797, 'Forward computations': 19074}
# 0.8933906555175781
# 0.0004184246063232422
# {'Filename': '0057.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 6, 'WER': 1.125, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'picked the of piper pickled peck the pickled of picked the', 'Decode speed': 0.8933906555175781, 'Backtrace speed': 0.0004184246063232422, 'Forward computations': 31528}
# 0.7129943370819092
# 0.0003592967987060547
# {'Filename': '0058.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.625, 'Word Count': 8, 'transcription': 'the peck of pickled peppers picked peter piper', 'Viterbi transcription': 'the peck of the of of picked picked piper the', 'Decode speed': 0.7129943370819092, 'Backtrace speed': 0.0003592967987060547, 'Forward computations': 23528}
# 0.8150384426116943
# 0.0003936290740966797
# {'Filename': '0059.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 6, 'transcription': 'piper picked peter the pickled peppers', 'Viterbi transcription': 'picked the piper of picked peter the pickled the picked the', 'Decode speed': 0.8150384426116943, 'Backtrace speed': 0.0003936290740966797, 'Forward computations': 28846}
# 0.6034624576568604
# 0.0007779598236083984
# {'Filename': '0060.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.4, 'Word Count': 5, 'transcription': 'peck piper peter pickled picked', 'Viterbi transcription': 'picked peck piper peter of the of the peck the', 'Decode speed': 0.6034624576568604, 'Backtrace speed': 0.0007779598236083984, 'Forward computations': 20830}
# 0.6852998733520508
# 0.0003299713134765625
# {'Filename': '0061.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6, 'Word Count': 5, 'transcription': 'peck peppers pickled peter piper', 'Viterbi transcription': 'picked peck peppers pickled peter piper picked the', 'Decode speed': 0.6852998733520508, 'Backtrace speed': 0.0003299713134765625, 'Forward computations': 23256}
# No path got to the end of the observations.
# 1.4701251983642578
# 0.0007145404815673828
# {'Filename': '0062.wav', 'Insertions': 2, 'Deletions': 3, 'Substitutions': 8, 'WER': 0.7647058823529411, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "the peter of of of a the the picked of pickled peppers where's peck of the", 'Decode speed': 1.4701251983642578, 'Backtrace speed': 0.0007145404815673828, 'Forward computations': 56772}
# 0.841869592666626
# 0.000408172607421875
# {'Filename': '0063.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.4285714285714286, 'Word Count': 7, 'transcription': "peter piper picked where's the peck of", 'Viterbi transcription': "the the of of of the a picked where's of peck where's the", 'Decode speed': 0.841869592666626, 'Backtrace speed': 0.000408172607421875, 'Forward computations': 32242}
# 1.2090914249420166
# 0.0006284713745117188
# {'Filename': '0064.wav', 'Insertions': 11, 'Deletions': 0, 'Substitutions': 6, 'WER': 1.4166666666666667, 'Word Count': 12, 'transcription': 'pickled peppers pickled peppers peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a the pickled of where's the of the of of the picked of of of a the of a of pickled peppers the", 'Decode speed': 1.2090914249420166, 'Backtrace speed': 0.0006284713745117188, 'Forward computations': 46890}
# 0.8840045928955078
# 0.0004909038543701172
# {'Filename': '0065.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 8, 'transcription': 'the peck of pickled peppers peter piper picked', 'Viterbi transcription': "the peck a of a where's peppers peter piper a the the", 'Decode speed': 0.8840045928955078, 'Backtrace speed': 0.0004909038543701172, 'Forward computations': 34336}
# 0.849510669708252
# 0.000415802001953125
# {'Filename': '0066.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.0, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "the the of a picked picked of picked where's pickled peppers the", 'Decode speed': 0.849510669708252, 'Backtrace speed': 0.000415802001953125, 'Forward computations': 32186}
# 1.336759090423584
# 0.0006830692291259766
# {'Filename': '0067.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.25, 'Word Count': 8, 'transcription': 'pickled peter peppers pickled peppers piper of piper', 'Viterbi transcription': 'picked the picked of peter the of picked a of peppers piper of piper the', 'Decode speed': 1.336759090423584, 'Backtrace speed': 0.0006830692291259766, 'Forward computations': 47520}
# 0.8163022994995117
# 0.0003857612609863281
# {'Filename': '0068.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': "pickled where's peck peck peppers", 'Viterbi transcription': "the pickled where's peck peck peppers the", 'Decode speed': 0.8163022994995117, 'Backtrace speed': 0.0003857612609863281, 'Forward computations': 29206}
# 1.1330187320709229
# 0.0005581378936767578
# {'Filename': '0069.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': 'picked pickled a pickled peter of peppers peppers piper', 'Viterbi transcription': 'the pickled pickled of pickled peter of of peppers of picked piper picked the', 'Decode speed': 1.1330187320709229, 'Backtrace speed': 0.0005581378936767578, 'Forward computations': 41862}
# 0.6265373229980469
# 0.00031375885009765625
# {'Filename': '0070.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 4, 'transcription': 'peck peppers picked piper', 'Viterbi transcription': 'picked the peck peppers picked piper a picked', 'Decode speed': 0.6265373229980469, 'Backtrace speed': 0.00031375885009765625, 'Forward computations': 24548}
# 0.7193074226379395
# 0.00025081634521484375
# {'Filename': '0071.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 5, 'transcription': 'a peter pickled pickled picked', 'Viterbi transcription': 'the of peter of pickled pickled a the', 'Decode speed': 0.7193074226379395, 'Backtrace speed': 0.00025081634521484375, 'Forward computations': 26706}
# 1.2037091255187988
# 0.0005123615264892578
# {'Filename': '0072.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 6, 'WER': 1.4444444444444444, 'Word Count': 9, 'transcription': 'peck peppers picked a picked peter a picked peppers', 'Viterbi transcription': "the peck of where's picked of picked the the of of pickled of of the the", 'Decode speed': 1.2037091255187988, 'Backtrace speed': 0.0005123615264892578, 'Forward computations': 43804}
# 0.9088766574859619
# 0.00019979476928710938
# {'Filename': '0073.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': "peck picked peppers peck picked where's of pickled", 'Viterbi transcription': "the peck picked of where's peck picked where's of pickled the", 'Decode speed': 0.9088766574859619, 'Backtrace speed': 0.00019979476928710938, 'Forward computations': 35668}
# 0.7095820903778076
# 0.0004520416259765625
# {'Filename': '0074.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.875, 'Word Count': 8, 'transcription': "a peter where's piper the picked picked peppers", 'Viterbi transcription': "the of peter where's piper the pickled picked peck of the the", 'Decode speed': 0.7095820903778076, 'Backtrace speed': 0.0004520416259765625, 'Forward computations': 28766}
# 0.9002971649169922
# 0.0003597736358642578
# {'Filename': '0075.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': 'piper peck of peck pickled picked pickled of peter', 'Viterbi transcription': 'the piper of piper of peck pickled picked pickled of peter the', 'Decode speed': 0.9002971649169922, 'Backtrace speed': 0.0003597736358642578, 'Forward computations': 35054}
# 1.0032639503479004
# 0.0004894733428955078
# {'Filename': '0076.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.7777777777777778, 'Word Count': 9, 'transcription': 'peck of peter peppers pickled peppers of picked peter', 'Viterbi transcription': 'the peck of peter of of pickled of picked the of picked the', 'Decode speed': 1.0032639503479004, 'Backtrace speed': 0.0004894733428955078, 'Forward computations': 39004}
# 1.141991138458252
# 0.0005016326904296875
# {'Filename': '0077.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2222222222222222, 'Word Count': 9, 'transcription': 'peppers peck of peck peter picked a of peppers', 'Viterbi transcription': 'the peppers peck of peck peter picked a of peppers the', 'Decode speed': 1.141991138458252, 'Backtrace speed': 0.0005016326904296875, 'Forward computations': 45292}
# No path got to the end of the observations.
# 0.9267578125
# 0.00047850608825683594
# {'Filename': '0078.wav', 'Insertions': 0, 'Deletions': 9, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 9, 'transcription': 'a peck of the pickled peppers peter piper picked', 'Viterbi transcription': '', 'Decode speed': 0.9267578125, 'Backtrace speed': 0.00047850608825683594, 'Forward computations': 36034}
# 0.7425549030303955
# 0.000339508056640625
# {'Filename': '0079.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': 'piper picked peter of the peck', 'Viterbi transcription': 'the piper picked peter of the peck the', 'Decode speed': 0.7425549030303955, 'Backtrace speed': 0.000339508056640625, 'Forward computations': 26320}
# 0.9545941352844238
# 0.0005199909210205078
# {'Filename': '0080.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'a peter picked peck of picked pickled piper', 'Viterbi transcription': 'picked the of peter picked peck of picked pickled piper the', 'Decode speed': 0.9545941352844238, 'Backtrace speed': 0.0005199909210205078, 'Forward computations': 34182}
# 0.7203614711761475
# 0.000324249267578125
# {'Filename': '0081.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': "where's peck peppers of piper", 'Viterbi transcription': "the where's peck peppers of piper the", 'Decode speed': 0.7203614711761475, 'Backtrace speed': 0.000324249267578125, 'Forward computations': 25936}
# 0.8154668807983398
# 0.0004153251647949219
# {'Filename': '0082.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.6666666666666667, 'Word Count': 3, 'transcription': 'piper of peppers', 'Viterbi transcription': 'picked piper of a a picked the', 'Decode speed': 0.8154668807983398, 'Backtrace speed': 0.0004153251647949219, 'Forward computations': 32334}
# 0.5822010040283203
# 0.00023651123046875
# {'Filename': '0083.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': 'peter picked piper', 'Viterbi transcription': 'the peter picked a piper a the', 'Decode speed': 0.5822010040283203, 'Backtrace speed': 0.00023651123046875, 'Forward computations': 23394}
# 0.40317225456237793
# 0.00012254714965820312
# {'Filename': '0084.wav', 'Insertions': 2, 'Deletions': 3, 'Substitutions': 2, 'WER': 0.7777777777777778, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "pickled of where's peter of piper picked the", 'Decode speed': 0.40317225456237793, 'Backtrace speed': 0.00012254714965820312, 'Forward computations': 16116}
# No path got to the end of the observations.
# 0.5619475841522217
# 0.00022268295288085938
# {'Filename': '0085.wav', 'Insertions': 0, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.36363636363636365, 'Word Count': 11, 'transcription': 'the peck of pickled peppers picked a peck of pickled peppers', 'Viterbi transcription': 'peck peck of peppers picked of peck of pickled peck', 'Decode speed': 0.5619475841522217, 'Backtrace speed': 0.00022268295288085938, 'Forward computations': 22186}
# No path got to the end of the observations.
# 0.6633784770965576
# 0.00018715858459472656
# {'Filename': '0086.wav', 'Insertions': 0, 'Deletions': 5, 'Substitutions': 0, 'WER': 0.625, 'Word Count': 8, 'transcription': "peter piper where's the peck of pickled peppers", 'Viterbi transcription': 'peter piper the', 'Decode speed': 0.6633784770965576, 'Backtrace speed': 0.00018715858459472656, 'Forward computations': 27214}
# No path got to the end of the observations.
# 0.7510948181152344
# 0.0007092952728271484
# {'Filename': '0087.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 9, 'transcription': 'peter piper peter piper a peck of pickled peppers', 'Viterbi transcription': 'peter piper picked the peter piper the of peter pickled peck', 'Decode speed': 0.7510948181152344, 'Backtrace speed': 0.0007092952728271484, 'Forward computations': 30854}
# No path got to the end of the observations.
# 0.8144314289093018
# 0.00016427040100097656
# {'Filename': '0088.wav', 'Insertions': 0, 'Deletions': 11, 'Substitutions': 1, 'WER': 0.7058823529411765, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "piper picked peck pickled peck where's", 'Decode speed': 0.8144314289093018, 'Backtrace speed': 0.00016427040100097656, 'Forward computations': 32036}
# 0.9636332988739014
# 0.000194549560546875
# {'Filename': '0089.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.5882352941176471, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "peck the of of picked picked peck of pickled peppers where's the peck of picked a peck picked peter piper picked the", 'Decode speed': 0.9636332988739014, 'Backtrace speed': 0.000194549560546875, 'Forward computations': 38750}
# 1.4004921913146973
# 0.0005602836608886719
# {'Filename': '0090.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5294117647058824, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "picked the peter piper picked a peck of pickled of picked the where's the peck of pickled peck where's peter piper of picked the", 'Decode speed': 1.4004921913146973, 'Backtrace speed': 0.0005602836608886719, 'Forward computations': 55816}
# 0.3450610637664795
# 7.176399230957031e-05
# {'Filename': '0091.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 4, 'transcription': "where's the peck of", 'Viterbi transcription': "picked where's of peck where's the", 'Decode speed': 0.3450610637664795, 'Backtrace speed': 7.176399230957031e-05, 'Forward computations': 14276}
# 0.4089376926422119
# 7.867813110351562e-05
# {'Filename': '0092.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': 'picked a peck of pickled', 'Viterbi transcription': 'picked picked peck of pickled the', 'Decode speed': 0.4089376926422119, 'Backtrace speed': 7.867813110351562e-05, 'Forward computations': 15610}
# 0.43239855766296387
# 8.988380432128906e-05
# {'Filename': '0093.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': "pickled peppers where's the peck", 'Viterbi transcription': "pickled of picked where's the peck the", 'Decode speed': 0.43239855766296387, 'Backtrace speed': 8.988380432128906e-05, 'Forward computations': 17914}
# 0.35883307456970215
# 7.605552673339844e-05
# {'Filename': '0094.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': "the peter picked peck where's", 'Decode speed': 0.35883307456970215, 'Backtrace speed': 7.605552673339844e-05, 'Forward computations': 14682}
# 0.5121474266052246
# 0.00010013580322265625
# {'Filename': '0095.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peter pickled a picked peck', 'Viterbi transcription': 'the peter pickled picked peck picked the', 'Decode speed': 0.5121474266052246, 'Backtrace speed': 0.00010013580322265625, 'Forward computations': 19788}
# 0.47325968742370605
# 9.679794311523438e-05
# {'Filename': '0096.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'peter picked the peck of peppers', 'Viterbi transcription': 'the peck picked the peck the of picked the', 'Decode speed': 0.47325968742370605, 'Backtrace speed': 9.679794311523438e-05, 'Forward computations': 19802}
# 0.6800181865692139
# 0.00013065338134765625
# {'Filename': '0097.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter picked a peck of the pickled peppers', 'Viterbi transcription': "the where's piper picked the peck of the pickled peppers the", 'Decode speed': 0.6800181865692139, 'Backtrace speed': 0.00013065338134765625, 'Forward computations': 26524}
# 0.4675111770629883
# 9.560585021972656e-05
# {'Filename': '0098.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': 'the peck of peppers peter piper pickled', 'Viterbi transcription': "the peck of peck where's peter piper pickled the", 'Decode speed': 0.4675111770629883, 'Backtrace speed': 9.560585021972656e-05, 'Forward computations': 19390}
# 1.2693934440612793
# 0.0003085136413574219
# {'Filename': '0099.wav', 'Insertions': 7, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.9090909090909091, 'Word Count': 11, 'transcription': "the peck pickled peppers picked pickled peter of piper a where's", 'Viterbi transcription': "picked the picked a picked the a pickled picked picked a pickled peter piper a where's the", 'Decode speed': 1.2693934440612793, 'Backtrace speed': 0.0003085136413574219, 'Forward computations': 50254}
# 0.9124867916107178
# 0.00018072128295898438
# {'Filename': '0100.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 10, 'transcription': 'the picked of piper picked of pickled a peter piper', 'Viterbi transcription': 'the picked of piper picked of pickled a the the peck piper the', 'Decode speed': 0.9124867916107178, 'Backtrace speed': 0.00018072128295898438, 'Forward computations': 36150}
# 1.4379191398620605
# 0.00045013427734375
# {'Filename': '0101.wav', 'Insertions': 7, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.6428571428571429, 'Word Count': 14, 'transcription': "peck piper picked of picked pickled of where's a peppers peter peppers peter pickled", 'Viterbi transcription': "picked the peck piper picked of peter pickled of where's a the peppers peter peter the picked of pickled picked", 'Decode speed': 1.4379191398620605, 'Backtrace speed': 0.00045013427734375, 'Forward computations': 57318}
# 0.539233922958374
# 0.0001277923583984375
# {'Filename': '0102.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.75, 'Word Count': 4, 'transcription': 'peppers peck peter pickled', 'Viterbi transcription': 'the peppers a peter pickled the', 'Decode speed': 0.539233922958374, 'Backtrace speed': 0.0001277923583984375, 'Forward computations': 22358}
# 0.7559187412261963
# 0.00033545494079589844
# {'Filename': '0103.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': "where's piper picked piper a pickled peppers", 'Viterbi transcription': "the where's piper picked piper pickled peck picked the", 'Decode speed': 0.7559187412261963, 'Backtrace speed': 0.00033545494079589844, 'Forward computations': 30322}
# 0.7369506359100342
# 0.000152587890625
# {'Filename': '0104.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.6666666666666667, 'Word Count': 6, 'transcription': 'peter picked peppers of pickled peppers', 'Viterbi transcription': 'picked the peck picked the peck peck of pickled peck picked the the', 'Decode speed': 0.7369506359100342, 'Backtrace speed': 0.000152587890625, 'Forward computations': 31032}
# 0.9318957328796387
# 0.00020623207092285156
# {'Filename': '0105.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 9, 'transcription': 'peter peppers picked piper a peck of pickled peppers', 'Viterbi transcription': 'the peter peppers picked piper picked a peck of pickled peter a the the', 'Decode speed': 0.9318957328796387, 'Backtrace speed': 0.00020623207092285156, 'Forward computations': 37396}
# 0.8067154884338379
# 0.0002338886260986328
# {'Filename': '0106.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.0, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'the picked piper peck a picked peck of pickled peck a picked the', 'Decode speed': 0.8067154884338379, 'Backtrace speed': 0.0002338886260986328, 'Forward computations': 33250}
# 0.7409389019012451
# 0.00019598007202148438
# {'Filename': '0107.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': "where's the peck of peppers peter piper picked", 'Viterbi transcription': "the where's the picked of peck picked peter piper picked the", 'Decode speed': 0.7409389019012451, 'Backtrace speed': 0.00019598007202148438, 'Forward computations': 30686}
# 0.6620144844055176
# 0.00024199485778808594
# {'Filename': '0108.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'the peck of pickled peter piper pickled', 'Viterbi transcription': 'the peck of pickled peter piper of pickled the', 'Decode speed': 0.6620144844055176, 'Backtrace speed': 0.00024199485778808594, 'Forward computations': 25506}
# 0.6707170009613037
# 0.00013184547424316406
# {'Filename': '0109.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.1666666666666667, 'Word Count': 6, 'transcription': 'piper peter picked peppers of piper', 'Viterbi transcription': "where's piper peter picked peck picked of piper of the the the", 'Decode speed': 0.6707170009613037, 'Backtrace speed': 0.00013184547424316406, 'Forward computations': 26374}
# 0.6157512664794922
# 0.00011992454528808594
# {'Filename': '0110.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 8, 'transcription': 'peter peppers picked a piper of the peck', 'Viterbi transcription': 'the peter of of picked picked of piper of the peck the', 'Decode speed': 0.6157512664794922, 'Backtrace speed': 0.00011992454528808594, 'Forward computations': 23958}
# 0.5080850124359131
# 0.00010418891906738281
# {'Filename': '0111.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'peck of picked peter piper picked', 'Viterbi transcription': 'picked peter picked peter of piper of picked the', 'Decode speed': 0.5080850124359131, 'Backtrace speed': 0.00010418891906738281, 'Forward computations': 21494}
# 0.5096969604492188
# 0.00010752677917480469
# {'Filename': '0112.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 5, 'transcription': 'picked the peppers peter pickled', 'Viterbi transcription': 'picked the picked the peppers peter of a pickled the', 'Decode speed': 0.5096969604492188, 'Backtrace speed': 0.00010752677917480469, 'Forward computations': 21046}
# 0.5806388854980469
# 0.00014019012451171875
# {'Filename': '0113.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'the piper of peck peppers peter picked', 'Viterbi transcription': 'the piper of peck peppers peter of picked the', 'Decode speed': 0.5806388854980469, 'Backtrace speed': 0.00014019012451171875, 'Forward computations': 24254}
# 1.3898451328277588
# 0.00038814544677734375
# {'Filename': '0114.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 7, 'WER': 1.75, 'Word Count': 8, 'transcription': 'piper picked peter a pickled peck of peppers', 'Viterbi transcription': "the the of the the the of where's picked of picked of of where's the", 'Decode speed': 1.3898451328277588, 'Backtrace speed': 0.00038814544677734375, 'Forward computations': 54672}
# 0.6194605827331543
# 0.00012493133544921875
# {'Filename': '0115.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.6666666666666667, 'Word Count': 3, 'transcription': "where's peter piper", 'Viterbi transcription': "the where's the the piper where's the", 'Decode speed': 0.6194605827331543, 'Backtrace speed': 0.00012493133544921875, 'Forward computations': 25318}
# 0.8607277870178223
# 0.0001842975616455078
# {'Filename': '0116.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.1111111111111112, 'Word Count': 9, 'transcription': 'piper picked the peck of pickled peppers peter picked', 'Viterbi transcription': 'the of a picked a the the of picked pickled of of picked a the', 'Decode speed': 0.8607277870178223, 'Backtrace speed': 0.0001842975616455078, 'Forward computations': 33884}
# ...
# 0.713911771774292
# 0.00018095970153808594
# {'Filename': '0185.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'piper picked a peck of peter', 'Viterbi transcription': 'the piper the the peck of peter a the', 'Decode speed': 0.713911771774292, 'Backtrace speed': 0.00018095970153808594, 'Forward computations': 29032}
# 0.6271483898162842
# 0.00013303756713867188
# {'Filename': '0186.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'peter pickled a peck of peppers', 'Viterbi transcription': 'the peter pickled peck of of a the', 'Decode speed': 0.6271483898162842, 'Backtrace speed': 0.00013303756713867188, 'Forward computations': 25366}
# No path got to the end of the observations.
# 0.4306619167327881
# 9.012222290039062e-05
# {'Filename': '0187.wav', 'Insertions': 0, 'Deletions': 2, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': 'piper pickled peter', 'Viterbi transcription': 'the', 'Decode speed': 0.4306619167327881, 'Backtrace speed': 9.012222290039062e-05, 'Forward computations': 17232}
# No path got to the end of the observations.
# 0.567765474319458
# 0.00013971328735351562
# {'Filename': '0188.wav', 'Insertions': 0, 'Deletions': 4, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 5, 'transcription': "where's peter piper pickled peppers", 'Viterbi transcription': 'the', 'Decode speed': 0.567765474319458, 'Backtrace speed': 0.00013971328735351562, 'Forward computations': 21690}
# No path got to the end of the observations.
# 0.6807875633239746
# 0.00013899803161621094
# {'Filename': '0189.wav', 'Insertions': 1, 'Deletions': 2, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'piper peter picked peppers picked peter', 'Viterbi transcription': 'the piper peter a a', 'Decode speed': 0.6807875633239746, 'Backtrace speed': 0.00013899803161621094, 'Forward computations': 26372}
# No path got to the end of the observations.
# 1.8980529308319092
# 0.0007891654968261719
# {'Filename': '0190.wav', 'Insertions': 7, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.6470588235294118, 'Word Count': 17, 'transcription': "piper pickled picked peppers of picked a pickled piper the peppers peck of peter peter peck where's", 'Viterbi transcription': 'picked the piper of pickled picked peppers of picked the of pickled picked of the of of of peck of peter peter peck', 'Decode speed': 1.8980529308319092, 'Backtrace speed': 0.0007891654968261719, 'Forward computations': 74300}
# 2.178041458129883
# 0.0009796619415283203
# {'Filename': '0191.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.6470588235294118, 'Word Count': 17, 'transcription': "a peter the of peck where's piper peter picked pickled picked peppers pickled of peck peppers piper", 'Viterbi transcription': "the of peter where's of the peck where's piper of peter picked the pickled pickled of picked pickled of the peck peppers piper picked", 'Decode speed': 2.178041458129883, 'Backtrace speed': 0.0009796619415283203, 'Forward computations': 86424}
# No path got to the end of the observations.
# 2.1262784004211426
# 0.0008997917175292969
# {'Filename': '0192.wav', 'Insertions': 8, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.7058823529411765, 'Word Count': 17, 'transcription': "peter picked peppers piper picked peter of where's peck pickled the peck pickled a piper peppers of", 'Viterbi transcription': "picked the peter picked peck of piper of picked peter the of where's peck the pickled the of peck the pickled of piper pickled", 'Decode speed': 2.1262784004211426, 'Backtrace speed': 0.0008997917175292969, 'Forward computations': 85206}
# 2.345735788345337
# 0.0009710788726806641
# {'Filename': '0193.wav', 'Insertions': 8, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.7647058823529411, 'Word Count': 17, 'transcription': "peck piper picked peppers peck the a peter pickled of pickled picked piper of where's peter peppers", 'Viterbi transcription': "picked the piper piper of picked peppers peck the of where's picked pickled of the pickled picked a picked where's the where's peter peppers the", 'Decode speed': 2.345735788345337, 'Backtrace speed': 0.0009710788726806641, 'Forward computations': 92012}
# 2.1954128742218018
# 0.0009291172027587891
# {'Filename': '0194.wav', 'Insertions': 10, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.7058823529411765, 'Word Count': 17, 'transcription': "a picked pickled peck of of picked the peck piper piper peter pickled peter peppers where's peppers", 'Viterbi transcription': "the of picked pickled peck of the of picked the of peck piper of piper of peter the pickled peter a the peck picked where's peppers the", 'Decode speed': 2.1954128742218018, 'Backtrace speed': 0.0009291172027587891, 'Forward computations': 87304}
# No path got to the end of the observations.
# 1.0776331424713135
# 0.00028014183044433594
# {'Filename': '0195.wav', 'Insertions': 0, 'Deletions': 5, 'Substitutions': 2, 'WER': 0.875, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'piper the the', 'Decode speed': 1.0776331424713135, 'Backtrace speed': 0.00028014183044433594, 'Forward computations': 42748}
# 0.9941906929016113
# 0.0007779598236083984
# {'Filename': '0196.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "the where's a peck peck of picked peck picked picked piper picked the", 'Decode speed': 0.9941906929016113, 'Backtrace speed': 0.0007779598236083984, 'Forward computations': 39024}
# 1.4602046012878418
# 0.0006399154663085938
# {'Filename': '0197.wav', 'Insertions': 8, 'Deletions': 0, 'Substitutions': 6, 'WER': 0.8235294117647058, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "picked the the of peck of picked where's peck of picked of picked where's the of peck of pickled of peppers peter pickled picked the", 'Decode speed': 1.4602046012878418, 'Backtrace speed': 0.0006399154663085938, 'Forward computations': 57116}
# 1.1847584247589111
# 0.00043702125549316406
# {'Filename': '0198.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 6, 'WER': 0.6470588235294118, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "picked the the of of peck of pickled peck of pickled peppers where's the peck of pickled peppers the the pickled picked", 'Decode speed': 1.1847584247589111, 'Backtrace speed': 0.00043702125549316406, 'Forward computations': 47292}
# 1.0744297504425049
# 0.0003781318664550781
# {'Filename': '0199.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 7, 'WER': 0.7058823529411765, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "picked the of peppers picked of peck of pickled peppers where's of peck of pickled peck where's picked peck of picked the", 'Decode speed': 1.0744297504425049, 'Backtrace speed': 0.0003781318664550781, 'Forward computations': 42502}
# 1.1340751647949219
# 0.0005342960357666016
# {'Filename': '0200.wav', 'Insertions': 6, 'Deletions': 2, 'Substitutions': 7, 'WER': 0.8823529411764706, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "picked the the of of pickled piper pickled peck of picked where's the peck of picked peck where's picked of picked", 'Decode speed': 1.1340751647949219, 'Backtrace speed': 0.0005342960357666016, 'Forward computations': 42546}
# 0.984760046005249
# 0.0002200603485107422
# {'Filename': '0201.wav', 'Insertions': 5, 'Deletions': 1, 'Substitutions': 5, 'WER': 0.6470588235294118, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "pickled of where's picked of of picked of peppers where's the of peck of pickled peppers peter of peppers picked the", 'Decode speed': 0.984760046005249, 'Backtrace speed': 0.0002200603485107422, 'Forward computations': 39330}
# 0.7376811504364014
# 0.00015926361083984375
# {'Filename': '0202.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.4, 'Word Count': 10, 'transcription': 'peppers picked a peck of peter a pickled peter piper', 'Viterbi transcription': 'the picked picked peck of peter the pickled peter piper picked', 'Decode speed': 0.7376811504364014, 'Backtrace speed': 0.00015926361083984375, 'Forward computations': 29500}
# 1.1062591075897217
# 0.00021839141845703125
# {'Filename': '0203.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.23529411764705882, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "the peter piper picked peck of pickled peppers the where's the peck of pickled peppers peter piper picked the", 'Decode speed': 1.1062591075897217, 'Backtrace speed': 0.00021839141845703125, 'Forward computations': 44274}
# 0.6687166690826416
# 0.0001323223114013672
# {'Filename': '0204.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'peck of pickled peppers peter piper picked', 'Viterbi transcription': 'the peck of pickled peppers peter piper picked the', 'Decode speed': 0.6687166690826416, 'Backtrace speed': 0.0001323223114013672, 'Forward computations': 26620}
# 0.6293799877166748
# 0.00013017654418945312
# {'Filename': '0205.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'peter piper peck peppers picked peter peppers', 'Viterbi transcription': 'the peter piper peck peppers picked peter peppers the', 'Decode speed': 0.6293799877166748, 'Backtrace speed': 0.00013017654418945312, 'Forward computations': 25164}
# 0.6497890949249268
# 0.00012922286987304688
# {'Filename': '0206.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'pickled peter piper a peck the peppers picked', 'Viterbi transcription': 'the pickled peter piper picked the peck the peppers picked the', 'Decode speed': 0.6497890949249268, 'Backtrace speed': 0.00012922286987304688, 'Forward computations': 26238}
# 0.6327095031738281
# 0.00012612342834472656
# {'Filename': '0207.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "the peter piper picked of peck of pickled of where's the", 'Decode speed': 0.6327095031738281, 'Backtrace speed': 0.00012612342834472656, 'Forward computations': 25124}
# 0.6651744842529297
# 0.00012540817260742188
# {'Filename': '0208.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "the where's of of of picked peppers picked of of picked the", 'Decode speed': 0.6651744842529297, 'Backtrace speed': 0.00012540817260742188, 'Forward computations': 26398}
# 0.6213898658752441
# 0.00011706352233886719
# {'Filename': '0209.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 6, 'transcription': "peter picked piper where's the peck", 'Viterbi transcription': "picked peter picked piper where's of peck the", 'Decode speed': 0.6213898658752441, 'Backtrace speed': 0.00011706352233886719, 'Forward computations': 25022}
# 0.51924729347229
# 9.846687316894531e-05
# {'Filename': '0210.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.625, 'Word Count': 8, 'transcription': "pickled peter the peppers a piper where's picked", 'Viterbi transcription': "pickled peter picked of of the piper where's picked the", 'Decode speed': 0.51924729347229, 'Backtrace speed': 9.846687316894531e-05, 'Forward computations': 20430}
# 0.6228439807891846
# 0.00012087821960449219
# {'Filename': '0211.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5555555555555556, 'Word Count': 9, 'transcription': "piper pickled peppers where's a peter picked a peck", 'Viterbi transcription': "picked the piper pickled peppers where's of peter picked peck the", 'Decode speed': 0.6228439807891846, 'Backtrace speed': 0.00012087821960449219, 'Forward computations': 24588}
# 1.5204946994781494
# 0.0004322528839111328
# {'Filename': '0212.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 8, 'WER': 0.8235294117647058, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "the peter of of a of peck of pickled peck where's where's a pickled pickled peck where's peter of peter of picked the", 'Decode speed': 1.5204946994781494, 'Backtrace speed': 0.0004322528839111328, 'Forward computations': 60244}
# 1.5095219612121582
# 0.0004203319549560547
# {'Filename': '0213.wav', 'Insertions': 11, 'Deletions': 0, 'Substitutions': 6, 'WER': 1.0625, 'Word Count': 16, 'transcription': 'the peck of pickled peppers peter piper picked peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'the piper of pickled peck of peter of piper of peck a the picked of piper of pickled peck of a pickled peck the of the the', 'Decode speed': 1.5095219612121582, 'Backtrace speed': 0.0004203319549560547, 'Forward computations': 59046}
# 1.9164071083068848
# 0.0006153583526611328
# {'Filename': '0214.wav', 'Insertions': 12, 'Deletions': 0, 'Substitutions': 7, 'WER': 1.3571428571428572, 'Word Count': 14, 'transcription': "a peck of pickled peppers peter piper picked where's the peck of pickled peppers", 'Viterbi transcription': "picked the where's a of of a where's picked of the of piper of a where's a where's of peck of pickled peck of the the", 'Decode speed': 1.9164071083068848, 'Backtrace speed': 0.0006153583526611328, 'Forward computations': 73060}
# 1.8287575244903564
# 0.0005848407745361328
# {'Filename': '0215.wav', 'Insertions': 12, 'Deletions': 0, 'Substitutions': 8, 'WER': 1.25, 'Word Count': 16, 'transcription': "a peck of pickled peppers picked peter piper where's peter piper peck of pickled peppers picked", 'Viterbi transcription': "the of of piper of the of peck where's picked the of piper where's where's the of peter picked of peck of pickled peck where's peck a the", 'Decode speed': 1.8287575244903564, 'Backtrace speed': 0.0005848407745361328, 'Forward computations': 72348}
# 2.022818088531494
# 0.0006847381591796875
# {'Filename': '0216.wav', 'Insertions': 9, 'Deletions': 0, 'Substitutions': 8, 'WER': 1.0625, 'Word Count': 16, 'transcription': "a peck of peppers pickled picked peter piper where's peter piper peppers pickled the peck picked", 'Viterbi transcription': "the where's piper of of a where's a where's peter peter of piper a where's peter of piper peck where's pickled the piper a the", 'Decode speed': 2.022818088531494, 'Backtrace speed': 0.0006847381591796875, 'Forward computations': 78196}
# 1.304788589477539
# 0.00036406517028808594
# {'Filename': '0217.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.8181818181818182, 'Word Count': 11, 'transcription': "peter where's a peter picked of piper piper peck pickled picked", 'Viterbi transcription': "picked the the of where's of peter picked of piper piper peck a where's the picked the", 'Decode speed': 1.304788589477539, 'Backtrace speed': 0.00036406517028808594, 'Forward computations': 51160}

# %%
from copy import deepcopy
def create_wfst_silent_word(n, probabilities=None, next_state_prob=0.5, sil_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs."""
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))


    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            last_state = current_state
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
            
        weight = fst.Weight('log',-math.log(1-sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,start_state))
        weight = fst.Weight('log',-math.log(sil_prob*(1-next_state_prob)))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'.format(i)),0,weight,current_state))
        next_state =f.add_state()
        weight = fst.Weight('log',-math.log(sil_prob*((1-next_state_prob))))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'.format(i)),0,weight,next_state))
        current_state=next_state
        
        
        for i in range(2,6):
            weight = fst.Weight('log',-math.log(1-next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
            next_state =f.add_state()
            weight = fst.Weight('log',-math.log(next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
            current_state=next_state
        

            
            
            
            
            
        
        
        
        next_weight = fst.Weight('log', -math.log(1))
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))
        break
    f.set_input_symbols(silent_state_table)
    f.set_output_symbols(word_table)


    return f


f=create_wfst_silent_word(3,next_state_prob=0.1,sil_prob=0.5)
draw_fst(f)
