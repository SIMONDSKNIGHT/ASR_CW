# %% [markdown]
# # ASR Assignment 2022-23
#
# This notebook has been provided as a template to get you started on the assignment.  Feel free to use it for your development, or do your development directly in Python.
#
# You can find a full description of the assignment [here](http://www.inf.ed.ac.uk/teaching/courses/asr/2022-23/coursework.pdf).
#
# You are provided with two Python modules `observation_model.py` and `wer.py`.  The first was described in [Lab 3](https://github.com/ZhaoZeyu1995/asr_labs/blob/master/asr_lab3_4.ipynb).  The second can be used to compute the number of substitution, deletion and insertion errors between ASR output and a reference text.
#
# It can be used as follows:
#
# ```python
# import wer
#
# my_refence = 'A B C'
# my_output = 'A C C D'
#
# wer.compute_alignment_errors(my_reference, my_output)
# ```
#
# This produces a tuple $(s,d,i)$ giving counts of substitution,
# deletion and insertion errors respectively - in this example (1, 0, 1).  The function accepts either two strings, as in the example above, or two lists.  Matching is case sensitive.
#
# ## Template code
#
# Assuming that you have already made a function to generate an WFST, `create_wfst()` and a decoder class, `MyViterbiDecoder`, you can perform recognition on all the audio files as follows:

# %%
import glob
import os
import wer
import observation_model
import openfst_python as fst

# ... (add your code to create WFSTs and Viterbi Decoder)
import observation_model
import math
import openfst_python as fst
import time

class MyViterbiDecoder:
    
    NLL_ZERO = 1e10  # define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    
    def __init__(self, f, audio_file_name):
        """Set up the decoder class with an audio file and WFST f
        """
        self.om = observation_model.ObservationModel()
        self.f = f
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
        
        forward_computations = 0
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                for arc in self.f.arcs(i):
                    
                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        forward_computations += 1
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            self.V[t][j] = prob
                            self.B[t][j] = i
                            
                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
        return forward_computations
                            
    
    def finalise_decoding(self):
        """ this incorporates the probability of terminating at each state
        """
        
        for state in self.f.states():
            final_weight = float(self.f.final(state))
            if self.V[-1][state] != self.NLL_ZERO:
                if final_weight == math.inf:
                    self.V[-1][state] = self.NLL_ZERO  # effectively says that we can't end in this state
                else:
                    self.V[-1][state] += final_weight
                    
        # get a list of all states where there was a path ending with non-zero probability
        finished = [x for x in self.V[-1] if x < self.NLL_ZERO]
        if not finished:  # if empty
            print("No path got to the end of the observations.")
        
        
    def decode(self):
        forward_computations = 0
        initial = time.time()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            forward_computations += self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            t += 1
        self.finalise_decoding()
        final=time.time()
        return (forward_computations, (final - initial))
    
    def backtrace(self):
        
        initial = time.time()
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        
        
        final = time.time()
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence =' '.join([ self.f.output_symbols().find(label) for label in best_out_sequence])
        return (best_state_sequence, best_out_sequence,(final-initial))
import openfst_python as fst

def parse_lexicon(lex_file):
    """
    Parse the lexicon file and return it in dictionary form.
    
    Args:
        lex_file (str): filename of lexicon file with structure '<word> <phone1> <phone2>...'
                        eg. peppers p eh p er z

    Returns:
        lex (dict): dictionary mapping words to list of phones
    """
    
    lex = {}  # create a dictionary for the lexicon entries (this could be a problem with larger lexica)
    with open(lex_file, 'r') as f:
        for line in f:
            line = line.split()  # split at each space
            lex[line[0]] = line[1:]  # first field the word, the rest is the phones
    return lex

def generate_symbol_tables(lexicon, n=3):
    '''
    Return word, phone and state symbol tables based on the supplied lexicon
        
    Args:
        lexicon (dict): lexicon to use, created from the parse_lexicon() function
        n (int): number of states for each phone HMM
        
    Returns:
        word_table (fst.SymbolTable): table of words
        phone_table (fst.SymbolTable): table of phones
        state_table (fst.SymbolTable): table of HMM phone-state IDs
    '''
    
    state_table = fst.SymbolTable()
    phone_table = fst.SymbolTable()
    word_table = fst.SymbolTable()
    
    # add empty <eps> symbol to all tables
    state_table.add_symbol('<eps>')
    phone_table.add_symbol('<eps>')
    word_table.add_symbol('<eps>')
    
    for word, phones  in lexicon.items():
        
        word_table.add_symbol(word)
        
        for p in phones: # for each phone
            
            phone_table.add_symbol(p)
            for i in range(1,n+1): # for each state 1 to n
                state_table.add_symbol('{}_{}'.format(p, i))
            
    return word_table, phone_table, state_table


# call these two functions
lex = parse_lexicon('lexicon.txt')
word_table, phone_table, state_table = generate_symbol_tables(lex)
def generate_phone_wfst(f, start_state, phone, n, next_state_prob):
    """
    Generate a WFST representing an n-state left-to-right phone HMM.
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assumed to exist already
        phone (str): the phone label 
        n (int): number of states of the HMM excluding start and end
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
    
        in_label = state_table.find('{}_{}'.format(phone, i))
        sl_weight = fst.Weight('log', -math.log(1-next_state_prob))
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, sl_weight, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        
        out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        next_weight = fst.Weight('log', -math.log(next_state_prob))
        f.add_arc(current_state, fst.Arc(in_label, out_label, next_weight, next_state))    
       
        current_state = next_state
    return current_state



def create_wfst(n, probabilities=None, next_state_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs.
        This will currently output phone labels.  
    
    Args:
        
        start_state (int): the index of the first state, assumed to exist already
        word (str): the word to generate
        n (int): states per phone HMM
        
    Returns:
        the constructed WFST
    
    """
    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
        # note: new current_state is now set to the final state of the previous phone WFST
        
        next_weight = fst.Weight('log', -math.log(1))
        out_label = word_table.find(word)
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))
    f.set_input_symbols(state_table)
    f.set_output_symbols(word_table)

    return f




    


def read_transcription(wav_file):
    """
    Get the transcription corresponding to wav_file.
    """
    
    transcription_file = os.path.splitext(wav_file)[0] + '.txt'
    
    with open(transcription_file, 'r') as f:
        transcription = f.readline().strip()
    
    return transcription


f = create_wfst(3)

print([x for x in lex.values()])

def num_states(f):
    counter = 0
    for x in f.states():
        counter += 1
    return counter

def total_num_arcs(f):
    return sum(f.num_arcs(s) for s in f.states())

def draw_fst(f):
    from subprocess import check_call
    from IPython.display import Image
    f.draw('tmp.dot', portrait=True)
    check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
    return Image(filename='tmp.png')




draw_fst(f)
# Out:
# [['ey'], ['ah', 'v'], ['p', 'eh', 'k'], ['p', 'eh', 'p', 'er', 'z'], ['p', 'iy', 't', 'er'], ['p', 'ih', 'k', 't'], ['p', 'ih', 'k', 'ah', 'l', 'd'], ['p', 'ay', 'p', 'er'], ['dh', 'iy'], ['w', 'eh', 'r', 'z']]

# %%
#TASK 1

# !pip install pandas
import pandas as pd
results_df=[]
import wer

print(num_states(f))
print(total_num_arcs(f))
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    break
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('resulto.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
from collections import defaultdict
word_count=defaultdict(int)

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    transcription = read_transcription(wav_file)
    for word in transcription.split(" "):
        word_count[word]+=1
total_words = sum(word_count.values())
probabilities ={word:count/total_words for word,count in word_count.items()}
print(word_count,probabilities)
# Out:
# defaultdict(<class 'int'>, {'peter': 338, 'piper': 289, 'picked': 286, 'a': 138, 'peck': 264, 'of': 246, 'pickled': 285, 'peppers': 321, "where's": 118, 'the': 137}) {'peter': 0.13955408753096615, 'piper': 0.11932287365813378, 'picked': 0.1180842279108175, 'a': 0.05697770437654831, 'peck': 0.10900082576383155, 'of': 0.10156895127993394, 'pickled': 0.11767134599504542, 'peppers': 0.13253509496284063, "where's": 0.04872006606110652, 'the': 0.056564822460776217}

# %%
#TASK 2, using the above probabilities to change the word probabilties
# !pip install pandas
import pandas as pd
results_df=[]
import wer
f= create_wfst(3,probabilities)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                     # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_unary.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
#TASK 2, changing self-loop probabilities
# !pip install pandas
import pandas as pd
results_df=[]
import wer
f= create_wfst(3,next_state_prob=0.7)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                                                               # audio files
    
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_0.7.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
#task2 silent states between states

# %%
from copy import deepcopy



def create_wfst_silent(n, probabilities=None, next_state_prob=0.5, sil_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs."""
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))


    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            last_state = current_state
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
            
        weight = fst.Weight('log',-math.log(1-sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,start_state))
        weight = fst.Weight('log',-math.log(sil_prob*(1-next_state_prob)))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'),0,weight,current_state))
        next_state =f.add_state()
        weight = fst.Weight('log',-math.log(sil_prob*((1-next_state_prob))))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'),0,weight,next_state))
        current_state=next_state
        
        
        for i in range(2,6):
            weight = fst.Weight('log',-math.log(1-next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
            next_state =f.add_state()
            weight = fst.Weight('log',-math.log(next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
            current_state=next_state
        

            
            
            
            
            
        
        
        
        next_weight = fst.Weight('log', -math.log(1))
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))
    f.set_input_symbols(silent_state_table)
    f.set_output_symbols(word_table)


    return f

# %%
f=create_wfst_silent(3,sil_prob=0.6)

# %%
draw_fst(f)

# %%
#TASK 2, changing self-loop probabilities
# !pip install pandas
import pandas as pd
results_df=[]
import wer
results_df=[]
f= create_wfst_silent(3,sil_prob=0.8)
print(num_states(f))
print(total_num_arcs(f))

results_df=[]
f= create_wfst_silent(3,sil_prob=0.9)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                          # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_silent_0.9.csv')
results_df=[]
f= create_wfst_silent(3,sil_prob=0.3)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                          # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_silent_0.3.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 166
# 340
# 166
# 340
# 8.138547658920288
# 0.0007152557373046875
# {'Filename': '0000.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.11764705882352941, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "pickled peter piper picked a the peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Decode speed': 8.138547658920288, 'Backtrace speed': 0.0007152557373046875, 'Forward computations': 354068}
# 4.624006032943726
# 0.00034880638122558594
# {'Filename': '0001.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': 'pickled a peter picked the of peck of pickled peppers', 'Decode speed': 4.624006032943726, 'Backtrace speed': 0.00034880638122558594, 'Forward computations': 200618}
# 3.472748279571533
# 0.00018930435180664062
# {'Filename': '0002.wav', 'Insertions': 0, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': 'a peck of pickled peppers picked', 'Viterbi transcription': 'pickled peck pickled peppers picked', 'Decode speed': 3.472748279571533, 'Backtrace speed': 0.00018930435180664062, 'Forward computations': 150398}
# 2.5499119758605957
# 0.00012874603271484375
# {'Filename': '0003.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peter piper peter piper', 'Viterbi transcription': 'pickled peter piper peter piper', 'Decode speed': 2.5499119758605957, 'Backtrace speed': 0.00012874603271484375, 'Forward computations': 110718}
# 3.3569483757019043
# 0.00018858909606933594
# {'Filename': '0004.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': "where's the peck of pickled peppers picked", 'Viterbi transcription': "pickled where's the pickled pickled peppers picked", 'Decode speed': 3.3569483757019043, 'Backtrace speed': 0.00018858909606933594, 'Forward computations': 145128}
# 2.0051021575927734
# 0.00010085105895996094
# {'Filename': '0005.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 4, 'transcription': 'peter piper pickled peppers', 'Viterbi transcription': 'peter piper pickled peppers', 'Decode speed': 2.0051021575927734, 'Backtrace speed': 0.00010085105895996094, 'Forward computations': 86848}
# 1.1637792587280273
# 6.771087646484375e-05
# {'Filename': '0006.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 2, 'transcription': "where's peter", 'Viterbi transcription': "where's peter", 'Decode speed': 1.1637792587280273, 'Backtrace speed': 6.771087646484375e-05, 'Forward computations': 52438}
# 1.9717495441436768
# 0.0003237724304199219
# {'Filename': '0007.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'piper picked peppers of peter', 'Viterbi transcription': 'a piper picked peppers of peter', 'Decode speed': 1.9717495441436768, 'Backtrace speed': 0.0003237724304199219, 'Forward computations': 86848}
# 2.2439870834350586
# 0.00011730194091796875
# {'Filename': '0008.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 6, 'transcription': 'peter peppers picked piper of peck', 'Viterbi transcription': 'peter peppers picked piper of peck', 'Decode speed': 2.2439870834350586, 'Backtrace speed': 0.00011730194091796875, 'Forward computations': 97388}
# 2.843188762664795
# 0.0002810955047607422
# {'Filename': '0009.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.125, 'Word Count': 8, 'transcription': 'a peck of pickled peppers peter piper pickled', 'Viterbi transcription': 'a peck of picked peppers peter piper pickled', 'Decode speed': 2.843188762664795, 'Backtrace speed': 0.0002810955047607422, 'Forward computations': 124048}
# 1.286353349685669
# 6.794929504394531e-05
# {'Filename': '0010.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'picked', 'Viterbi transcription': 'a picked', 'Decode speed': 1.286353349685669, 'Backtrace speed': 6.794929504394531e-05, 'Forward computations': 55228}
# 1.060511827468872
# 6.008148193359375e-05
# {'Filename': '0011.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'pickled', 'Viterbi transcription': 'a pickled', 'Decode speed': 1.060511827468872, 'Backtrace speed': 6.008148193359375e-05, 'Forward computations': 47168}
# 1.8406140804290771
# 0.00010156631469726562
# {'Filename': '0012.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'peppers', 'Viterbi transcription': 'a peppers', 'Decode speed': 1.8406140804290771, 'Backtrace speed': 0.00010156631469726562, 'Forward computations': 81578}
# 1.661069393157959
# 8.726119995117188e-05
# {'Filename': '0013.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'piper', 'Viterbi transcription': 'a piper', 'Decode speed': 1.661069393157959, 'Backtrace speed': 8.726119995117188e-05, 'Forward computations': 73518}
# 1.4891149997711182
# 9.226799011230469e-05
# {'Filename': '0014.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'peter', 'Viterbi transcription': 'a peter', 'Decode speed': 1.4891149997711182, 'Backtrace speed': 9.226799011230469e-05, 'Forward computations': 65768}
# 2.7395095825195312
# 0.00023412704467773438
# {'Filename': '0015.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's the peck of the pickled peppers", 'Decode speed': 2.7395095825195312, 'Backtrace speed': 0.00023412704467773438, 'Forward computations': 121258}
# 1.7204060554504395
# 9.226799011230469e-05
# {'Filename': '0016.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'a peter piper the picked', 'Decode speed': 1.7204060554504395, 'Backtrace speed': 9.226799011230469e-05, 'Forward computations': 76308}
# 3.8608832359313965
# 0.0003452301025390625
# {'Filename': '0017.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter of piper picked of peck of pickled peppers', 'Decode speed': 3.8608832359313965, 'Backtrace speed': 0.0003452301025390625, 'Forward computations': 168998}
# 1.8992910385131836
# 9.298324584960938e-05
# {'Filename': '0018.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'picked a peck of pickled peppers', 'Viterbi transcription': "a picked the peck of pickled peck where's", 'Decode speed': 1.8992910385131836, 'Backtrace speed': 9.298324584960938e-05, 'Forward computations': 84368}
# 3.509843587875366
# 0.00021195411682128906
# {'Filename': '0019.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'a peter piper a picked', 'Decode speed': 3.509843587875366, 'Backtrace speed': 0.00021195411682128906, 'Forward computations': 152878}
# 4.81929612159729
# 0.0004062652587890625
# {'Filename': '0020.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': "peppers picked peter piper where's the peck", 'Viterbi transcription': "a peppers picked peter piper the where's the the peck", 'Decode speed': 4.81929612159729, 'Backtrace speed': 0.0004062652587890625, 'Forward computations': 208678}
# 6.8529462814331055
# 0.0006234645843505859
# {'Filename': '0021.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 10, 'transcription': 'peter picked a peck piper pickled peppers of pickled peppers', 'Viterbi transcription': 'a peter peck picked of peck piper the of pickled the peppers of pickled peppers', 'Decode speed': 6.8529462814331055, 'Backtrace speed': 0.0006234645843505859, 'Forward computations': 295788}
# 5.11621880531311
# 0.0005273818969726562
# {'Filename': '0022.wav', 'Insertions': 9, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.25, 'Word Count': 8, 'transcription': 'peter piper piper peter peter peter piper piper', 'Viterbi transcription': 'a the picked peck piper the of piper the peter peter of peter of piper the piper', 'Decode speed': 5.11621880531311, 'Backtrace speed': 0.0005273818969726562, 'Forward computations': 221698}
# 3.249568462371826
# 0.00042819976806640625
# {'Filename': '0023.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 4, 'transcription': 'peter picked piper peppers', 'Viterbi transcription': 'a peter of picked piper peppers', 'Decode speed': 3.249568462371826, 'Backtrace speed': 0.00042819976806640625, 'Forward computations': 143888}
# 3.7045013904571533
# 0.00034999847412109375
# {'Filename': '0024.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'peter peter peter peter peter peter', 'Viterbi transcription': 'a peter peter peter peck peter picked pickled', 'Decode speed': 3.7045013904571533, 'Backtrace speed': 0.00034999847412109375, 'Forward computations': 160938}
# 3.7978250980377197
# 0.00033283233642578125
# {'Filename': '0025.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': 'piper picked a peck of peter peppers', 'Viterbi transcription': 'a a picked picked of peck of peter peppers a', 'Decode speed': 3.7978250980377197, 'Backtrace speed': 0.00033283233642578125, 'Forward computations': 166208}
# 3.6794273853302
# 0.0009024143218994141
# {'Filename': '0026.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'pickled peppers peter piper picked a peck of', 'Viterbi transcription': "a pickled of where's peter piper picked the peck of a", 'Decode speed': 3.6794273853302, 'Backtrace speed': 0.0009024143218994141, 'Forward computations': 160938}
# 4.477705001831055
# 0.0003628730773925781
# {'Filename': '0027.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'of peppers of picked a peter piper of', 'Viterbi transcription': "a of of where's of picked of peter piper of a", 'Decode speed': 4.477705001831055, 'Backtrace speed': 0.0003628730773925781, 'Forward computations': 195348}
# 2.834547758102417
# 0.00016498565673828125
# {'Filename': '0028.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 5, 'transcription': 'pickled peppers peter piper picked', 'Viterbi transcription': 'a pickled peppers picked of piper of peck', 'Decode speed': 2.834547758102417, 'Backtrace speed': 0.00016498565673828125, 'Forward computations': 124048}
# 2.857811450958252
# 0.00021004676818847656
# {'Filename': '0029.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': 'a a picked peck of peck of pickled peppers', 'Decode speed': 2.857811450958252, 'Backtrace speed': 0.00021004676818847656, 'Forward computations': 126528}
# 3.0707342624664307
# 0.0003097057342529297
# {'Filename': '0030.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': "where's a peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's of peck pickled peppers peter piper peck", 'Decode speed': 3.0707342624664307, 'Backtrace speed': 0.0003097057342529297, 'Forward computations': 134588}
# 1.7825629711151123
# 0.00010037422180175781
# {'Filename': '0031.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6, 'Word Count': 5, 'transcription': 'peter piper picked the peppers', 'Viterbi transcription': 'a picked piper picked of peppers', 'Decode speed': 1.7825629711151123, 'Backtrace speed': 0.00010037422180175781, 'Forward computations': 79098}
# 2.01863694190979
# 0.00011920928955078125
# {'Filename': '0032.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.8, 'Word Count': 5, 'transcription': 'pickled peppers picked peter piper', 'Viterbi transcription': "a pickled where's a picked piper", 'Decode speed': 2.01863694190979, 'Backtrace speed': 0.00011920928955078125, 'Forward computations': 89638}
# 2.076981782913208
# 0.0001087188720703125
# {'Filename': '0033.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 5, 'transcription': 'a peck of pickled peppers', 'Viterbi transcription': 'a peck of pickled peppers', 'Decode speed': 2.076981782913208, 'Backtrace speed': 0.0001087188720703125, 'Forward computations': 92118}
# 1.533750295639038
# 8.082389831542969e-05
# {'Filename': '0034.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': "where's the peck peter picked", 'Viterbi transcription': "a where's the peck peter picked", 'Decode speed': 1.533750295639038, 'Backtrace speed': 8.082389831542969e-05, 'Forward computations': 68248}
# 2.845684289932251
# 0.0001633167266845703
# {'Filename': '0035.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'pickled peppers piper picked', 'Viterbi transcription': 'a pickled peppers piper picked', 'Decode speed': 2.845684289932251, 'Backtrace speed': 0.0001633167266845703, 'Forward computations': 126528}
# 1.5939648151397705
# 8.392333984375e-05
# {'Filename': '0036.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': 'a peter picked peppers', 'Decode speed': 1.5939648151397705, 'Backtrace speed': 8.392333984375e-05, 'Forward computations': 71038}
# 2.7165822982788086
# 0.0002048015594482422
# {'Filename': '0037.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter piper picked peck of pickled peppers', 'Decode speed': 2.7165822982788086, 'Backtrace speed': 0.0002048015594482422, 'Forward computations': 118778}
# 2.647390127182007
# 0.0003006458282470703
# {'Filename': '0038.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter picked a picked picked picked pickled peppers', 'Decode speed': 2.647390127182007, 'Backtrace speed': 0.0003006458282470703, 'Forward computations': 115988}
# 2.2993311882019043
# 0.00013709068298339844
# {'Filename': '0039.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': 'peppers pickled peter of the piper peck', 'Viterbi transcription': 'a peppers pickled peter of the piper peck', 'Decode speed': 2.2993311882019043, 'Backtrace speed': 0.00013709068298339844, 'Forward computations': 102658}
# 3.2788643836975098
# 0.0001709461212158203
# {'Filename': '0040.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': "piper peter picked where's the pickled peppers peter", 'Viterbi transcription': "a peck peter picked where's the pickled peppers peter a", 'Decode speed': 3.2788643836975098, 'Backtrace speed': 0.0001709461212158203, 'Forward computations': 142338}
# 2.5094985961914062
# 0.0001289844512939453
# {'Filename': '0041.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'peck pickled piper of the peter peppers', 'Viterbi transcription': 'a peck pickled picked of the peter peppers', 'Decode speed': 2.5094985961914062, 'Backtrace speed': 0.0001289844512939453, 'Forward computations': 110718}
# 3.170191764831543
# 0.00016927719116210938
# {'Filename': '0042.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.09090909090909091, 'Word Count': 11, 'transcription': 'a peck of pickled peter picked the peppers of the peck', 'Viterbi transcription': 'a peck of pickled peter peck the peppers of the peck', 'Decode speed': 3.170191764831543, 'Backtrace speed': 0.00016927719116210938, 'Forward computations': 137068}
# 2.6300649642944336
# 0.00012922286987304688
# {'Filename': '0043.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': "where's the peck of peppers piper pickled", 'Viterbi transcription': "a where's of a of peppers piper of pickled", 'Decode speed': 2.6300649642944336, 'Backtrace speed': 0.00012922286987304688, 'Forward computations': 115988}
# 3.1023972034454346
# 0.00017952919006347656
# {'Filename': '0044.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'piper pickled peppers of the peck peter picked', 'Viterbi transcription': 'a piper of pickled peppers of the piper peter peck', 'Decode speed': 3.1023972034454346, 'Backtrace speed': 0.00017952919006347656, 'Forward computations': 134588}
# 3.0430901050567627
# 0.0001544952392578125
# {'Filename': '0045.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'piper peter picked pickled piper peppers', 'Viterbi transcription': "a pickled the where's pickled picked peppers", 'Decode speed': 3.0430901050567627, 'Backtrace speed': 0.0001544952392578125, 'Forward computations': 131798}
# 3.2357890605926514
# 0.00024199485778808594
# {'Filename': '0046.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.8181818181818182, 'Word Count': 11, 'transcription': 'peter picked peppers of the pickled peck of peppers of piper', 'Viterbi transcription': "a the a of where's of the pickled peck of peck where's of of the", 'Decode speed': 3.2357890605926514, 'Backtrace speed': 0.00024199485778808594, 'Forward computations': 142338}
# 5.657597541809082
# 0.001247406005859375
# {'Filename': '0047.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.4117647058823529, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a the pickled piper picked peck of picked of peppers where's the peck of picked peppers peter piper picked", 'Decode speed': 5.657597541809082, 'Backtrace speed': 0.001247406005859375, 'Forward computations': 248358}
# 3.1454386711120605
# 0.00018835067749023438
# {'Filename': '0048.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter piper picked the peck of pickled peppers', 'Decode speed': 3.1454386711120605, 'Backtrace speed': 0.00018835067749023438, 'Forward computations': 137068}
# 2.594852924346924
# 0.0001773834228515625
# {'Filename': '0049.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's the peck of picked of peppers peter piper picked", 'Decode speed': 2.594852924346924, 'Backtrace speed': 0.0001773834228515625, 'Forward computations': 113198}
# 2.4271717071533203
# 0.0001220703125
# {'Filename': '0050.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'pickled peppers pickled peter piper', 'Viterbi transcription': "a pickled of where's pickled picked piper", 'Decode speed': 2.4271717071533203, 'Backtrace speed': 0.0001220703125, 'Forward computations': 107928}
# 3.7414779663085938
# 0.0003116130828857422
# {'Filename': '0051.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.36363636363636365, 'Word Count': 11, 'transcription': 'peter piper picked a peck of pickled peppers peter piper pickled', 'Viterbi transcription': "a peter piper picked picked of pickled where's peter piper pickled", 'Decode speed': 3.7414779663085938, 'Backtrace speed': 0.0003116130828857422, 'Forward computations': 163728}
# 2.5008084774017334
# 0.00017571449279785156
# {'Filename': '0052.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a peter of piper picked peck of pickled where's", 'Decode speed': 2.5008084774017334, 'Backtrace speed': 0.00017571449279785156, 'Forward computations': 107928}
# 2.251340389251709
# 0.00015425682067871094
# {'Filename': '0053.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's of peck of pickled peppers", 'Decode speed': 2.251340389251709, 'Backtrace speed': 0.00015425682067871094, 'Forward computations': 97388}
# 2.0099499225616455
# 0.0001246929168701172
# {'Filename': '0054.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.75, 'Word Count': 4, 'transcription': 'piper peter peppers pickled', 'Viterbi transcription': "a piper of peter where's pickled", 'Decode speed': 2.0099499225616455, 'Backtrace speed': 0.0001246929168701172, 'Forward computations': 86848}
# 2.5476815700531006
# 0.0001316070556640625
# {'Filename': '0055.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5555555555555556, 'Word Count': 9, 'transcription': 'peter piper picked peter piper picked peter piper picked', 'Viterbi transcription': 'a peter of piper of picked peter of of picked peter piper picked', 'Decode speed': 2.5476815700531006, 'Backtrace speed': 0.0001316070556640625, 'Forward computations': 110718}
# 2.08184552192688
# 0.0001659393310546875
# {'Filename': '0056.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "where's the peck of peter piper peppers", 'Viterbi transcription': "a where's the peck of peter piper where's", 'Decode speed': 2.08184552192688, 'Backtrace speed': 0.0001659393310546875, 'Forward computations': 92118}
# 3.5208561420440674
# 0.00024390220642089844
# {'Filename': '0057.wav', 'Insertions': 1, 'Deletions': 2, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a picked piper pickled peck pickled peppers', 'Decode speed': 3.5208561420440674, 'Backtrace speed': 0.00024390220642089844, 'Forward computations': 152878}
# 2.5551180839538574
# 0.0001304149627685547
# {'Filename': '0058.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.625, 'Word Count': 8, 'transcription': 'the peck of pickled peppers picked peter piper', 'Viterbi transcription': "a the peck of the pickled of where's picked piper", 'Decode speed': 2.5551180839538574, 'Backtrace speed': 0.0001304149627685547, 'Forward computations': 113198}
# 3.1558375358581543
# 0.00017976760864257812
# {'Filename': '0059.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'piper picked peter the pickled peppers', 'Viterbi transcription': "a piper of picked peter the pickled picked where's", 'Decode speed': 3.1558375358581543, 'Backtrace speed': 0.00017976760864257812, 'Forward computations': 137068}
# 2.20855712890625
# 0.00011467933654785156
# {'Filename': '0060.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': 'peck piper peter pickled picked', 'Viterbi transcription': 'a peck piper peter of pickled peck', 'Decode speed': 2.20855712890625, 'Backtrace speed': 0.00011467933654785156, 'Forward computations': 97388}
# 2.5067596435546875
# 0.00013685226440429688
# {'Filename': '0061.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'peck peppers pickled peter piper', 'Viterbi transcription': 'a peck peppers pickled peter piper', 'Decode speed': 2.5067596435546875, 'Backtrace speed': 0.00013685226440429688, 'Forward computations': 110718}
# 6.4529383182525635
# 0.0007655620574951172
# {'Filename': '0062.wav', 'Insertions': 4, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter of piper a picked of picked of pickled peppers where's peck of pickled peppers picked of piper picked", 'Decode speed': 6.4529383182525635, 'Backtrace speed': 0.0007655620574951172, 'Forward computations': 279048}
# 3.6523611545562744
# 0.00022101402282714844
# {'Filename': '0063.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8571428571428571, 'Word Count': 7, 'transcription': "peter piper picked where's the peck of", 'Viterbi transcription': "a picked of piper a where's of peck pickled", 'Decode speed': 3.6523611545562744, 'Backtrace speed': 0.00022101402282714844, 'Forward computations': 158148}
# 5.274722576141357
# 0.0004703998565673828
# {'Filename': '0064.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 4, 'WER': 0.6666666666666666, 'Word Count': 12, 'transcription': 'pickled peppers pickled peppers peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a pickled where's pickled peppers picked of piper a of a of picked peppers", 'Decode speed': 5.274722576141357, 'Backtrace speed': 0.0004703998565673828, 'Forward computations': 230068}
# 3.8371360301971436
# 0.0006427764892578125
# {'Filename': '0065.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'the peck of pickled peppers peter piper picked', 'Viterbi transcription': 'a the of a of pickled peppers peter of piper a', 'Decode speed': 3.8371360301971436, 'Backtrace speed': 0.0006427764892578125, 'Forward computations': 166828}
# 3.582711696624756
# 0.00021982192993164062
# {'Filename': '0066.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a the the of piper picked of peck of pickled peppers', 'Decode speed': 3.582711696624756, 'Backtrace speed': 0.00021982192993164062, 'Forward computations': 155358}
# 5.330503463745117
# 0.0004439353942871094
# {'Filename': '0067.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'pickled peter peppers pickled peppers piper of piper', 'Viterbi transcription': 'a picked of peter the peppers pickled peppers piper of piper', 'Decode speed': 5.330503463745117, 'Backtrace speed': 0.0004439353942871094, 'Forward computations': 232238}
# 3.256502866744995
# 0.00022649765014648438
# {'Filename': '0068.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': "pickled where's peck peck peppers", 'Viterbi transcription': "a pickled where's peck picked peppers", 'Decode speed': 3.256502866744995, 'Backtrace speed': 0.00022649765014648438, 'Forward computations': 142338}
# 4.662954330444336
# 0.00042366981506347656
# {'Filename': '0069.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': 'picked pickled a pickled peter of peppers peppers piper', 'Viterbi transcription': 'a pickled pickled of pickled peter of of peppers peppers piper', 'Decode speed': 4.662954330444336, 'Backtrace speed': 0.00042366981506347656, 'Forward computations': 203408}
# 2.61252498626709
# 0.00028204917907714844
# {'Filename': '0070.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peck peppers picked piper', 'Viterbi transcription': 'a peck peppers picked piper', 'Decode speed': 2.61252498626709, 'Backtrace speed': 0.00028204917907714844, 'Forward computations': 115988}
# 2.9843132495880127
# 0.000186920166015625
# {'Filename': '0071.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'a peter pickled pickled picked', 'Viterbi transcription': 'a of peter of pickled pickled picked', 'Decode speed': 2.9843132495880127, 'Backtrace speed': 0.000186920166015625, 'Forward computations': 129318}
# 4.87156867980957
# 0.0004177093505859375
# {'Filename': '0072.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 5, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': 'peck peppers picked a picked peter a picked peppers', 'Viterbi transcription': "a of where's picked of a peter of pickled where's", 'Decode speed': 4.87156867980957, 'Backtrace speed': 0.0004177093505859375, 'Forward computations': 213018}
# 3.946007251739502
# 0.00028252601623535156
# {'Filename': '0073.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': "peck picked peppers peck picked where's of pickled", 'Viterbi transcription': "a peck picked where's peck picked where's of pickled", 'Decode speed': 3.946007251739502, 'Backtrace speed': 0.00028252601623535156, 'Forward computations': 172718}
# 3.252845048904419
# 0.0002269744873046875
# {'Filename': '0074.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.125, 'Word Count': 8, 'transcription': "a peter where's piper the picked picked peppers", 'Viterbi transcription': "a peter where's piper the pickled picked peppers", 'Decode speed': 3.252845048904419, 'Backtrace speed': 0.0002269744873046875, 'Forward computations': 140788}
# 3.891829252243042
# 0.0002460479736328125
# {'Filename': '0075.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'piper peck of peck pickled picked pickled of peter', 'Viterbi transcription': 'a piper of piper of peck pickled picked pickled of peter', 'Decode speed': 3.891829252243042, 'Backtrace speed': 0.0002460479736328125, 'Forward computations': 169618}
# 4.348187446594238
# 0.00030803680419921875
# {'Filename': '0076.wav', 'Insertions': 4, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': 'peck of peter peppers pickled peppers of picked peter', 'Viterbi transcription': "a peck of the the of peck where's pickled where's of picked", 'Decode speed': 4.348187446594238, 'Backtrace speed': 0.00030803680419921875, 'Forward computations': 189768}
# 5.0975518226623535
# 0.00040793418884277344
# {'Filename': '0077.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2222222222222222, 'Word Count': 9, 'transcription': 'peppers peck of peck peter picked a of peppers', 'Viterbi transcription': 'a peppers peck of peck peck peter picked a of peppers', 'Decode speed': 5.0975518226623535, 'Backtrace speed': 0.00040793418884277344, 'Forward computations': 221698}
# 4.060757398605347
# 0.00039076805114746094
# {'Filename': '0078.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.1111111111111111, 'Word Count': 9, 'transcription': 'a peck of the pickled peppers peter piper picked', 'Viterbi transcription': 'a of peck of the pickled peppers peter piper picked', 'Decode speed': 4.060757398605347, 'Backtrace speed': 0.00039076805114746094, 'Forward computations': 176748}
# 2.9500925540924072
# 0.00015878677368164062
# {'Filename': '0079.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.16666666666666666, 'Word Count': 6, 'transcription': 'piper picked peter of the peck', 'Viterbi transcription': 'a piper picked peter of the peck', 'Decode speed': 2.9500925540924072, 'Backtrace speed': 0.00015878677368164062, 'Forward computations': 129318}
# 3.8470711708068848
# 0.0003101825714111328
# {'Filename': '0080.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.125, 'Word Count': 8, 'transcription': 'a peter picked peck of picked pickled piper', 'Viterbi transcription': 'a peck peter picked peck of picked pickled piper', 'Decode speed': 3.8470711708068848, 'Backtrace speed': 0.0003101825714111328, 'Forward computations': 166208}
# 2.9324698448181152
# 0.00015974044799804688
# {'Filename': '0081.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': "where's peck peppers of piper", 'Viterbi transcription': "a where's peck peppers of piper", 'Decode speed': 2.9324698448181152, 'Backtrace speed': 0.00015974044799804688, 'Forward computations': 126528}
# 3.52786922454834
# 0.00020599365234375
# {'Filename': '0082.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 3, 'transcription': 'piper of peppers', 'Viterbi transcription': "a piper picked where's", 'Decode speed': 3.52786922454834, 'Backtrace speed': 0.00020599365234375, 'Forward computations': 152878}
# 2.6176507472991943
# 0.00013637542724609375
# {'Filename': '0083.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peter picked piper', 'Viterbi transcription': 'a peter picked picked piper', 'Decode speed': 2.6176507472991943, 'Backtrace speed': 0.00013637542724609375, 'Forward computations': 113198}
# 1.747185230255127
# 8.678436279296875e-05
# {'Filename': '0084.wav', 'Insertions': 1, 'Deletions': 4, 'Substitutions': 0, 'WER': 0.5555555555555556, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': 'pickled peppers peter of piper picked', 'Decode speed': 1.747185230255127, 'Backtrace speed': 8.678436279296875e-05, 'Forward computations': 76308}
# 2.3848366737365723
# 0.00011968612670898438
# {'Filename': '0085.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.36363636363636365, 'Word Count': 11, 'transcription': 'the peck of pickled peppers picked a peck of pickled peppers', 'Viterbi transcription': 'peck of pickled peppers picked of peck of peck of peppers', 'Decode speed': 2.3848366737365723, 'Backtrace speed': 0.00011968612670898438, 'Forward computations': 105448}
# 3.05796217918396
# 0.00018405914306640625
# {'Filename': '0086.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': "peter piper where's the peck of pickled peppers", 'Viterbi transcription': "peter of piper where's of peck of pickled peppers peter piper", 'Decode speed': 3.05796217918396, 'Backtrace speed': 0.00018405914306640625, 'Forward computations': 131798}
# 3.48032808303833
# 0.00020360946655273438
# {'Filename': '0087.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': 'peter piper peter piper a peck of pickled peppers', 'Viterbi transcription': "peter piper peter piper picked of pickled peck where's", 'Decode speed': 3.48032808303833, 'Backtrace speed': 0.00020360946655273438, 'Forward computations': 150398}
# 3.585752487182617
# 0.00021028518676757812
# {'Filename': '0088.wav', 'Insertions': 0, 'Deletions': 5, 'Substitutions': 2, 'WER': 0.4117647058823529, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "piper picked peck pickled peppers where's peck pickled where's peter picked picked", 'Decode speed': 3.585752487182617, 'Backtrace speed': 0.00021028518676757812, 'Forward computations': 155668}
# 4.289150238037109
# 0.00028824806213378906
# {'Filename': '0089.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.4117647058823529, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a picked of of the picked peck of pickled peppers where's the peck of picked peppers peter piper picked", 'Decode speed': 4.289150238037109, 'Backtrace speed': 0.00028824806213378906, 'Forward computations': 184808}
# 6.328891754150391
# 0.0005121231079101562
# {'Filename': '0090.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.23529411764705882, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter piper picked a peck of pickled peppers where's the peck of pickled picked where's peter piper peck picked", 'Decode speed': 6.328891754150391, 'Backtrace speed': 0.0005121231079101562, 'Forward computations': 271918}
# 1.537980318069458
# 7.62939453125e-05
# {'Filename': '0091.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 4, 'transcription': "where's the peck of", 'Viterbi transcription': "a where's of peck of", 'Decode speed': 1.537980318069458, 'Backtrace speed': 7.62939453125e-05, 'Forward computations': 65768}
# 1.6596477031707764
# 8.344650268554688e-05
# {'Filename': '0092.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'picked a peck of pickled', 'Viterbi transcription': 'a picked peck of pickled', 'Decode speed': 1.6596477031707764, 'Backtrace speed': 8.344650268554688e-05, 'Forward computations': 73518}
# 2.0167624950408936
# 0.00010275840759277344
# {'Filename': '0093.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': "pickled peppers where's the peck", 'Viterbi transcription': "a pickled peppers where's the peck", 'Decode speed': 2.0167624950408936, 'Backtrace speed': 0.00010275840759277344, 'Forward computations': 86848}
# 1.5975611209869385
# 8.106231689453125e-05
# {'Filename': '0094.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': "a peter picked peck where's", 'Decode speed': 1.5975611209869385, 'Backtrace speed': 8.106231689453125e-05, 'Forward computations': 71038}
# 2.1367783546447754
# 0.00010752677917480469
# {'Filename': '0095.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'peter pickled a picked peck', 'Viterbi transcription': 'a peter pickled picked peck', 'Decode speed': 2.1367783546447754, 'Backtrace speed': 0.00010752677917480469, 'Forward computations': 94908}
# 2.1901607513427734
# 0.00010704994201660156
# {'Filename': '0096.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': 'peter picked the peck of peppers', 'Viterbi transcription': 'a peter picked the peck peck of peppers', 'Decode speed': 2.1901607513427734, 'Backtrace speed': 0.00010704994201660156, 'Forward computations': 94908}
# 2.892425060272217
# 0.00015544891357421875
# {'Filename': '0097.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': 'peter picked a peck of the pickled peppers', 'Viterbi transcription': 'a peter piper picked the peck of the pickled peppers', 'Decode speed': 2.892425060272217, 'Backtrace speed': 0.00015544891357421875, 'Forward computations': 126528}
# 2.076000690460205
# 0.00010609626770019531
# {'Filename': '0098.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': 'the peck of peppers peter piper pickled', 'Viterbi transcription': "a the peck of peck where's peter piper pickled", 'Decode speed': 2.076000690460205, 'Backtrace speed': 0.00010609626770019531, 'Forward computations': 92118}
# 5.593000888824463
# 0.001384735107421875
# {'Filename': '0099.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2727272727272727, 'Word Count': 11, 'transcription': "the peck pickled peppers picked pickled peter of piper a where's", 'Viterbi transcription': "a the picked piper pickled peppers picked pickled peter of piper a where's", 'Decode speed': 5.593000888824463, 'Backtrace speed': 0.001384735107421875, 'Forward computations': 243088}
# 4.023693323135376
# 0.0002627372741699219
# {'Filename': '0100.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 10, 'transcription': 'the picked of piper picked of pickled a peter piper', 'Viterbi transcription': 'a the picked of piper picked of pickled a the peter piper', 'Decode speed': 4.023693323135376, 'Backtrace speed': 0.0002627372741699219, 'Forward computations': 174268}
# 6.35816764831543
# 0.0005707740783691406
# {'Filename': '0101.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.2857142857142857, 'Word Count': 14, 'transcription': "peck piper picked of picked pickled of where's a peppers peter peppers peter pickled", 'Viterbi transcription': "a picked piper picked of peter pickled of where's a the peppers peter peppers peter pickled", 'Decode speed': 6.35816764831543, 'Backtrace speed': 0.0005707740783691406, 'Forward computations': 277498}
# 2.508131504058838
# 0.0001289844512939453
# {'Filename': '0102.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peppers peck peter pickled', 'Viterbi transcription': 'a peppers peck peter pickled', 'Decode speed': 2.508131504058838, 'Backtrace speed': 0.0001289844512939453, 'Forward computations': 107928}
# 3.325901746749878
# 0.00019598007202148438
# {'Filename': '0103.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "where's piper picked piper a pickled peppers", 'Viterbi transcription': "a where's piper picked piper pickled peppers", 'Decode speed': 3.325901746749878, 'Backtrace speed': 0.00019598007202148438, 'Forward computations': 145128}
# 3.3766655921936035
# 0.0002148151397705078
# {'Filename': '0104.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'peter picked peppers of pickled peppers', 'Viterbi transcription': 'a peter picked a peppers of pickled picked a a', 'Decode speed': 3.3766655921936035, 'Backtrace speed': 0.0002148151397705078, 'Forward computations': 146678}
# 4.172361135482788
# 0.00027680397033691406
# {'Filename': '0105.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'peter peppers picked piper a peck of pickled peppers', 'Viterbi transcription': 'a peter peppers a piper peck of pickled peppers', 'Decode speed': 4.172361135482788, 'Backtrace speed': 0.00027680397033691406, 'Forward computations': 181088}
# 3.6984283924102783
# 0.0002353191375732422
# {'Filename': '0106.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a peter piper peck picked peck of pickled where's", 'Decode speed': 3.6984283924102783, 'Backtrace speed': 0.0002353191375732422, 'Forward computations': 160938}
# 3.4386281967163086
# 0.00020241737365722656
# {'Filename': '0107.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.375, 'Word Count': 8, 'transcription': "where's the peck of peppers peter piper picked", 'Viterbi transcription': "a where's the picked of peppers peter piper a", 'Decode speed': 3.4386281967163086, 'Backtrace speed': 0.00020241737365722656, 'Forward computations': 149468}
# 2.8147153854370117
# 0.00014972686767578125
# {'Filename': '0108.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'the peck of pickled peter piper pickled', 'Viterbi transcription': 'a peck of pickled peter piper of pickled', 'Decode speed': 2.8147153854370117, 'Backtrace speed': 0.00014972686767578125, 'Forward computations': 123738}
# 2.9212636947631836
# 0.00015401840209960938
# {'Filename': '0109.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': 'piper peter picked peppers of piper', 'Viterbi transcription': 'a piper peter picked peppers of piper a', 'Decode speed': 2.9212636947631836, 'Backtrace speed': 0.00015401840209960938, 'Forward computations': 126528}
# 2.6341819763183594
# 0.0001437664031982422
# {'Filename': '0110.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': 'peter peppers picked a piper of the peck', 'Viterbi transcription': 'a peter of peppers picked of piper of the peck', 'Decode speed': 2.6341819763183594, 'Backtrace speed': 0.0001437664031982422, 'Forward computations': 115988}
# 2.31557559967041
# 0.00011944770812988281
# {'Filename': '0111.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'peck of picked peter piper picked', 'Viterbi transcription': 'a picked of picked peter of piper of picked', 'Decode speed': 2.31557559967041, 'Backtrace speed': 0.00011944770812988281, 'Forward computations': 102658}
# 2.328995704650879
# 0.00011610984802246094
# {'Filename': '0112.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': 'picked the peppers peter pickled', 'Viterbi transcription': 'a a the peppers peter of pickled', 'Decode speed': 2.328995704650879, 'Backtrace speed': 0.00011610984802246094, 'Forward computations': 100178}
# 2.659107208251953
# 0.00014162063598632812
# {'Filename': '0113.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'the piper of peck peppers peter picked', 'Viterbi transcription': 'a the piper of peck peppers peter of picked', 'Decode speed': 2.659107208251953, 'Backtrace speed': 0.00014162063598632812, 'Forward computations': 115988}
# 6.1562793254852295
# 0.00048542022705078125
# {'Filename': '0114.wav', 'Insertions': 0, 'Deletions': 5, 'Substitutions': 2, 'WER': 0.875, 'Word Count': 8, 'transcription': 'piper picked peter a pickled peck of peppers', 'Viterbi transcription': "a where's where's", 'Decode speed': 6.1562793254852295, 'Backtrace speed': 0.00048542022705078125, 'Forward computations': 266648}
# 2.8626012802124023
# 0.00016021728515625
# {'Filename': '0115.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': "where's peter piper", 'Viterbi transcription': "a where's the the piper", 'Decode speed': 2.8626012802124023, 'Backtrace speed': 0.00016021728515625, 'Forward computations': 124048}
# 3.8001348972320557
# 0.0002880096435546875
# {'Filename': '0116.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 6, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': 'piper picked the peck of pickled peppers peter picked', 'Viterbi transcription': "a of a picked of peck pickled of where's picked picked", 'Decode speed': 3.8001348972320557, 'Backtrace speed': 0.0002880096435546875, 'Forward computations': 163728}
# 3.2261929512023926
# 0.0001811981201171875
# ...
# 2.905104398727417
# 0.0002090930938720703
# {'Filename': '0153.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': "where's the peck of peppers peter piper picked", 'Viterbi transcription': "a where's of peck of peppers peter piper picked", 'Decode speed': 2.905104398727417, 'Backtrace speed': 0.0002090930938720703, 'Forward computations': 126528}
# 3.1713759899139404
# 0.0002429485321044922
# {'Filename': '0154.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a picked picked piper picked of peck of pickled peppers', 'Decode speed': 3.1713759899139404, 'Backtrace speed': 0.0002429485321044922, 'Forward computations': 139858}
# 2.542585849761963
# 0.00016570091247558594
# {'Filename': '0155.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'a peck of pickled peppers', 'Viterbi transcription': 'a of peck of pickled peppers', 'Decode speed': 2.542585849761963, 'Backtrace speed': 0.00016570091247558594, 'Forward computations': 110718}
# 2.357534885406494
# 0.00016498565673828125
# {'Filename': '0156.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.75, 'Word Count': 4, 'transcription': 'peter piper picked peppers', 'Viterbi transcription': 'a the of piper of peter peck of', 'Decode speed': 2.357534885406494, 'Backtrace speed': 0.00016498565673828125, 'Forward computations': 102658}
# 3.3449113368988037
# 0.00024127960205078125
# {'Filename': '0157.wav', 'Insertions': 5, 'Deletions': 1, 'Substitutions': 3, 'WER': 1.0, 'Word Count': 9, 'transcription': "peter piper picked where's the peck of pickled peppers", 'Viterbi transcription': "a peter of peck of picked where's the pickled pickled peck peck picked", 'Decode speed': 3.3449113368988037, 'Backtrace speed': 0.00024127960205078125, 'Forward computations': 145128}
# 3.5843024253845215
# 0.0002605915069580078
# {'Filename': '0158.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a picked piper peter peck of pickled peck peppers', 'Decode speed': 3.5843024253845215, 'Backtrace speed': 0.0002605915069580078, 'Forward computations': 155668}
# 3.8736562728881836
# 0.00030517578125
# {'Filename': '0159.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2222222222222222, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': 'a peppers the peck of pickled peppers peter piper picked', 'Decode speed': 3.8736562728881836, 'Backtrace speed': 0.00030517578125, 'Forward computations': 168998}
# 3.3895299434661865
# 0.00025463104248046875
# {'Filename': '0160.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.875, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a a of piper of picked of peck of pickled piper where's", 'Decode speed': 3.3895299434661865, 'Backtrace speed': 0.00025463104248046875, 'Forward computations': 147608}
# 3.330728054046631
# 0.0007357597351074219
# {'Filename': '0161.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.7777777777777778, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's of piper of pickled piper where's peter piper of the", 'Decode speed': 3.330728054046631, 'Backtrace speed': 0.0007357597351074219, 'Forward computations': 145128}
# 3.451324462890625
# 0.0002715587615966797
# {'Filename': '0162.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.1428571428571428, 'Word Count': 7, 'transcription': 'peck of pickled peppers peter piper picked', 'Viterbi transcription': "a piper of pickled piper where's picked of piper of the", 'Decode speed': 3.451324462890625, 'Backtrace speed': 0.0002715587615966797, 'Forward computations': 150398}
# 3.0999348163604736
# 0.00023174285888671875
# {'Filename': '0163.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.75, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a peter piper of picked of piper of pickled piper where's", 'Decode speed': 3.0999348163604736, 'Backtrace speed': 0.00023174285888671875, 'Forward computations': 137068}
# 2.725062131881714
# 0.00019598007202148438
# {'Filename': '0164.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 5, 'transcription': 'peter piper picked pickled peppers', 'Viterbi transcription': "a peter of piper of picked pickled piper where's", 'Decode speed': 2.725062131881714, 'Backtrace speed': 0.00019598007202148438, 'Forward computations': 118778}
# 1.771474838256836
# 0.00010418891906738281
# {'Filename': '0165.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'a peter picked picked picked', 'Decode speed': 1.771474838256836, 'Backtrace speed': 0.00010418891906738281, 'Forward computations': 76308}
# 3.101135015487671
# 0.00022983551025390625
# {'Filename': '0166.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a the of piper picked of peck of pickled peppers', 'Decode speed': 3.101135015487671, 'Backtrace speed': 0.00022983551025390625, 'Forward computations': 137068}
# 2.5482125282287598
# 0.00017023086547851562
# {'Filename': '0167.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 6, 'transcription': 'picked a peck of pickled peppers', 'Viterbi transcription': 'a a the of peck of pickled peppers', 'Decode speed': 2.5482125282287598, 'Backtrace speed': 0.00017023086547851562, 'Forward computations': 110718}
# 2.302436351776123
# 0.00015115737915039062
# {'Filename': '0168.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's the picked of pickled peppers", 'Decode speed': 2.302436351776123, 'Backtrace speed': 0.00015115737915039062, 'Forward computations': 100178}
# 3.686152219772339
# 0.0002892017364501953
# {'Filename': '0169.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.3, 'Word Count': 10, 'transcription': "peter piper picked a peck where's the peck peter picked", 'Viterbi transcription': "a peter piper picked of peck where's peck peter picked", 'Decode speed': 3.686152219772339, 'Backtrace speed': 0.0002892017364501953, 'Forward computations': 160938}
# 2.7480385303497314
# 0.00019168853759765625
# {'Filename': '0170.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': 'peter piper picked pickled peppers', 'Viterbi transcription': 'a picked piper picked pickled peppers', 'Decode speed': 2.7480385303497314, 'Backtrace speed': 0.00019168853759765625, 'Forward computations': 121258}
# 3.6985809803009033
# 0.0003101825714111328
# {'Filename': '0171.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.75, 'Word Count': 8, 'transcription': "peter piper picked pickled peppers where's the peck", 'Viterbi transcription': "a picked piper picked pickled the piper where's where's the piper", 'Decode speed': 3.6985809803009033, 'Backtrace speed': 0.0003101825714111328, 'Forward computations': 160938}
# 4.060185670852661
# 0.0003654956817626953
# {'Filename': '0172.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's the peck pickled piper peter piper picked", 'Decode speed': 4.060185670852661, 'Backtrace speed': 0.0003654956817626953, 'Forward computations': 176748}
# 3.230208396911621
# 0.00023484230041503906
# {'Filename': '0173.wav', 'Insertions': 4, 'Deletions': 1, 'Substitutions': 3, 'WER': 1.0, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a picked of piper peck a of peck pickled piper where's", 'Decode speed': 3.230208396911621, 'Backtrace speed': 0.00023484230041503906, 'Forward computations': 139858}
# 6.104214191436768
# 0.0005643367767333984
# {'Filename': '0174.wav', 'Insertions': 1, 'Deletions': 2, 'Substitutions': 5, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a picked piper picked of peck pickled peppers where's the pickled pickled pickled peter peter picked", 'Decode speed': 6.104214191436768, 'Backtrace speed': 0.0005643367767333984, 'Forward computations': 264168}
# 2.3300349712371826
# 0.0003616809844970703
# {'Filename': '0175.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 2, 'transcription': 'peter piper', 'Viterbi transcription': 'a peter piper', 'Decode speed': 2.3300349712371826, 'Backtrace speed': 0.0003616809844970703, 'Forward computations': 102658}
# 1.9037902355194092
# 0.00010395050048828125
# {'Filename': '0176.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.5, 'Word Count': 2, 'transcription': 'pickled peppers', 'Viterbi transcription': "a pickled picked where's", 'Decode speed': 1.9037902355194092, 'Backtrace speed': 0.00010395050048828125, 'Forward computations': 84368}
# 6.630987167358398
# 0.0005996227264404297
# {'Filename': '0177.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's the peter pickled of pickled of peppers peter a piper picked a", 'Decode speed': 6.630987167358398, 'Backtrace speed': 0.0005996227264404297, 'Forward computations': 285248}
# 1.776108980178833
# 9.655952453613281e-05
# {'Filename': '0178.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 2.5, 'Word Count': 2, 'transcription': 'pickled peppers', 'Viterbi transcription': "a a where's of where's", 'Decode speed': 1.776108980178833, 'Backtrace speed': 9.655952453613281e-05, 'Forward computations': 76308}
# 4.458225965499878
# 0.0005600452423095703
# {'Filename': '0179.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'picked a peck of pickled peppers', 'Viterbi transcription': 'a a pickled pickled a pickled peppers', 'Decode speed': 4.458225965499878, 'Backtrace speed': 0.0005600452423095703, 'Forward computations': 192558}
# 3.5143299102783203
# 0.0002512931823730469
# {'Filename': '0180.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter of peter picked of peck of pickled peppers', 'Decode speed': 3.5143299102783203, 'Backtrace speed': 0.0002512931823730469, 'Forward computations': 152878}
# 4.19672703742981
# 0.0003056526184082031
# {'Filename': '0181.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'the peck of pickled peppers peter piper picked', 'Viterbi transcription': 'a the of peck of pickled peppers peter peter the', 'Decode speed': 4.19672703742981, 'Backtrace speed': 0.0003056526184082031, 'Forward computations': 182018}
# 2.918480396270752
# 0.00016951560974121094
# {'Filename': '0182.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.75, 'Word Count': 4, 'transcription': 'peter picked pickled peppers', 'Viterbi transcription': 'a peter of pickled pickled peppers', 'Decode speed': 2.918480396270752, 'Backtrace speed': 0.00016951560974121094, 'Forward computations': 126528}
# 2.990814447402954
# 0.00016546249389648438
# {'Filename': '0183.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.16666666666666666, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's the peck of pickled peppers", 'Decode speed': 2.990814447402954, 'Backtrace speed': 0.00016546249389648438, 'Forward computations': 129318}
# 2.3806841373443604
# 0.00012111663818359375
# {'Filename': '0184.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'a peck of pickled peppers', 'Viterbi transcription': 'a of peck of pickled peppers', 'Decode speed': 2.3806841373443604, 'Backtrace speed': 0.00012111663818359375, 'Forward computations': 102658}
# 3.2591795921325684
# 0.0002002716064453125
# {'Filename': '0185.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'piper picked a peck of peter', 'Viterbi transcription': 'a a picked the the peck peter', 'Decode speed': 3.2591795921325684, 'Backtrace speed': 0.0002002716064453125, 'Forward computations': 140788}
# 2.8529419898986816
# 0.00016236305236816406
# {'Filename': '0186.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'peter pickled a peck of peppers', 'Viterbi transcription': "a peter pickled peck of of where's", 'Decode speed': 2.8529419898986816, 'Backtrace speed': 0.00016236305236816406, 'Forward computations': 123738}
# 1.8902204036712646
# 0.00010728836059570312
# {'Filename': '0187.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 3, 'transcription': 'piper pickled peter', 'Viterbi transcription': 'a piper a pickled peter a', 'Decode speed': 1.8902204036712646, 'Backtrace speed': 0.00010728836059570312, 'Forward computations': 83438}
# 2.403909683227539
# 0.00013756752014160156
# {'Filename': '0188.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': "where's peter piper pickled peppers", 'Viterbi transcription': "a where's peter piper a pickled peppers", 'Decode speed': 2.403909683227539, 'Backtrace speed': 0.00013756752014160156, 'Forward computations': 106378}
# 2.990953207015991
# 0.0001704692840576172
# {'Filename': '0189.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'piper peter picked peppers picked peter', 'Viterbi transcription': "a piper peter a a where's a peter", 'Decode speed': 2.990953207015991, 'Backtrace speed': 0.0001704692840576172, 'Forward computations': 129318}
# 8.381034851074219
# 0.0007987022399902344
# {'Filename': '0190.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "piper pickled picked peppers of picked a pickled piper the peppers peck of peter peter peck where's", 'Viterbi transcription': "a piper of pickled picked peppers of picked of pickled picked of the picked of where's peck of peter peter peck where's", 'Decode speed': 8.381034851074219, 'Backtrace speed': 0.0007987022399902344, 'Forward computations': 362128}
# 9.733365297317505
# 0.0009527206420898438
# {'Filename': '0191.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.4117647058823529, 'Word Count': 17, 'transcription': "a peter the of peck where's piper peter picked pickled picked peppers pickled of peck peppers piper", 'Viterbi transcription': "a of peter pickled of peck where's piper of peter picked pickled pickled of where's pickled of peck where's piper", 'Decode speed': 9.733365297317505, 'Backtrace speed': 0.0009527206420898438, 'Forward computations': 417618}

# %%
#task 3 pruning

#attempt using beam search
"""
what is beam search?




"""
class PrunedViterbiDecoder:
    
    
    NLL_ZERO = 1e10# define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    
    def __init__(self, f, audio_file_name,beam=30, beam_type = "size"):
        """Set up the decoder class with an audio file and WFST f
        """
        self.NLL_ZERO = 1e10
        self.om = observation_model.ObservationModel()
        self.f = f
        self.beam = beam
        self.beam_type = beam_type
        if beam_type != "size" and beam_type != "width":
            raise Exception("beam_type must be of size or width")
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
        
        forward_computations = 0
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                for arc in self.f.arcs(i):
                    
                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        forward_computations += 1
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            self.V[t][j] = prob
                            self.B[t][j] = i
                            
                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
                                
        if self.beam_type == "width":
            minimum_state_value = min(self.V[t])
            print(minimum_state_value)
            for j in range(self.f.num_states()):
                if self.V[t][j] > -math.log(self.beam) + minimum_state_value:
                    self.V[t][j] = self.NLL_ZERO 
            print(minimum_state_value)
        
        if self.beam_type == "size": 
            sorted_values = sorted(self.V[t])
            beam = min(self.beam, len(self.V[t]))
            threshold = sorted_values[self.beam - 1]
            for j in range(f.num_states()):
                if self.V[t][j] > threshold:
                    self.V[t][j] = self.NLL_ZERO 
        
                                
        return forward_computations
                            
    
    def finalise_decoding(self):
        """ this incorporates the probability of terminating at each state
        """
        
        for state in self.f.states():
            final_weight = float(self.f.final(state))
            if self.V[-1][state] != self.NLL_ZERO:
                if final_weight == math.inf:
                    self.V[-1][state] = self.NLL_ZERO  # effectively says that we can't end in this state
                else:
                    self.V[-1][state] += final_weight
                    
        # get a list of all states where there was a path ending with non-zero probability
        finished = [x for x in self.V[-1] if x < self.NLL_ZERO]
        if not finished:  # if empty
            print("No path got to the end of the observations.")
        
        
    def decode(self):
        forward_computations = 0
        initial = time.time()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            forward_computations += self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            t += 1
        self.finalise_decoding()
        final=time.time()
        return (forward_computations, (final - initial))
    
    def backtrace(self):
        
        initial = time.time()
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        
        
        final = time.time()
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence =' '.join([ self.f.output_symbols().find(label) for label in best_out_sequence])
        
        return (best_state_sequence, best_out_sequence,(final-initial))

# %%
f=create_wfst(3)
draw_fst(f)

# %%
#TASK 2, changing self-loop probabilities


print(num_states(f))
print(total_num_arcs(f))
f=create_wfst_silent(3,probabilities,next_state_prob=0.1,sil_prob=0.5)
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'): 
    break# replace path if using your own
                                                                      # audio files
    decoder = PrunedViterbiDecoder(f, wav_file,beam=50,beam_type="size")
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_pruned_size_50.csv')
# Out:
# 116
# 230

# %%
#task 4
#Bigram Probabilities

from collections import defaultdict
bigram_count=defaultdict(int)
word_count = defaultdict(int)


for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    transcription = read_transcription(wav_file)
    transcription = "<s> "+ str(transcription)+" </s>"
    transcription = transcription.split(" ")
    for i in range(0,len(transcription)-1):
        bigram = transcription[i]+ " "+transcription[i+1]
        bigram_count[bigram]+=1
        word_count[transcription[i]]+=1
bigram_prob = {}

for bigram in bigram_count.keys():
    word = bigram.split()[0]

    bigram_prob[bigram]= bigram_count[bigram] / word_count[word]
bigram_prob

# probabilities ={bigram:count/total_words for word,count in word_count.items()}
# print(word_count,bigram_probabilities)
# Out:
# {'<s> peter': 0.3677811550151976,
#  'peter piper': 0.5384615384615384,
#  'piper picked': 0.5501730103806228,
#  'picked a': 0.2972027972027972,
#  'a peck': 0.7608695652173914,
#  'peck of': 0.7083333333333334,
#  'of pickled': 0.6219512195121951,
#  'pickled peppers': 0.6947368421052632,
#  "peppers where's": 0.09968847352024922,
#  "where's the": 0.6864406779661016,
#  'the peck': 0.6861313868613139,
#  'peppers peter': 0.24922118380062305,
#  'picked </s>': 0.34265734265734266,
#  'peter picked': 0.17751479289940827,
#  'peppers </s>': 0.3707165109034268,
#  '<s> a': 0.07598784194528875,
#  'peppers picked': 0.07476635514018691,
#  'piper peter': 0.0657439446366782,
#  'piper </s>': 0.12802768166089964,
#  "<s> where's": 0.1762917933130699,
#  'piper pickled': 0.07958477508650519,
#  "where's peter": 0.1440677966101695,
#  'peter </s>': 0.08284023668639054,
#  '<s> piper': 0.1033434650455927,
#  'picked peppers': 0.09090909090909091,
#  'peppers of': 0.056074766355140186,
#  'of peter': 0.04878048780487805,
#  'peter peppers': 0.04142011834319527,
#  'picked piper': 0.045454545454545456,
#  'piper of': 0.04152249134948097,
#  'of peck': 0.044715447154471545,
#  'peck </s>': 0.07954545454545454,
#  'pickled </s>': 0.06666666666666667,
#  '<s> picked': 0.030395136778115502,
#  '<s> pickled': 0.0851063829787234,
#  '<s> peppers': 0.0364741641337386,
#  'picked peter': 0.08041958041958042,
#  "piper where's": 0.031141868512110725,
#  'peck piper': 0.01893939393939394,
#  'piper piper': 0.01384083044982699,
#  'peter peter': 0.05029585798816568,
#  'piper peppers': 0.02768166089965398,
#  'of </s>': 0.02032520325203252,
#  '<s> of': 0.0121580547112462,
#  'of peppers': 0.11788617886178862,
#  'of picked': 0.032520325203252036,
#  'a peter': 0.07971014492753623,
#  "where's a": 0.0423728813559322,
#  'picked the': 0.03496503496503497,
#  'the peppers': 0.10948905109489052,
#  'peck peter': 0.045454545454545456,
#  'peppers piper': 0.04672897196261682,
#  'peppers pickled': 0.04672897196261682,
#  'pickled peter': 0.08421052631578947,
#  'peter of': 0.026627218934911243,
#  'of the': 0.044715447154471545,
#  'the piper': 0.043795620437956206,
#  'piper peck': 0.031141868512110725,
#  "picked where's": 0.017482517482517484,
#  'the pickled': 0.10948905109489052,
#  '<s> peck': 0.060790273556231005,
#  'peck pickled': 0.041666666666666664,
#  'pickled piper': 0.031578947368421054,
#  'the peter': 0.014598540145985401,
#  'picked pickled': 0.06293706293706294,
#  'pickled peck': 0.017543859649122806,
#  'of piper': 0.04065040650406504,
#  '<s> the': 0.05167173252279635,
#  'peter the': 0.008875739644970414,
#  'peter pickled': 0.03550295857988166,
#  'pickled picked': 0.031578947368421054,
#  'peck peppers': 0.03409090909090909,
#  "pickled where's": 0.007017543859649123,
#  "where's peck": 0.025423728813559324,
#  'peck peck': 0.003787878787878788,
#  'pickled a': 0.021052631578947368,
#  'a pickled': 0.043478260869565216,
#  'peppers peppers': 0.018691588785046728,
#  'pickled pickled': 0.007017543859649123,
#  'a picked': 0.028985507246376812,
#  'peter a': 0.011834319526627219,
#  'peck picked': 0.026515151515151516,
#  'peppers peck': 0.028037383177570093,
#  "where's of": 0.01694915254237288,
#  "peter where's": 0.014792899408284023,
#  "where's piper": 0.025423728813559324,
#  'piper the': 0.01384083044982699,
#  'the picked': 0.021897810218978103,
#  'picked picked': 0.0034965034965034965,
#  'pickled of': 0.021052631578947368,
#  'a of': 0.007246376811594203,
#  'picked peck': 0.01048951048951049,
#  'piper a': 0.01730103806228374,
#  "a where's": 0.007246376811594203,
#  "where's </s>": 0.01694915254237288,
#  'picked of': 0.013986013986013986,
#  "of where's": 0.012195121951219513,
#  'a peppers': 0.014492753623188406,
#  'a piper': 0.057971014492753624,
#  'of a': 0.008130081300813009,
#  "where's pickled": 0.01694915254237288,
#  "peck where's": 0.011363636363636364,
#  'peter peck': 0.011834319526627219,
#  'the of': 0.0072992700729927005,
#  'pickled the': 0.017543859649122806,
#  'peck the': 0.01893939393939394,
#  'the a': 0.0072992700729927005,
#  'of of': 0.008130081300813009,
#  "where's peppers": 0.01694915254237288,
#  'peppers a': 0.006230529595015576,
#  "where's picked": 0.00847457627118644,
#  'peck a': 0.011363636363636364,
#  'peppers the': 0.003115264797507788}

# %%
#task 4 reducing the number of states in wfst by having silence be connected for all
def create_wfst_silent_2(n, probabilities=None, next_state_prob=0.5, sil_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs."""
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))


    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    
    this_state = f.add_state()
    first_sil = this_state
    for i in range(1,6):
        weight = fst.Weight('log',-math.log(1-next_state_prob))
        
        f.add_arc(this_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0, weight, this_state))
        next_state= f.add_state()
        weight = fst.Weight('log',-math.log(next_state_prob))
        f.add_arc(this_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
        this_state=next_state
    
    weight = fst.Weight('log',-math.log(1))
    f.add_arc(this_state,fst.Arc(0,0, weight, start_state))

    
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            last_state = current_state
            current_state = generate_phone_wfst(f, current_state, phone, n, 0.5)
            
        weight = fst.Weight('log',-math.log(1-sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,start_state))
        weight = fst.Weight('log',-math.log(sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,first_sil))
        
        

        

            
            
            

    f.set_input_symbols(silent_state_table)
    f.set_output_symbols(word_table)


    return f

    
f=create_wfst_silent_2(3)
draw_fst(f)

# %%
print(num_states(f))
print(total_num_arcs(f))
f=create_wfst_silent(3,probabilities,next_state_prob=0.1,sil_prob=0.5)
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                                                                  # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_silent_new.csv')
# Out:
# 122
# 251

# %%
#task 4 tree structure diagrams
def generate_phone_wfst_tree(f, start_state, phone, n):
    """
    Generate a WFST representing an n-state left-to-right phone HMM.
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assumed to exist already
        phone (str): the phone label 
        n (int): number of states of the HMM excluding start and end
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
    
        in_label = state_table.find('{}_{}'.format(phone, i))
        sl_weight = fst.Weight('log', -math.log(1))
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, sl_weight, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        
        out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        next_weight = fst.Weight('log', -math.log(1))
        f.add_arc(current_state, fst.Arc(in_label, out_label, next_weight, next_state))    
       
        current_state = next_state
    return current_state


def generate_tree_wfst(lex,sil_prob=0.5,next_state_prob=0.5):
    """Express the  in WFST form.

    Args:
        lex (dict): lexicon to use, created from the parse_lexicon() function.
    
    Returns:
        the constructed lexicon WFST.
    """
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))

    L = fst.Fst('log')
    
    # Create a single start state
    start_state = L.add_state()
    L.set_start(start_state)
    L.set_final(start_state)
    
    # Dictionary to check if an arc already exists (current_state, phone) -> next_state
    state_transitions = {}
    
    for word, pron in lex.items():
        
        
        current_state = start_state
        for i, phone in enumerate(pron):
            # Check if this (state, phone) pair has an existing next state
            if (current_state, phone) in state_transitions:
                next_state = state_transitions[(current_state, phone)]
            else:
                next_state= L.add_state()
                L.add_arc(current_state, fst.Arc(0,0, fst.Weight('log',-math.log(1)), next_state))
                c_state=next_state
                
                next_state = generate_phone_wfst_tree(L, c_state, phone, 3)
                state_transitions[(current_state, phone)] = next_state
                
                
            
            current_state = next_state
                          
        
        L.add_arc(current_state, fst.Arc(0,word_table.find(word) , fst.Weight('log',-math.log(1)), start_state))  
        weight = fst.Weight('log',-math.log(sil_prob*(1)))
         
        L.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'),0,weight,current_state))
        next_state =L.add_state()
        weight = fst.Weight('log',-math.log(sil_prob*((1))))
        L.add_arc(current_state,fst.Arc(silent_state_table.find('sil_1'),0,weight,next_state))
        current_state=next_state
        
        
        for i in range(2,6):
            weight = fst.Weight('log',-math.log(1))
            L.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
            next_state =L.add_state()
            weight = fst.Weight('log',-math.log(1))
            L.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
            current_state=next_state
        print(word, word_table.find(word))

            
            
            
            
            
        
        
        
        next_weight = fst.Weight('log', -math.log(1))
        L.add_arc(current_state, fst.Arc(0, word_table.find(word),next_weight , start_state))
        
        
        
        
    L.set_input_symbols(silent_state_table)
    L.set_output_symbols(word_table)                      
    
    return L

L = generate_tree_wfst(lex)
L.arcsort()

def generate_probability_tree(lex, probabilities):
    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        
        # note: new current_state is now set to the final state of the previous phone WFST
        
        next_weight = fst.Weight('log', -math.log(1))
        out_label = word_table.find(word)
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))

    f.set_input_symbols(state_table)
    f.set_output_symbols(word_table)

    return f




draw_fst(L)
# Out:
# a 1
# of 2
# peck 3
# peppers 4
# peter 5
# picked 6
# pickled 7
# piper 8
# the 9
# where's 10

# %%
Ldet = fst.determinize(L)
draw_fst(Ldet)

# %%
f=create_wfst(3)

# %%
print(num_states(f))
print(total_num_arcs(f))
f=generate_tree_wfst(3,)
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                      # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_silent_new.csv')

# %%
from copy import deepcopy
def create_wfst_silent_word(n, probabilities=None, next_state_prob=0.5, sil_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs."""
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))


    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            last_state = current_state
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
            
        weight = fst.Weight('log',-math.log(1-sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,start_state))
        weight = fst.Weight('log',-math.log(sil_prob*(1-next_state_prob)))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
        next_state =f.add_state()
        weight = fst.Weight('log',-math.log(sil_prob*((1-next_state_prob))))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
        current_state=next_state
        
        
        for i in range(2,6):
            weight = fst.Weight('log',-math.log(1-next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
            next_state =f.add_state()
            weight = fst.Weight('log',-math.log(next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
            current_state=next_state
        

            
            
            
            
            
        
        
        
        next_weight = fst.Weight('log', -math.log(1))
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))
    f.set_input_symbols(silent_state_table)
    f.set_output_symbols(word_table)


    return f


f=create_wfst_silent_word(3,next_state_prob=0.1,sil_prob=0.5)
draw_fst(f)
