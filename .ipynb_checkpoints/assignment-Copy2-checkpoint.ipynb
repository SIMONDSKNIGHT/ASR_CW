# %% [markdown]
# # ASR Assignment 2022-23
#
# This notebook has been provided as a template to get you started on the assignment.  Feel free to use it for your development, or do your development directly in Python.
#
# You can find a full description of the assignment [here](http://www.inf.ed.ac.uk/teaching/courses/asr/2022-23/coursework.pdf).
#
# You are provided with two Python modules `observation_model.py` and `wer.py`.  The first was described in [Lab 3](https://github.com/ZhaoZeyu1995/asr_labs/blob/master/asr_lab3_4.ipynb).  The second can be used to compute the number of substitution, deletion and insertion errors between ASR output and a reference text.
#
# It can be used as follows:
#
# ```python
# import wer
#
# my_refence = 'A B C'
# my_output = 'A C C D'
#
# wer.compute_alignment_errors(my_reference, my_output)
# ```
#
# This produces a tuple $(s,d,i)$ giving counts of substitution,
# deletion and insertion errors respectively - in this example (1, 0, 1).  The function accepts either two strings, as in the example above, or two lists.  Matching is case sensitive.
#
# ## Template code
#
# Assuming that you have already made a function to generate an WFST, `create_wfst()` and a decoder class, `MyViterbiDecoder`, you can perform recognition on all the audio files as follows:

# %%
import glob
import os
import wer
import observation_model
import openfst_python as fst

# ... (add your code to create WFSTs and Viterbi Decoder)
import observation_model
import math
import openfst_python as fst
import time

class MyViterbiDecoder:
    
    NLL_ZERO = 1e10  # define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    
    def __init__(self, f, audio_file_name):
        """Set up the decoder class with an audio file and WFST f
        """
        self.om = observation_model.ObservationModel()
        self.f = f
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
        
        forward_computations = 0
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                for arc in self.f.arcs(i):
                    
                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        forward_computations += 1
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            self.V[t][j] = prob
                            self.B[t][j] = i
                            
                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
        return forward_computations
                            
    
    def finalise_decoding(self):
        """ this incorporates the probability of terminating at each state
        """
        
        for state in self.f.states():
            final_weight = float(self.f.final(state))
            if self.V[-1][state] != self.NLL_ZERO:
                if final_weight == math.inf:
                    self.V[-1][state] = self.NLL_ZERO  # effectively says that we can't end in this state
                else:
                    self.V[-1][state] += final_weight
                    
        # get a list of all states where there was a path ending with non-zero probability
        finished = [x for x in self.V[-1] if x < self.NLL_ZERO]
        if not finished:  # if empty
            print("No path got to the end of the observations.")
        
        
    def decode(self):
        forward_computations = 0
        initial = time.time()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            forward_computations += self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            t += 1
        self.finalise_decoding()
        final=time.time()
        return (forward_computations, (final - initial))
    
    def backtrace(self):
        
        initial = time.time()
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        
        
        final = time.time()
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence =' '.join([ self.f.output_symbols().find(label) for label in best_out_sequence])
        return (best_state_sequence, best_out_sequence,(final-initial))
import openfst_python as fst

def parse_lexicon(lex_file):
    """
    Parse the lexicon file and return it in dictionary form.
    
    Args:
        lex_file (str): filename of lexicon file with structure '<word> <phone1> <phone2>...'
                        eg. peppers p eh p er z

    Returns:
        lex (dict): dictionary mapping words to list of phones
    """
    
    lex = {}  # create a dictionary for the lexicon entries (this could be a problem with larger lexica)
    with open(lex_file, 'r') as f:
        for line in f:
            line = line.split()  # split at each space
            lex[line[0]] = line[1:]  # first field the word, the rest is the phones
    return lex

def generate_symbol_tables(lexicon, n=3):
    '''
    Return word, phone and state symbol tables based on the supplied lexicon
        
    Args:
        lexicon (dict): lexicon to use, created from the parse_lexicon() function
        n (int): number of states for each phone HMM
        
    Returns:
        word_table (fst.SymbolTable): table of words
        phone_table (fst.SymbolTable): table of phones
        state_table (fst.SymbolTable): table of HMM phone-state IDs
    '''
    
    state_table = fst.SymbolTable()
    phone_table = fst.SymbolTable()
    word_table = fst.SymbolTable()
    
    # add empty <eps> symbol to all tables
    state_table.add_symbol('<eps>')
    phone_table.add_symbol('<eps>')
    word_table.add_symbol('<eps>')
    
    for word, phones  in lexicon.items():
        
        word_table.add_symbol(word)
        
        for p in phones: # for each phone
            
            phone_table.add_symbol(p)
            for i in range(1,n+1): # for each state 1 to n
                state_table.add_symbol('{}_{}'.format(p, i))
            
    return word_table, phone_table, state_table


# call these two functions
lex = parse_lexicon('lexicon.txt')
word_table, phone_table, state_table = generate_symbol_tables(lex)
def generate_phone_wfst(f, start_state, phone, n, next_state_prob):
    """
    Generate a WFST representing an n-state left-to-right phone HMM.
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assumed to exist already
        phone (str): the phone label 
        n (int): number of states of the HMM excluding start and end
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
    
        in_label = state_table.find('{}_{}'.format(phone, i))
        sl_weight = fst.Weight('log', -math.log(1-next_state_prob))
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, sl_weight, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        
        out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        next_weight = fst.Weight('log', -math.log(next_state_prob))
        f.add_arc(current_state, fst.Arc(in_label, out_label, next_weight, next_state))    
       
        current_state = next_state
    return current_state



def create_wfst(n, probabilities=None, next_state_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs.
        This will currently output phone labels.  
    
    Args:
        
        start_state (int): the index of the first state, assumed to exist already
        word (str): the word to generate
        n (int): states per phone HMM
        
    Returns:
        the constructed WFST
    
    """
    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
        # note: new current_state is now set to the final state of the previous phone WFST
        
        next_weight = fst.Weight('log', -math.log(1))
        out_label = word_table.find(word)
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))
    f.set_input_symbols(state_table)
    f.set_output_symbols(word_table)

    return f




    


def read_transcription(wav_file):
    """
    Get the transcription corresponding to wav_file.
    """
    
    transcription_file = os.path.splitext(wav_file)[0] + '.txt'
    
    with open(transcription_file, 'r') as f:
        transcription = f.readline().strip()
    
    return transcription


f = create_wfst(3)

print([x for x in lex.values()])

def num_states(f):
    counter = 0
    for x in f.states():
        counter += 1
    return counter

def total_num_arcs(f):
    return sum(f.num_arcs(s) for s in f.states())

def draw_fst(f):
    from subprocess import check_call
    from IPython.display import Image
    f.draw('tmp.dot', portrait=True)
    check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
    return Image(filename='tmp.png')




draw_fst(f)
# Out:
# [['ey'], ['ah', 'v'], ['p', 'eh', 'k'], ['p', 'eh', 'p', 'er', 'z'], ['p', 'iy', 't', 'er'], ['p', 'ih', 'k', 't'], ['p', 'ih', 'k', 'ah', 'l', 'd'], ['p', 'ay', 'p', 'er'], ['dh', 'iy'], ['w', 'eh', 'r', 'z']]

# %%
#TASK 1

# !pip install pandas
import pandas as pd
results_df=[]
import wer

print(num_states(f))
print(total_num_arcs(f))
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    break
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('resulto.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
from collections import defaultdict
word_count=defaultdict(int)

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    transcription = read_transcription(wav_file)
    for word in transcription.split(" "):
        word_count[word]+=1
total_words = sum(word_count.values())
probabilities ={word:count/total_words for word,count in word_count.items()}
print(word_count,probabilities)
# Out:
# defaultdict(<class 'int'>, {'peter': 338, 'piper': 289, 'picked': 286, 'a': 138, 'peck': 264, 'of': 246, 'pickled': 285, 'peppers': 321, "where's": 118, 'the': 137}) {'peter': 0.13955408753096615, 'piper': 0.11932287365813378, 'picked': 0.1180842279108175, 'a': 0.05697770437654831, 'peck': 0.10900082576383155, 'of': 0.10156895127993394, 'pickled': 0.11767134599504542, 'peppers': 0.13253509496284063, "where's": 0.04872006606110652, 'the': 0.056564822460776217}

# %%
#TASK 2, using the above probabilities to change the word probabilties
# !pip install pandas
import pandas as pd
results_df=[]
import wer
f= create_wfst(3,probabilities)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                     # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_unary.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
#TASK 2, changing self-loop probabilities
# !pip install pandas
import pandas as pd
results_df=[]
import wer
f= create_wfst(3,next_state_prob=0.7)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                                                               # audio files
    
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_0.7.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230

# %%
#task2 silent states between states

# %%
from copy import deepcopy



def create_wfst_silent(n, probabilities=None, next_state_prob=0.5, sil_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs."""
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))


    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            last_state = current_state
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
            
        weight = fst.Weight('log',-math.log(1-sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,start_state))
        weight = fst.Weight('log',-math.log(sil_prob*(1-next_state_prob)))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
        next_state =f.add_state()
        weight = fst.Weight('log',-math.log(sil_prob*((1-next_state_prob))))
        f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
        current_state=next_state
        
        
        for i in range(2,6):
            weight = fst.Weight('log',-math.log(1-next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,current_state))
            next_state =f.add_state()
            weight = fst.Weight('log',-math.log(next_state_prob))
            f.add_arc(current_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
            current_state=next_state
        

            
            
            
            
            
        
        
        
        next_weight = fst.Weight('log', -math.log(1))
        f.add_arc(current_state, fst.Arc(0, out_label,next_weight , start_state))
    f.set_input_symbols(silent_state_table)
    f.set_output_symbols(word_table)


    return f

# %%
f=create_wfst_silent(3,sil_prob=0.6)

# %%
draw_fst(f)

# %%
#TASK 2, changing self-loop probabilities
# !pip install pandas
import pandas as pd
results_df=[]
import wer
f= create_wfst_silent(3,sil_prob=0.9)
print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
    break                                                                       # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
# results_df.to_csv('result_silent_0.9.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 166
# 340

# %%
#task 3 pruning

#attempt using beam search
"""
what is beam search?




"""
class PrunedViterbiDecoder:
    
    
    NLL_ZERO = 1e10# define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    
    def __init__(self, f, audio_file_name,beam=30, beam_type = "size"):
        """Set up the decoder class with an audio file and WFST f
        """
        self.NLL_ZERO = 1e10
        self.om = observation_model.ObservationModel()
        self.f = f
        self.beam = beam
        self.beam_type = beam_type
        if beam_type != "size" and beam_type != "width":
            raise Exception("beam_type must be of size or width")
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
        
        forward_computations = 0
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                for arc in self.f.arcs(i):
                    
                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        forward_computations += 1
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            self.V[t][j] = prob
                            self.B[t][j] = i
                            
                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
                                
        if self.beam_type == "width":
            minimum_state_value = min(self.V[t])
            print(minimum_state_value)
            for j in range(self.f.num_states()):
                if self.V[t][j] > -math.log(self.beam) + minimum_state_value:
                    self.V[t][j] = self.NLL_ZERO 
            print(minimum_state_value)
        
        if self.beam_type == "size": 
            sorted_values = sorted(self.V[t])
            beam = min(self.beam, len(self.V[t]))
            threshold = sorted_values[self.beam - 1]
            for j in range(f.num_states()):
                if self.V[t][j] > threshold:
                    self.V[t][j] = self.NLL_ZERO 
        
                                
        return forward_computations
                            
    
    def finalise_decoding(self):
        """ this incorporates the probability of terminating at each state
        """
        
        for state in self.f.states():
            final_weight = float(self.f.final(state))
            if self.V[-1][state] != self.NLL_ZERO:
                if final_weight == math.inf:
                    self.V[-1][state] = self.NLL_ZERO  # effectively says that we can't end in this state
                else:
                    self.V[-1][state] += final_weight
                    
        # get a list of all states where there was a path ending with non-zero probability
        finished = [x for x in self.V[-1] if x < self.NLL_ZERO]
        if not finished:  # if empty
            print("No path got to the end of the observations.")
        
        
    def decode(self):
        forward_computations = 0
        initial = time.time()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            forward_computations += self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            t += 1
        self.finalise_decoding()
        final=time.time()
        return (forward_computations, (final - initial))
    
    def backtrace(self):
        
        initial = time.time()
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        
        
        final = time.time()
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence =' '.join([ self.f.output_symbols().find(label) for label in best_out_sequence])
        
        return (best_state_sequence, best_out_sequence,(final-initial))

# %%
f=create_wfst(3)
draw_fst(f)

# %%
#TASK 2, changing self-loop probabilities


print(num_states(f))
print(total_num_arcs(f))
f=create_wfst_silent(3,probabilities,next_state_prob=0.1,sil_prob=0.5)
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                      # audio files
    decoder = PrunedViterbiDecoder(f, wav_file,beam=50,beam_type="size")
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_pruned_size_50.csv')
# Out:
# 166
# 340
# 2.9572031497955322
# 0.000720977783203125
# {'Filename': '0000.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.23529411764705882, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter piper the a the peck of pickled peppers where's peck of pickled peppers peter piper picked", 'Decode speed': 2.9572031497955322, 'Backtrace speed': 0.000720977783203125, 'Forward computations': 114168}
# 1.677302598953247
# 0.0002415180206298828
# {'Filename': '0001.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': "a a peter picked the peck of pickled peck where's", 'Decode speed': 1.677302598953247, 'Backtrace speed': 0.0002415180206298828, 'Forward computations': 64852}
# 1.222161054611206
# 0.0002334117889404297
# {'Filename': '0002.wav', 'Insertions': 1, 'Deletions': 2, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 6, 'transcription': 'a peck of pickled peppers picked', 'Viterbi transcription': 'a peck picked of picked', 'Decode speed': 1.222161054611206, 'Backtrace speed': 0.0002334117889404297, 'Forward computations': 48002}
# 0.942812442779541
# 0.00013136863708496094
# {'Filename': '0003.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peter piper peter piper', 'Viterbi transcription': 'a peter piper peter piper', 'Decode speed': 0.942812442779541, 'Backtrace speed': 0.00013136863708496094, 'Forward computations': 36122}
# 1.2351927757263184
# 0.0002694129943847656
# {'Filename': '0004.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': "where's the peck of pickled peppers picked", 'Viterbi transcription': "a a where's pickled pickled peppers picked", 'Decode speed': 1.2351927757263184, 'Backtrace speed': 0.0002694129943847656, 'Forward computations': 47142}
# 0.7538766860961914
# 0.00010752677917480469
# {'Filename': '0005.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 4, 'transcription': 'peter piper pickled peppers', 'Viterbi transcription': 'peter piper pickled peppers', 'Decode speed': 0.7538766860961914, 'Backtrace speed': 0.00010752677917480469, 'Forward computations': 29064}
# 0.43398094177246094
# 6.771087646484375e-05
# {'Filename': '0006.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 2, 'transcription': "where's peter", 'Viterbi transcription': "where's peter", 'Decode speed': 0.43398094177246094, 'Backtrace speed': 6.771087646484375e-05, 'Forward computations': 17370}
# 0.7115850448608398
# 9.894371032714844e-05
# {'Filename': '0007.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'piper picked peppers of peter', 'Viterbi transcription': 'a piper picked peppers of peter', 'Decode speed': 0.7115850448608398, 'Backtrace speed': 9.894371032714844e-05, 'Forward computations': 28518}
# 0.8012957572937012
# 0.00011205673217773438
# {'Filename': '0008.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 6, 'transcription': 'peter peppers picked piper of peck', 'Viterbi transcription': 'peter peppers picked piper of peck', 'Decode speed': 0.8012957572937012, 'Backtrace speed': 0.00011205673217773438, 'Forward computations': 32196}
# 1.0481986999511719
# 0.00013589859008789062
# {'Filename': '0009.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.125, 'Word Count': 8, 'transcription': 'a peck of pickled peppers peter piper pickled', 'Viterbi transcription': 'a peck of picked peppers peter piper pickled', 'Decode speed': 1.0481986999511719, 'Backtrace speed': 0.00013589859008789062, 'Forward computations': 40958}
# 0.49240684509277344
# 7.009506225585938e-05
# {'Filename': '0010.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'picked', 'Viterbi transcription': 'a picked', 'Decode speed': 0.49240684509277344, 'Backtrace speed': 7.009506225585938e-05, 'Forward computations': 18118}
# 0.3918170928955078
# 5.841255187988281e-05
# {'Filename': '0011.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'pickled', 'Viterbi transcription': 'a pickled', 'Decode speed': 0.3918170928955078, 'Backtrace speed': 5.841255187988281e-05, 'Forward computations': 15580}
# 0.6708166599273682
# 0.00018286705017089844
# {'Filename': '0012.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'peppers', 'Viterbi transcription': 'a peppers', 'Decode speed': 0.6708166599273682, 'Backtrace speed': 0.00018286705017089844, 'Forward computations': 26486}
# 0.6031279563903809
# 8.702278137207031e-05
# {'Filename': '0013.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'piper', 'Viterbi transcription': 'a piper', 'Decode speed': 0.6031279563903809, 'Backtrace speed': 8.702278137207031e-05, 'Forward computations': 23954}
# 0.569439172744751
# 8.034706115722656e-05
# {'Filename': '0014.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'peter', 'Viterbi transcription': 'a peter', 'Decode speed': 0.569439172744751, 'Backtrace speed': 8.034706115722656e-05, 'Forward computations': 21318}
# 0.9913568496704102
# 0.0002791881561279297
# {'Filename': '0015.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's peck of the pickled peppers", 'Decode speed': 0.9913568496704102, 'Backtrace speed': 0.0002791881561279297, 'Forward computations': 39700}
# 0.631767988204956
# 8.7738037109375e-05
# {'Filename': '0016.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'a peter piper the picked', 'Decode speed': 0.631767988204956, 'Backtrace speed': 8.7738037109375e-05, 'Forward computations': 25462}
# 1.4200170040130615
# 0.00030040740966796875
# {'Filename': '0017.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter piper picked of peck of pickled peppers', 'Decode speed': 1.4200170040130615, 'Backtrace speed': 0.00030040740966796875, 'Forward computations': 54894}
# 0.7023522853851318
# 0.00014734268188476562
# {'Filename': '0018.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'picked a peck of pickled peppers', 'Viterbi transcription': "a picked the peck of pickled peck where's", 'Decode speed': 0.7023522853851318, 'Backtrace speed': 0.00014734268188476562, 'Forward computations': 27908}
# 1.2844738960266113
# 0.00023317337036132812
# {'Filename': '0019.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': 'a peter piper a', 'Decode speed': 1.2844738960266113, 'Backtrace speed': 0.00023317337036132812, 'Forward computations': 49170}
# 1.7291910648345947
# 0.00030803680419921875
# {'Filename': '0020.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "peppers picked peter piper where's the peck", 'Viterbi transcription': "a peppers picked peter piper where's the the", 'Decode speed': 1.7291910648345947, 'Backtrace speed': 0.00030803680419921875, 'Forward computations': 66820}
# 2.4974238872528076
# 0.0005495548248291016
# {'Filename': '0021.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.8, 'Word Count': 10, 'transcription': 'peter picked a peck piper pickled peppers of pickled peppers', 'Viterbi transcription': "a peter where's picked of peck piper pickled the of picked of pickled peck picked", 'Decode speed': 2.4974238872528076, 'Backtrace speed': 0.0005495548248291016, 'Forward computations': 95210}
# 1.8813691139221191
# 0.0003662109375
# {'Filename': '0022.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 8, 'transcription': 'peter piper piper peter peter peter piper piper', 'Viterbi transcription': 'a peter piper piper the peter peter peter piper piper', 'Decode speed': 1.8813691139221191, 'Backtrace speed': 0.0003662109375, 'Forward computations': 72344}
# 1.2006375789642334
# 0.0001895427703857422
# {'Filename': '0023.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.75, 'Word Count': 4, 'transcription': 'peter picked piper peppers', 'Viterbi transcription': 'a peter of picked of peppers', 'Decode speed': 1.2006375789642334, 'Backtrace speed': 0.0001895427703857422, 'Forward computations': 46356}
# 1.3373053073883057
# 0.00022339820861816406
# {'Filename': '0024.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': 'peter peter peter peter peter peter', 'Viterbi transcription': 'a peter peter peter peter picked peter', 'Decode speed': 1.3373053073883057, 'Backtrace speed': 0.00022339820861816406, 'Forward computations': 51884}
# 1.3878154754638672
# 0.0002086162567138672
# {'Filename': '0025.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': 'piper picked a peck of peter peppers', 'Viterbi transcription': 'a a picked of peck of peter peppers', 'Decode speed': 1.3878154754638672, 'Backtrace speed': 0.0002086162567138672, 'Forward computations': 53898}
# 1.3446235656738281
# 0.0002110004425048828
# {'Filename': '0026.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'pickled peppers peter piper picked a peck of', 'Viterbi transcription': 'a pickled of picked piper picked peck of', 'Decode speed': 1.3446235656738281, 'Backtrace speed': 0.0002110004425048828, 'Forward computations': 52086}
# 1.6269245147705078
# 0.0003159046173095703
# {'Filename': '0027.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'of peppers of picked a peter piper of', 'Viterbi transcription': "a of of where's of picked of peter piper of a", 'Decode speed': 1.6269245147705078, 'Backtrace speed': 0.0003159046173095703, 'Forward computations': 62902}
# 1.0451619625091553
# 0.00014495849609375
# {'Filename': '0028.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': 'pickled peppers peter piper picked', 'Viterbi transcription': 'a pickled peppers peter piper of peck', 'Decode speed': 1.0451619625091553, 'Backtrace speed': 0.00014495849609375, 'Forward computations': 40088}
# 1.0412750244140625
# 0.0002644062042236328
# {'Filename': '0029.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': 'a a peck of peck of pickled peppers', 'Decode speed': 1.0412750244140625, 'Backtrace speed': 0.0002644062042236328, 'Forward computations': 41028}
# 1.1337647438049316
# 0.0001742839813232422
# {'Filename': '0030.wav', 'Insertions': 0, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': "where's a peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's of peck peppers peter piper picked", 'Decode speed': 1.1337647438049316, 'Backtrace speed': 0.0001742839813232422, 'Forward computations': 43586}
# 0.6824774742126465
# 9.274482727050781e-05
# {'Filename': '0031.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peter piper picked the peppers', 'Viterbi transcription': 'a picked piper picked of', 'Decode speed': 0.6824774742126465, 'Backtrace speed': 9.274482727050781e-05, 'Forward computations': 25932}
# 0.7633099555969238
# 0.00010395050048828125
# {'Filename': '0032.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.8, 'Word Count': 5, 'transcription': 'pickled peppers picked peter piper', 'Viterbi transcription': 'a peck peppers a picked piper', 'Decode speed': 0.7633099555969238, 'Backtrace speed': 0.00010395050048828125, 'Forward computations': 29096}
# 0.7797119617462158
# 0.00010228157043457031
# {'Filename': '0033.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 5, 'transcription': 'a peck of pickled peppers', 'Viterbi transcription': 'a peck of pickled peppers', 'Decode speed': 0.7797119617462158, 'Backtrace speed': 0.00010228157043457031, 'Forward computations': 30296}
# 0.5900650024414062
# 7.963180541992188e-05
# {'Filename': '0034.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': "where's the peck peter picked", 'Viterbi transcription': "a where's the peck peter picked", 'Decode speed': 0.5900650024414062, 'Backtrace speed': 7.963180541992188e-05, 'Forward computations': 22702}
# 1.0256140232086182
# 0.00013780593872070312
# {'Filename': '0035.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'pickled peppers piper picked', 'Viterbi transcription': 'a pickled peppers piper picked', 'Decode speed': 1.0256140232086182, 'Backtrace speed': 0.00013780593872070312, 'Forward computations': 41352}
# 0.5827732086181641
# 8.058547973632812e-05
# {'Filename': '0036.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': 'a peter picked peppers', 'Decode speed': 0.5827732086181641, 'Backtrace speed': 8.058547973632812e-05, 'Forward computations': 23544}
# 1.005056381225586
# 0.00014066696166992188
# {'Filename': '0037.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter piper picked peck of pickled peppers', 'Decode speed': 1.005056381225586, 'Backtrace speed': 0.00014066696166992188, 'Forward computations': 39286}
# 0.9898481369018555
# 0.00013256072998046875
# {'Filename': '0038.wav', 'Insertions': 2, 'Deletions': 2, 'Substitutions': 1, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter a peck picked picked pickled peppers', 'Decode speed': 0.9898481369018555, 'Backtrace speed': 0.00013256072998046875, 'Forward computations': 38290}
# 0.8417766094207764
# 0.00012993812561035156
# {'Filename': '0039.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': 'peppers pickled peter of the piper peck', 'Viterbi transcription': 'a peppers pickled peter of the piper peck', 'Decode speed': 0.8417766094207764, 'Backtrace speed': 0.00012993812561035156, 'Forward computations': 34040}
# 1.1912245750427246
# 0.0001785755157470703
# {'Filename': '0040.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': "piper peter picked where's the pickled peppers peter", 'Viterbi transcription': "a peck peter picked where's the pickled peppers peter a", 'Decode speed': 1.1912245750427246, 'Backtrace speed': 0.0001785755157470703, 'Forward computations': 46732}
# 0.9070825576782227
# 0.00013136863708496094
# {'Filename': '0041.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': 'peck pickled piper of the peter peppers', 'Viterbi transcription': 'a peck picked of the peter peppers', 'Decode speed': 0.9070825576782227, 'Backtrace speed': 0.00013136863708496094, 'Forward computations': 36626}
# 1.1601691246032715
# 0.0006940364837646484
# {'Filename': '0042.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.36363636363636365, 'Word Count': 11, 'transcription': 'a peck of pickled peter picked the peppers of the peck', 'Viterbi transcription': 'a peck of pickled peter peck the peck a of peck', 'Decode speed': 1.1601691246032715, 'Backtrace speed': 0.0006940364837646484, 'Forward computations': 45042}
# 0.9453473091125488
# 0.00013518333435058594
# {'Filename': '0043.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.8571428571428571, 'Word Count': 7, 'transcription': "where's the peck of peppers piper pickled", 'Viterbi transcription': "a where's of a of of where's piper of pickled", 'Decode speed': 0.9453473091125488, 'Backtrace speed': 0.00013518333435058594, 'Forward computations': 37630}
# 1.134692668914795
# 0.00019693374633789062
# {'Filename': '0044.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'piper pickled peppers of the peck peter picked', 'Viterbi transcription': 'a piper pickled peppers of a peter peck', 'Decode speed': 1.134692668914795, 'Backtrace speed': 0.00019693374633789062, 'Forward computations': 43170}
# 1.0692930221557617
# 0.00014352798461914062
# {'Filename': '0045.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'piper peter picked pickled piper peppers', 'Viterbi transcription': "a piper the where's pickled picked", 'Decode speed': 1.0692930221557617, 'Backtrace speed': 0.00014352798461914062, 'Forward computations': 42350}
# 1.1903247833251953
# 0.00018405914306640625
# {'Filename': '0046.wav', 'Insertions': 2, 'Deletions': 5, 'Substitutions': 1, 'WER': 0.7272727272727273, 'Word Count': 11, 'transcription': 'peter picked peppers of the pickled peck of peppers of piper', 'Viterbi transcription': "a the pickled pickled peck where's of of", 'Decode speed': 1.1903247833251953, 'Backtrace speed': 0.00018405914306640625, 'Forward computations': 45404}
# 2.0677082538604736
# 0.0004506111145019531
# {'Filename': '0047.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.35294117647058826, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a the of piper picked piper of pickled peppers where's the peck of picked peppers peter piper picked", 'Decode speed': 2.0677082538604736, 'Backtrace speed': 0.0004506111145019531, 'Forward computations': 81130}
# 1.159162998199463
# 0.00017523765563964844
# {'Filename': '0048.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter piper picked the peck of pickled peppers', 'Decode speed': 1.159162998199463, 'Backtrace speed': 0.00017523765563964844, 'Forward computations': 45050}
# 0.959373950958252
# 0.00014352798461914062
# {'Filename': '0049.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a where's the peck of picked of peppers peter piper picked", 'Decode speed': 0.959373950958252, 'Backtrace speed': 0.00014352798461914062, 'Forward computations': 37570}
# 0.8912057876586914
# 0.00013566017150878906
# {'Filename': '0050.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': 'pickled peppers pickled peter piper', 'Viterbi transcription': 'a pickled of picked pickled peter piper', 'Decode speed': 0.8912057876586914, 'Backtrace speed': 0.00013566017150878906, 'Forward computations': 35600}
# 1.3669703006744385
# 0.0002040863037109375
# {'Filename': '0051.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.2727272727272727, 'Word Count': 11, 'transcription': 'peter piper picked a peck of pickled peppers peter piper pickled', 'Viterbi transcription': 'a peter piper picked picked of pickled peppers peter piper pickled', 'Decode speed': 1.3669703006744385, 'Backtrace speed': 0.0002040863037109375, 'Forward computations': 53520}
# 0.8908147811889648
# 0.00012493133544921875
# {'Filename': '0052.wav', 'Insertions': 2, 'Deletions': 3, 'Substitutions': 2, 'WER': 0.875, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a the of piper picked peck where's", 'Decode speed': 0.8908147811889648, 'Backtrace speed': 0.00012493133544921875, 'Forward computations': 35030}
# 0.8379850387573242
# 0.0001251697540283203
# {'Filename': '0053.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': "a where's of peck of pickled peppers", 'Decode speed': 0.8379850387573242, 'Backtrace speed': 0.0001251697540283203, 'Forward computations': 31558}
# 0.756493091583252
# 0.00011920928955078125
# {'Filename': '0054.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'piper peter peppers pickled', 'Viterbi transcription': 'a piper peter peppers pickled', 'Decode speed': 0.756493091583252, 'Backtrace speed': 0.00011920928955078125, 'Forward computations': 28378}
# 0.9389262199401855
# 0.00011849403381347656
# {'Filename': '0055.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2222222222222222, 'Word Count': 9, 'transcription': 'peter piper picked peter piper picked peter piper picked', 'Viterbi transcription': 'a peter piper picked peter of picked peter piper picked', 'Decode speed': 0.9389262199401855, 'Backtrace speed': 0.00011849403381347656, 'Forward computations': 36880}
# 0.7573609352111816
# 0.0001068115234375
# {'Filename': '0056.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "where's the peck of peter piper peppers", 'Viterbi transcription': "a where's peck of peter piper peppers", 'Decode speed': 0.7573609352111816, 'Backtrace speed': 0.0001068115234375, 'Forward computations': 30382}
# 1.2986524105072021
# 0.0001823902130126953
# {'Filename': '0057.wav', 'Insertions': 0, 'Deletions': 1, 'Substitutions': 5, 'WER': 0.75, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a picked piper peck peck picked picked', 'Decode speed': 1.2986524105072021, 'Backtrace speed': 0.0001823902130126953, 'Forward computations': 49938}
# 0.932335615158081
# 0.0001480579376220703
# {'Filename': '0058.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'the peck of pickled peppers picked peter piper', 'Viterbi transcription': 'a the peck the of of picked picked piper', 'Decode speed': 0.932335615158081, 'Backtrace speed': 0.0001480579376220703, 'Forward computations': 37132}
# 1.1454193592071533
# 0.00017952919006347656
# {'Filename': '0059.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'piper picked peter the pickled peppers', 'Viterbi transcription': 'a piper picked peter the peck the picked', 'Decode speed': 1.1454193592071533, 'Backtrace speed': 0.00017952919006347656, 'Forward computations': 44864}
# 0.8346571922302246
# 0.0001201629638671875
# {'Filename': '0060.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': 'peck piper peter pickled picked', 'Viterbi transcription': 'a peck piper peter of pickled peck', 'Decode speed': 0.8346571922302246, 'Backtrace speed': 0.0001201629638671875, 'Forward computations': 32024}
# 0.9067752361297607
# 0.00012111663818359375
# {'Filename': '0061.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'peck peppers pickled peter piper', 'Viterbi transcription': 'a peck peppers pickled peter piper', 'Decode speed': 0.9067752361297607, 'Backtrace speed': 0.00012111663818359375, 'Forward computations': 36634}
# 2.3625454902648926
# 0.0005028247833251953
# {'Filename': '0062.wav', 'Insertions': 3, 'Deletions': 2, 'Substitutions': 5, 'WER': 0.5882352941176471, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter of piper a of a of pickled peppers where's peck of the where's picked piper peck", 'Decode speed': 2.3625454902648926, 'Backtrace speed': 0.0005028247833251953, 'Forward computations': 89978}
# 1.3224725723266602
# 0.0002315044403076172
# {'Filename': '0063.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8571428571428571, 'Word Count': 7, 'transcription': "peter piper picked where's the peck of", 'Viterbi transcription': "a picked of piper a where's of peck a", 'Decode speed': 1.3224725723266602, 'Backtrace speed': 0.0002315044403076172, 'Forward computations': 50634}
# 1.9109327793121338
# 0.0005242824554443359
# {'Filename': '0064.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 5, 'WER': 0.75, 'Word Count': 12, 'transcription': 'pickled peppers pickled peppers peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a a of where's pickled peppers picked piper a of a of picked peppers", 'Decode speed': 1.9109327793121338, 'Backtrace speed': 0.0005242824554443359, 'Forward computations': 73938}
# 1.388002872467041
# 0.00023984909057617188
# {'Filename': '0065.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.75, 'Word Count': 8, 'transcription': 'the peck of pickled peppers peter piper picked', 'Viterbi transcription': "a the a of a where's peter of piper a", 'Decode speed': 1.388002872467041, 'Backtrace speed': 0.00023984909057617188, 'Forward computations': 53890}
# 1.3014562129974365
# 0.00020599365234375
# {'Filename': '0066.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': "a the the piper picked of peck of pickled where's", 'Decode speed': 1.3014562129974365, 'Backtrace speed': 0.00020599365234375, 'Forward computations': 50014}
# 1.9698264598846436
# 0.00040459632873535156
# {'Filename': '0067.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': 'pickled peter peppers pickled peppers piper of piper', 'Viterbi transcription': 'a picked of peter the pickled peppers piper of piper', 'Decode speed': 1.9698264598846436, 'Backtrace speed': 0.00040459632873535156, 'Forward computations': 75354}
# 1.1575567722320557
# 0.0001633167266845703
# {'Filename': '0068.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': "pickled where's peck peck peppers", 'Viterbi transcription': "a pickled where's peck picked peppers", 'Decode speed': 1.1575567722320557, 'Backtrace speed': 0.0001633167266845703, 'Forward computations': 46328}
# 1.7028396129608154
# 0.00033354759216308594
# {'Filename': '0069.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'picked pickled a pickled peter of peppers peppers piper', 'Viterbi transcription': 'a pickled pickled of pickled peter of peppers peppers piper', 'Decode speed': 1.7028396129608154, 'Backtrace speed': 0.00033354759216308594, 'Forward computations': 66232}
# 0.94293212890625
# 0.0001289844512939453
# {'Filename': '0070.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peck peppers picked piper', 'Viterbi transcription': 'a peck peppers picked piper', 'Decode speed': 0.94293212890625, 'Backtrace speed': 0.0001289844512939453, 'Forward computations': 37776}
# 1.0935969352722168
# 0.00015735626220703125
# {'Filename': '0071.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'a peter pickled pickled picked', 'Viterbi transcription': 'a of peter of pickled pickled picked', 'Decode speed': 1.0935969352722168, 'Backtrace speed': 0.00015735626220703125, 'Forward computations': 42296}
# 1.7605931758880615
# 0.00030732154846191406
# {'Filename': '0072.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 5, 'WER': 1.0, 'Word Count': 9, 'transcription': 'peck peppers picked a picked peter a picked peppers', 'Viterbi transcription': "a of where's picked of a peter of pickled of of", 'Decode speed': 1.7605931758880615, 'Backtrace speed': 0.00030732154846191406, 'Forward computations': 67462}
# 1.4366109371185303
# 0.0002529621124267578
# {'Filename': '0073.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': "peck picked peppers peck picked where's of pickled", 'Viterbi transcription': "a peck picked of peck picked where's of pickled", 'Decode speed': 1.4366109371185303, 'Backtrace speed': 0.0002529621124267578, 'Forward computations': 55412}
# 1.1783747673034668
# 0.00015473365783691406
# {'Filename': '0074.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.375, 'Word Count': 8, 'transcription': "a peter where's piper the picked picked peppers", 'Viterbi transcription': "a peter where's piper the pickled picked peck of", 'Decode speed': 1.1783747673034668, 'Backtrace speed': 0.00015473365783691406, 'Forward computations': 45624}
# 1.4188811779022217
# 0.0002434253692626953
# {'Filename': '0075.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'piper peck of peck pickled picked pickled of peter', 'Viterbi transcription': 'a piper of piper of peck pickled picked pickled of peter', 'Decode speed': 1.4188811779022217, 'Backtrace speed': 0.0002434253692626953, 'Forward computations': 55172}
# 1.5838727951049805
# 0.0002772808074951172
# {'Filename': '0076.wav', 'Insertions': 0, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': 'peck of peter peppers pickled peppers of picked peter', 'Viterbi transcription': "a of peter of pickled where's of picked", 'Decode speed': 1.5838727951049805, 'Backtrace speed': 0.0002772808074951172, 'Forward computations': 60938}
# 1.8612563610076904
# 0.00037026405334472656
# {'Filename': '0077.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.1111111111111111, 'Word Count': 9, 'transcription': 'peppers peck of peck peter picked a of peppers', 'Viterbi transcription': 'a peppers peck of peck peter picked a of peppers', 'Decode speed': 1.8612563610076904, 'Backtrace speed': 0.00037026405334472656, 'Forward computations': 72128}
# 1.4821643829345703
# 0.0002315044403076172
# {'Filename': '0078.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 9, 'transcription': 'a peck of the pickled peppers peter piper picked', 'Viterbi transcription': 'a peck of the pickled peppers peter piper picked', 'Decode speed': 1.4821643829345703, 'Backtrace speed': 0.0002315044403076172, 'Forward computations': 57876}
# 1.0967316627502441
# 0.00016450881958007812
# {'Filename': '0079.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.16666666666666666, 'Word Count': 6, 'transcription': 'piper picked peter of the peck', 'Viterbi transcription': 'a piper picked peter of the peck', 'Decode speed': 1.0967316627502441, 'Backtrace speed': 0.00016450881958007812, 'Forward computations': 42386}
# 1.352015495300293
# 0.0002124309539794922
# {'Filename': '0080.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.0, 'Word Count': 8, 'transcription': 'a peter picked peck of picked pickled piper', 'Viterbi transcription': 'a peter picked peck of picked pickled piper', 'Decode speed': 1.352015495300293, 'Backtrace speed': 0.0002124309539794922, 'Forward computations': 54270}
# 1.0645110607147217
# 0.0001685619354248047
# {'Filename': '0081.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': "where's peck peppers of piper", 'Viterbi transcription': "a where's peck peppers of piper", 'Decode speed': 1.0645110607147217, 'Backtrace speed': 0.0001685619354248047, 'Forward computations': 41482}
# 1.280052900314331
# 0.0002295970916748047
# {'Filename': '0082.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': 'piper of peppers', 'Viterbi transcription': 'a piper picked', 'Decode speed': 1.280052900314331, 'Backtrace speed': 0.0002295970916748047, 'Forward computations': 49278}
# 0.9483075141906738
# 0.00012755393981933594
# {'Filename': '0083.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 3, 'transcription': 'peter picked piper', 'Viterbi transcription': 'a peter picked piper', 'Decode speed': 0.9483075141906738, 'Backtrace speed': 0.00012755393981933594, 'Forward computations': 36600}
# 0.6291933059692383
# 9.036064147949219e-05
# {'Filename': '0084.wav', 'Insertions': 0, 'Deletions': 3, 'Substitutions': 2, 'WER': 0.5555555555555556, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "of of where's peter piper picked", 'Decode speed': 0.6291933059692383, 'Backtrace speed': 9.036064147949219e-05, 'Forward computations': 25382}
# 0.8682141304016113
# 0.00011754035949707031
# {'Filename': '0085.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.45454545454545453, 'Word Count': 11, 'transcription': 'the peck of pickled peppers picked a peck of pickled peppers', 'Viterbi transcription': "peck of pickled peppers picked peck of peck of peck where's", 'Decode speed': 0.8682141304016113, 'Backtrace speed': 0.00011754035949707031, 'Forward computations': 34960}
# 1.1211433410644531
# 0.00019884109497070312
# {'Filename': '0086.wav', 'Insertions': 3, 'Deletions': 2, 'Substitutions': 0, 'WER': 0.625, 'Word Count': 8, 'transcription': "peter piper where's the peck of pickled peppers", 'Viterbi transcription': "peter of piper where's peck pickled peppers peter piper", 'Decode speed': 1.1211433410644531, 'Backtrace speed': 0.00019884109497070312, 'Forward computations': 43194}
# 1.2897229194641113
# 0.00024628639221191406
# {'Filename': '0087.wav', 'Insertions': 0, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.2222222222222222, 'Word Count': 9, 'transcription': 'peter piper peter piper a peck of pickled peppers', 'Viterbi transcription': 'peter piper peter piper peck of pickled peter', 'Decode speed': 1.2897229194641113, 'Backtrace speed': 0.00024628639221191406, 'Forward computations': 49080}
# 1.324371337890625
# 0.000217437744140625
# {'Filename': '0088.wav', 'Insertions': 0, 'Deletions': 5, 'Substitutions': 3, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "piper picked peck pickled peppers where's peck picked where's peter picked picked", 'Decode speed': 1.324371337890625, 'Backtrace speed': 0.000217437744140625, 'Forward computations': 51360}
# 1.559110403060913
# 0.0003094673156738281
# {'Filename': '0089.wav', 'Insertions': 1, 'Deletions': 3, 'Substitutions': 4, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter of picked peck picked picked where's peck of picked peppers peter piper picked", 'Decode speed': 1.559110403060913, 'Backtrace speed': 0.0003094673156738281, 'Forward computations': 60862}
# 2.299042224884033
# 0.0004925727844238281
# {'Filename': '0090.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.11764705882352941, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper of picked", 'Decode speed': 2.299042224884033, 'Backtrace speed': 0.0004925727844238281, 'Forward computations': 88608}
# 0.577866792678833
# 7.939338684082031e-05
# {'Filename': '0091.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 4, 'transcription': "where's the peck of", 'Viterbi transcription': "a where's peck of", 'Decode speed': 0.577866792678833, 'Backtrace speed': 7.939338684082031e-05, 'Forward computations': 21566}
# 0.6408276557922363
# 9.417533874511719e-05
# {'Filename': '0092.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'picked a peck of pickled', 'Viterbi transcription': 'a picked peck of pickled', 'Decode speed': 0.6408276557922363, 'Backtrace speed': 9.417533874511719e-05, 'Forward computations': 24164}
# 0.7511980533599854
# 0.00010180473327636719
# {'Filename': '0093.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': "pickled peppers where's the peck", 'Viterbi transcription': "a pickled of picked where's the peck", 'Decode speed': 0.7511980533599854, 'Backtrace speed': 0.00010180473327636719, 'Forward computations': 28542}
# 0.6222243309020996
# 8.7738037109375e-05
# {'Filename': '0094.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': "a peter picked peck where's", 'Decode speed': 0.6222243309020996, 'Backtrace speed': 8.7738037109375e-05, 'Forward computations': 23426}
# 0.8170640468597412
# 0.00010967254638671875
# {'Filename': '0095.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'peter pickled a picked peck', 'Viterbi transcription': 'a peter pickled picked peck', 'Decode speed': 0.8170640468597412, 'Backtrace speed': 0.00010967254638671875, 'Forward computations': 31240}
# 0.8051128387451172
# 0.00010752677917480469
# {'Filename': '0096.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'peter picked the peck of peppers', 'Viterbi transcription': 'a picked picked the picked of picked', 'Decode speed': 0.8051128387451172, 'Backtrace speed': 0.00010752677917480469, 'Forward computations': 31208}
# 1.0365915298461914
# 0.0001575946807861328
# {'Filename': '0097.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.375, 'Word Count': 8, 'transcription': 'peter picked a peck of the pickled peppers', 'Viterbi transcription': 'a picked piper picked peck of the pickled peppers', 'Decode speed': 1.0365915298461914, 'Backtrace speed': 0.0001575946807861328, 'Forward computations': 41670}
# 0.7559018135070801
# 0.00011777877807617188
# {'Filename': '0098.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'the peck of peppers peter piper pickled', 'Viterbi transcription': 'a the peck of peck peter piper pickled', 'Decode speed': 0.7559018135070801, 'Backtrace speed': 0.00011777877807617188, 'Forward computations': 30372}
# 2.0282936096191406
# 0.00041556358337402344
# {'Filename': '0099.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.36363636363636365, 'Word Count': 11, 'transcription': "the peck pickled peppers picked pickled peter of piper a where's", 'Viterbi transcription': "a the peck a picked picked picked pickled peter of piper a where's", 'Decode speed': 2.0282936096191406, 'Backtrace speed': 0.00041556358337402344, 'Forward computations': 78660}
# 1.4608824253082275
# 0.0002701282501220703
# {'Filename': '0100.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.1, 'Word Count': 10, 'transcription': 'the picked of piper picked of pickled a peter piper', 'Viterbi transcription': 'a the picked of piper picked of pickled a peter piper', 'Decode speed': 1.4608824253082275, 'Backtrace speed': 0.0002701282501220703, 'Forward computations': 56998}
# 2.3764808177948
# 0.0005178451538085938
# {'Filename': '0101.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.2857142857142857, 'Word Count': 14, 'transcription': "peck piper picked of picked pickled of where's a peppers peter peppers peter pickled", 'Viterbi transcription': "a picked piper picked of a pickled of where's a peppers peter peter peter pickled", 'Decode speed': 2.3764808177948, 'Backtrace speed': 0.0005178451538085938, 'Forward computations': 90090}
# 0.9136695861816406
# 0.0001201629638671875
# {'Filename': '0102.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peppers peck peter pickled', 'Viterbi transcription': 'a peppers peck peter pickled', 'Decode speed': 0.9136695861816406, 'Backtrace speed': 0.0001201629638671875, 'Forward computations': 35312}
# 1.2337827682495117
# 0.00020265579223632812
# {'Filename': '0103.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "where's piper picked piper a pickled peppers", 'Viterbi transcription': "a where's piper picked piper pickled peppers", 'Decode speed': 1.2337827682495117, 'Backtrace speed': 0.00020265579223632812, 'Forward computations': 47420}
# 1.2269301414489746
# 0.00019097328186035156
# {'Filename': '0104.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'peter picked peppers of pickled peppers', 'Viterbi transcription': 'a peter a peppers of picked picked a', 'Decode speed': 1.2269301414489746, 'Backtrace speed': 0.00019097328186035156, 'Forward computations': 47400}
# 1.4991531372070312
# 0.00027108192443847656
# {'Filename': '0105.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'peter peppers picked piper a peck of pickled peppers', 'Viterbi transcription': 'a peter peppers a piper peck of pickled peppers', 'Decode speed': 1.4991531372070312, 'Backtrace speed': 0.00027108192443847656, 'Forward computations': 58594}
# 1.343364953994751
# 0.0002319812774658203
# {'Filename': '0106.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': 'a peter piper peck picked peck of pickled a', 'Decode speed': 1.343364953994751, 'Backtrace speed': 0.0002319812774658203, 'Forward computations': 52034}
# 1.2484171390533447
# 0.00018024444580078125
# {'Filename': '0107.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.25, 'Word Count': 8, 'transcription': "where's the peck of peppers peter piper picked", 'Viterbi transcription': "a where's the peck of peppers peter piper a", 'Decode speed': 1.2484171390533447, 'Backtrace speed': 0.00018024444580078125, 'Forward computations': 48526}
# 1.0498411655426025
# 0.00016117095947265625
# {'Filename': '0108.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'the peck of pickled peter piper pickled', 'Viterbi transcription': 'a peck of pickled peter piper of pickled', 'Decode speed': 1.0498411655426025, 'Backtrace speed': 0.00016117095947265625, 'Forward computations': 40224}
# 1.0593454837799072
# 0.0001621246337890625
# {'Filename': '0109.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'piper peter picked peppers of piper', 'Viterbi transcription': 'a piper peter picked peter of piper of a', 'Decode speed': 1.0593454837799072, 'Backtrace speed': 0.0001621246337890625, 'Forward computations': 41144}
# 0.9469738006591797
# 0.00014257431030273438
# {'Filename': '0110.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter peppers picked a piper of the peck', 'Viterbi transcription': 'a peter of of picked picked of piper of the peck', 'Decode speed': 0.9469738006591797, 'Backtrace speed': 0.00014257431030273438, 'Forward computations': 38056}
# 0.8770878314971924
# 0.00011539459228515625
# {'Filename': '0111.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 6, 'transcription': 'peck of picked peter piper picked', 'Viterbi transcription': 'a picked picked peter of piper picked', 'Decode speed': 0.8770878314971924, 'Backtrace speed': 0.00011539459228515625, 'Forward computations': 33938}
# 0.8558564186096191
# 0.00011515617370605469
# {'Filename': '0112.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': 'picked the peppers peter pickled', 'Viterbi transcription': 'a a the peppers peter of pickled', 'Decode speed': 0.8558564186096191, 'Backtrace speed': 0.00011515617370605469, 'Forward computations': 32758}
# 0.9526357650756836
# 0.0001327991485595703
# {'Filename': '0113.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': 'the piper of peck peppers peter picked', 'Viterbi transcription': 'a the piper of peck peppers peter picked', 'Decode speed': 0.9526357650756836, 'Backtrace speed': 0.0001327991485595703, 'Forward computations': 38520}
# 2.2028603553771973
# 0.0004506111145019531
# {'Filename': '0114.wav', 'Insertions': 0, 'Deletions': 5, 'Substitutions': 2, 'WER': 0.875, 'Word Count': 8, 'transcription': 'piper picked peter a pickled peck of peppers', 'Viterbi transcription': "a where's where's", 'Decode speed': 2.2028603553771973, 'Backtrace speed': 0.0004506111145019531, 'Forward computations': 83966}
# 1.0466954708099365
# 0.00014472007751464844
# {'Filename': '0115.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': "where's peter piper", 'Viterbi transcription': "a where's the the piper", 'Decode speed': 1.0466954708099365, 'Backtrace speed': 0.00014472007751464844, 'Forward computations': 39946}
# 1.3706603050231934
# 0.0005497932434082031
# {'Filename': '0116.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 4, 'WER': 0.6666666666666666, 'Word Count': 9, 'transcription': 'piper picked the peck of pickled peppers peter picked', 'Viterbi transcription': 'a of picked of of pickled of picked picked', 'Decode speed': 1.3706603050231934, 'Backtrace speed': 0.0005497932434082031, 'Forward computations': 52410}
# 1.1246271133422852
# 0.000152587890625
# {'Filename': '0117.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.5, 'Word Count': 4, 'transcription': 'piper picked peter peppers', 'Viterbi transcription': 'a piper the the the of the', 'Decode speed': 1.1246271133422852, 'Backtrace speed': 0.000152587890625, 'Forward computations': 44394}
# 1.8144726753234863
# 0.0003008842468261719
# {'Filename': '0118.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.5, 'Word Count': 8, 'transcription': "peter where's the peck of peppers piper picked", 'Viterbi transcription': "a the where's of peck of of piper picked", 'Decode speed': 1.8144726753234863, 'Backtrace speed': 0.0003008842468261719, 'Forward computations': 69182}
# 1.3383870124816895
# 0.00016808509826660156
# {'Filename': '0119.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.75, 'Word Count': 4, 'transcription': 'piper peck pickled peppers', 'Viterbi transcription': 'a piper peck a', 'Decode speed': 1.3383870124816895, 'Backtrace speed': 0.00016808509826660156, 'Forward computations': 51006}
# 0.7126309871673584
# 9.465217590332031e-05
# {'Filename': '0120.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peck pickled peter', 'Viterbi transcription': 'a a pickled peter', 'Decode speed': 0.7126309871673584, 'Backtrace speed': 9.465217590332031e-05, 'Forward computations': 28232}
# 0.990755558013916
# 0.00012993812561035156
# ...
# 2.12778639793396
# 0.0006606578826904297
# {'Filename': '0257.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.5882352941176471, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a a of of of a of peck of pickled peppers where's the peck of picked of of picked peter piper picked", 'Decode speed': 2.12778639793396, 'Backtrace speed': 0.0006606578826904297, 'Forward computations': 81810}
# 2.266117811203003
# 0.0006744861602783203
# {'Filename': '0258.wav', 'Insertions': 2, 'Deletions': 2, 'Substitutions': 5, 'WER': 0.5294117647058824, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a picked of of picked peck of where's the peck of pickled peppers peter of picked picked", 'Decode speed': 2.266117811203003, 'Backtrace speed': 0.0006744861602783203, 'Forward computations': 87050}
# 1.6469461917877197
# 0.0004687309265136719
# {'Filename': '0259.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 5, 'WER': 0.47058823529411764, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': "a picked of picked peck of pickled of picked where's the peck of picked peppers peter of picked", 'Decode speed': 1.6469461917877197, 'Backtrace speed': 0.0004687309265136719, 'Forward computations': 63604}
# 0.9257309436798096
# 0.0002715587615966797
# {'Filename': '0260.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.0, 'Word Count': 6, 'transcription': 'peck of pickled peppers peter picked', 'Viterbi transcription': 'a of picked of piper picked of a', 'Decode speed': 0.9257309436798096, 'Backtrace speed': 0.0002715587615966797, 'Forward computations': 34984}
# 0.8347675800323486
# 0.00019812583923339844
# {'Filename': '0261.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.8, 'Word Count': 5, 'transcription': "where's the peck peter picked", 'Viterbi transcription': "a where's the peck picked of a", 'Decode speed': 0.8347675800323486, 'Backtrace speed': 0.00019812583923339844, 'Forward computations': 31612}
# 0.7431454658508301
# 9.751319885253906e-05
# {'Filename': '0262.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.0, 'Word Count': 5, 'transcription': 'pickled peppers peter piper picked', 'Viterbi transcription': 'a pickled of the of of picked', 'Decode speed': 0.7431454658508301, 'Backtrace speed': 9.751319885253906e-05, 'Forward computations': 28288}
# 0.9329211711883545
# 0.000156402587890625
# {'Filename': '0263.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'peter picked peck of pickled peppers', 'Viterbi transcription': 'a a of peck peck of pickled piper', 'Decode speed': 0.9329211711883545, 'Backtrace speed': 0.000156402587890625, 'Forward computations': 36890}
# 0.7448248863220215
# 0.00016570091247558594
# {'Filename': '0264.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': "where's peter piper peck", 'Viterbi transcription': "a where's peter piper peck", 'Decode speed': 0.7448248863220215, 'Backtrace speed': 0.00016570091247558594, 'Forward computations': 29380}
# 0.6855349540710449
# 9.322166442871094e-05
# {'Filename': '0265.wav', 'Insertions': 0, 'Deletions': 1, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 3, 'transcription': 'piper picked peppers', 'Viterbi transcription': 'a of', 'Decode speed': 0.6855349540710449, 'Backtrace speed': 9.322166442871094e-05, 'Forward computations': 26988}
# 0.9894213676452637
# 0.00021123886108398438
# {'Filename': '0266.wav', 'Insertions': 0, 'Deletions': 2, 'Substitutions': 4, 'WER': 1.0, 'Word Count': 6, 'transcription': "where's peter piper pickled picked peppers", 'Viterbi transcription': 'a of of a', 'Decode speed': 0.9894213676452637, 'Backtrace speed': 0.00021123886108398438, 'Forward computations': 36904}
# 0.7266371250152588
# 0.0001633167266845703
# {'Filename': '0267.wav', 'Insertions': 0, 'Deletions': 2, 'Substitutions': 3, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'the peck of peppers peter picked', 'Viterbi transcription': 'a of of a', 'Decode speed': 0.7266371250152588, 'Backtrace speed': 0.0001633167266845703, 'Forward computations': 26878}
# 0.7333567142486572
# 0.00017523765563964844
# {'Filename': '0268.wav', 'Insertions': 0, 'Deletions': 3, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': "where's the pickled peck of peppers", 'Viterbi transcription': 'a of the', 'Decode speed': 0.7333567142486572, 'Backtrace speed': 0.00017523765563964844, 'Forward computations': 27264}
# 1.270308256149292
# 0.00026702880859375
# {'Filename': '0269.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peter piper picked pickled peppers', 'Viterbi transcription': 'a peter piper a picked of', 'Decode speed': 1.270308256149292, 'Backtrace speed': 0.00026702880859375, 'Forward computations': 47974}
# 0.8365442752838135
# 0.0002739429473876953
# {'Filename': '0270.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peter picked piper', 'Viterbi transcription': 'a peter a piper', 'Decode speed': 0.8365442752838135, 'Backtrace speed': 0.0002739429473876953, 'Forward computations': 31402}
# 1.0398650169372559
# 0.000286102294921875
# {'Filename': '0271.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 4, 'transcription': 'picked peppers picked piper', 'Viterbi transcription': 'a a picked picked piper', 'Decode speed': 1.0398650169372559, 'Backtrace speed': 0.000286102294921875, 'Forward computations': 39108}
# 1.1435742378234863
# 0.00020837783813476562
# {'Filename': '0272.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': "where's the pickled peppers piper picked", 'Viterbi transcription': "a where's the picked where's a", 'Decode speed': 1.1435742378234863, 'Backtrace speed': 0.00020837783813476562, 'Forward computations': 42450}
# 1.3007874488830566
# 0.00018668174743652344
# {'Filename': '0273.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 6, 'WER': 1.0, 'Word Count': 7, 'transcription': 'peck of picked peppers piper peter picked', 'Viterbi transcription': 'a picked a picked of the of a', 'Decode speed': 1.3007874488830566, 'Backtrace speed': 0.00018668174743652344, 'Forward computations': 49852}
# 1.177211046218872
# 0.0001475811004638672
# {'Filename': '0274.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peter piper picked peppers', 'Viterbi transcription': 'a peter piper picked peppers', 'Decode speed': 1.177211046218872, 'Backtrace speed': 0.0001475811004638672, 'Forward computations': 45614}
# 0.7573535442352295
# 0.00023889541625976562
# {'Filename': '0275.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': 'pickled peppers picked', 'Viterbi transcription': 'a a of peppers a', 'Decode speed': 0.7573535442352295, 'Backtrace speed': 0.00023889541625976562, 'Forward computations': 29896}
# 1.2401106357574463
# 0.00031757354736328125
# {'Filename': '0276.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.5714285714285714, 'Word Count': 7, 'transcription': 'peter piper picked a peck of peppers', 'Viterbi transcription': 'a peter piper picked of peck peck of', 'Decode speed': 1.2401106357574463, 'Backtrace speed': 0.00031757354736328125, 'Forward computations': 47464}
# 0.9259724617004395
# 0.0002200603485107422
# {'Filename': '0277.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 4, 'transcription': 'piper picked pickled peppers', 'Viterbi transcription': "a piper a pickled of where's", 'Decode speed': 0.9259724617004395, 'Backtrace speed': 0.0002200603485107422, 'Forward computations': 36546}
# 0.9634101390838623
# 0.00024008750915527344
# {'Filename': '0278.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peter piper pickled peppers', 'Viterbi transcription': 'a peter piper pickled peppers', 'Decode speed': 0.9634101390838623, 'Backtrace speed': 0.00024008750915527344, 'Forward computations': 36976}
# 1.138169765472412
# 0.00029206275939941406
# {'Filename': '0279.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.25, 'Word Count': 4, 'transcription': 'peck the peppers peck', 'Viterbi transcription': "a a of where's a", 'Decode speed': 1.138169765472412, 'Backtrace speed': 0.00029206275939941406, 'Forward computations': 44360}
# 1.147028923034668
# 0.0002429485321044922
# {'Filename': '0280.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'piper the piper pickled peppers', 'Viterbi transcription': 'a of the piper picked', 'Decode speed': 1.147028923034668, 'Backtrace speed': 0.0002429485321044922, 'Forward computations': 43624}
# 1.1371698379516602
# 0.00014328956604003906
# {'Filename': '0281.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 5, 'WER': 1.0, 'Word Count': 7, 'transcription': 'peter picked piper picked the picked peppers', 'Viterbi transcription': 'a a of the a of the picked piper', 'Decode speed': 1.1371698379516602, 'Backtrace speed': 0.00014328956604003906, 'Forward computations': 43050}
# 0.956719160079956
# 0.00012612342834472656
# {'Filename': '0282.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.4, 'Word Count': 5, 'transcription': 'pickled piper peppers pickled peter', 'Viterbi transcription': "a a of of of of where's pickled peter", 'Decode speed': 0.956719160079956, 'Backtrace speed': 0.00012612342834472656, 'Forward computations': 36578}
# 1.5067219734191895
# 0.0002090930938720703
# {'Filename': '0283.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 8, 'WER': 0.7647058823529411, 'Word Count': 17, 'transcription': "piper peter picked a peck of pickled peppers where's the peck of pickled peppers piper peter picked", 'Viterbi transcription': "a of peter the of a of the of of where's where's the peck of the of peppers piper the of the", 'Decode speed': 1.5067219734191895, 'Backtrace speed': 0.0002090930938720703, 'Forward computations': 58258}
# 0.6651051044464111
# 8.940696716308594e-05
# {'Filename': '0284.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 2, 'transcription': 'the peck', 'Viterbi transcription': 'a peck', 'Decode speed': 0.6651051044464111, 'Backtrace speed': 8.940696716308594e-05, 'Forward computations': 26522}
# 0.6845614910125732
# 9.1552734375e-05
# {'Filename': '0285.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': "where's the peck peter", 'Viterbi transcription': "a where's the peck peter", 'Decode speed': 0.6845614910125732, 'Backtrace speed': 9.1552734375e-05, 'Forward computations': 27634}
# 0.7523543834686279
# 9.846687316894531e-05
# {'Filename': '0286.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 3, 'transcription': 'piper pickled peppers', 'Viterbi transcription': 'a piper pickled peppers', 'Decode speed': 0.7523543834686279, 'Backtrace speed': 9.846687316894531e-05, 'Forward computations': 30146}
# 1.0554611682891846
# 0.00023245811462402344
# {'Filename': '0287.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'a peck of pickled peppers peter piper picked', 'Viterbi transcription': "a of peck of pickled the of where's peter piper picked", 'Decode speed': 1.0554611682891846, 'Backtrace speed': 0.00023245811462402344, 'Forward computations': 40748}
# 0.997870922088623
# 0.00013208389282226562
# {'Filename': '0288.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'peppers pickled a peck picked peter', 'Viterbi transcription': 'a of of pickled of peck picked peter', 'Decode speed': 0.997870922088623, 'Backtrace speed': 0.00013208389282226562, 'Forward computations': 38844}
# 0.6025757789611816
# 8.273124694824219e-05
# {'Filename': '0289.wav', 'Insertions': 0, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': 'a peck peter', 'Decode speed': 0.6025757789611816, 'Backtrace speed': 8.273124694824219e-05, 'Forward computations': 23810}
# 0.6786675453186035
# 8.940696716308594e-05
# {'Filename': '0290.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 4, 'transcription': 'peck of pickled peppers', 'Viterbi transcription': "a picked of pickled where's", 'Decode speed': 0.6786675453186035, 'Backtrace speed': 8.940696716308594e-05, 'Forward computations': 25808}
# 0.6133654117584229
# 7.891654968261719e-05
# {'Filename': '0291.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': "where's peter piper", 'Viterbi transcription': 'a picked a of piper', 'Decode speed': 0.6133654117584229, 'Backtrace speed': 7.891654968261719e-05, 'Forward computations': 23200}
# 0.8261051177978516
# 0.00010919570922851562
# {'Filename': '0292.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 4, 'transcription': 'pickled peck of peppers', 'Viterbi transcription': 'a of peck of picked', 'Decode speed': 0.8261051177978516, 'Backtrace speed': 0.00010919570922851562, 'Forward computations': 31702}
# 0.8775460720062256
# 0.0001957416534423828
# {'Filename': '0293.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peter piper picked a peck', 'Viterbi transcription': "a where's piper a peck peck", 'Decode speed': 0.8775460720062256, 'Backtrace speed': 0.0001957416534423828, 'Forward computations': 33042}
# 1.6403594017028809
# 0.001253366470336914
# {'Filename': '0294.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': 'peppers of piper peck peter', 'Viterbi transcription': "a where's of piper peck peter", 'Decode speed': 1.6403594017028809, 'Backtrace speed': 0.001253366470336914, 'Forward computations': 61698}
# 0.975792407989502
# 0.00024247169494628906
# {'Filename': '0295.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 6, 'transcription': 'peter a piper of a peck', 'Viterbi transcription': 'a peter of piper of a of', 'Decode speed': 0.975792407989502, 'Backtrace speed': 0.00024247169494628906, 'Forward computations': 36628}
# 1.0277495384216309
# 0.000270843505859375
# {'Filename': '0296.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 4, 'transcription': 'peck pickled peter peck', 'Viterbi transcription': 'a peck pickled picked a', 'Decode speed': 1.0277495384216309, 'Backtrace speed': 0.000270843505859375, 'Forward computations': 38566}
# 1.538644790649414
# 0.0004570484161376953
# {'Filename': '0297.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'a piper of peter picked peppers of pickled peter', 'Viterbi transcription': "a a piper of peter of where's of pickled peter", 'Decode speed': 1.538644790649414, 'Backtrace speed': 0.0004570484161376953, 'Forward computations': 59134}
# 1.1618189811706543
# 0.0002918243408203125
# {'Filename': '0298.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.0, 'Word Count': 5, 'transcription': 'of peck a peter pickled', 'Viterbi transcription': 'a of peppers picked of picked', 'Decode speed': 1.1618189811706543, 'Backtrace speed': 0.0002918243408203125, 'Forward computations': 43580}

# %%
#task 4
#Bigram Probabilities

from collections import defaultdict
bigram_count=defaultdict(int)
word_count = defaultdict(int)


for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    transcription = read_transcription(wav_file)
    transcription = "<s> "+ str(transcription)+" </s>"
    transcription = transcription.split(" ")
    for i in range(1,len(transcription)):
        bigram = transcription[i]+ " "+transcription[i+1]
        bigram_count[bigram]+=1
        print(word)
        print(bigram)
        
total_words = sum(word_count.values())
# probabilities ={bigram:count/total_words for word,count in word_count.items()}
# print(word_count,bigram_probabilities)

# %%
#task 4 reducing the number of states in wfst by having silence be connected for all
def create_wfst_silent_2(n, probabilities=None, next_state_prob=0.5, sil_prob=0.5):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs."""
    silent_state_table = deepcopy(state_table)
    for i in range(1, 6):
        silent_state_table.add_symbol('sil_{}'.format(i))


    f = fst.Fst('log')
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    f.set_final(start_state)
    start_weight= fst.Weight('log', -math.log(1))
    
    this_state = f.add_state()
    first_sil = this_state
    for i in range(1,6):
        weight = fst.Weight('log',-math.log(1-next_state_prob))
        
        f.add_arc(this_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0, weight, this_state))
        next_state= f.add_state()
        weight = fst.Weight('log',-math.log(next_state_prob))
        f.add_arc(this_state,fst.Arc(silent_state_table.find('sil_{}'.format(i)),0,weight,next_state))
        this_state=next_state
    
    weight = fst.Weight('log',-math.log(1))
    f.add_arc(this_state,fst.Arc(0,0, weight, start_state))

    
    for word, phones in lex.items():
        out_label = word_table.find(word)
        if probabilities:
            start_weight = fst.Weight('log', -math.log(probabilities[word]))
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0,start_weight , current_state))
        
        for phone in phones: 
            last_state = current_state
            current_state = generate_phone_wfst(f, current_state, phone, n,next_state_prob)
            
        weight = fst.Weight('log',-math.log(1-sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,start_state))
        weight = fst.Weight('log',-math.log(sil_prob))
        f.add_arc(current_state,fst.Arc(0,out_label,weight,first_sil))
        
        

        

            
            
            

    f.set_input_symbols(silent_state_table)
    f.set_output_symbols(word_table)


    return f

    
f=create_wfst_silent_2(3)
draw_fst(f)

# %%
print(num_states(f))
print(total_num_arcs(f))
f=create_wfst_silent(3,probabilities,next_state_prob=0.1,sil_prob=0.5)
results_df=[]
for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                      # audio files
    decoder = MyViterbiDecoder(f, wav_file)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    
    # Append results to the DataFrame
    results_df.append(row)
    
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('result_silent_new.csv')

# %%
#task 4 tree structure diagrams
