# %% [markdown]
# # ASR Assignment 2022-23
#
# This notebook has been provided as a template to get you started on the assignment.  Feel free to use it for your development, or do your development directly in Python.
#
# You can find a full description of the assignment [here](http://www.inf.ed.ac.uk/teaching/courses/asr/2022-23/coursework.pdf).
#
# You are provided with two Python modules `observation_model.py` and `wer.py`.  The first was described in [Lab 3](https://github.com/ZhaoZeyu1995/asr_labs/blob/master/asr_lab3_4.ipynb).  The second can be used to compute the number of substitution, deletion and insertion errors between ASR output and a reference text.
#
# It can be used as follows:
#
# ```python
# import wer
#
# my_refence = 'A B C'
# my_output = 'A C C D'
#
# wer.compute_alignment_errors(my_reference, my_output)
# ```
#
# This produces a tuple $(s,d,i)$ giving counts of substitution,
# deletion and insertion errors respectively - in this example (1, 0, 1).  The function accepts either two strings, as in the example above, or two lists.  Matching is case sensitive.
#
# ## Template code
#
# Assuming that you have already made a function to generate an WFST, `create_wfst()` and a decoder class, `MyViterbiDecoder`, you can perform recognition on all the audio files as follows:

# %%
import glob
import os
import wer
import observation_model
import openfst_python as fst

# ... (add your code to create WFSTs and Viterbi Decoder)
import observation_model
import math
import openfst_python as fst
import time

class MyViterbiDecoder:
    
    NLL_ZERO = 1e10  # define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    
    def __init__(self, f, audio_file_name, l):
        """Set up the decoder class with an audio file and WFST f
        """
        self.om = observation_model.ObservationModel()
        self.f = f
        self.l = l
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
        
        forward_computations = 0
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                for arc in self.f.arcs(i):
                    
                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        forward_computations += 1
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            self.V[t][j] = prob
                            self.B[t][j] = i
                            
                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
        return forward_computations
                            
    
    def finalise_decoding(self):
        """ this incorporates the probability of terminating at each state
        """
        
        for state in self.f.states():
            final_weight = float(self.f.final(state))
            if self.V[-1][state] != self.NLL_ZERO:
                if final_weight == math.inf:
                    self.V[-1][state] = self.NLL_ZERO  # effectively says that we can't end in this state
                else:
                    self.V[-1][state] += final_weight
                    
        # get a list of all states where there was a path ending with non-zero probability
        finished = [x for x in self.V[-1] if x < self.NLL_ZERO]
        if not finished:  # if empty
            print("No path got to the end of the observations.")
        
        
    def decode(self):
        forward_computations = 0
        initial = time.time()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            forward_computations += self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            t += 1
        self.finalise_decoding()
        final = time.time()
        return (forward_computations, (final - initial))
    
    def backtrace(self):
        
        initial = time.time()
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        
        
        
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence = transduce_sequence_det(Ldet,[ self.f.output_symbols().find(label) for label in best_out_sequence])
        
        # convert the best output sequence from FST integer labels into strings

        final = time.time()
        return (best_state_sequence, best_out_sequence,(final-initial))
import openfst_python as fst

def parse_lexicon(lex_file):
    """
    Parse the lexicon file and return it in dictionary form.
    
    Args:
        lex_file (str): filename of lexicon file with structure '<word> <phone1> <phone2>...'
                        eg. peppers p eh p er z

    Returns:
        lex (dict): dictionary mapping words to list of phones
    """
    
    lex = {}  # create a dictionary for the lexicon entries (this could be a problem with larger lexica)
    with open(lex_file, 'r') as f:
        for line in f:
            line = line.split()  # split at each space
            lex[line[0]] = line[1:]  # first field the word, the rest is the phones
    return lex

def generate_symbol_tables(lexicon, n=3):
    '''
    Return word, phone and state symbol tables based on the supplied lexicon
        
    Args:
        lexicon (dict): lexicon to use, created from the parse_lexicon() function
        n (int): number of states for each phone HMM
        
    Returns:
        word_table (fst.SymbolTable): table of words
        phone_table (fst.SymbolTable): table of phones
        state_table (fst.SymbolTable): table of HMM phone-state IDs
    '''
    
    state_table = fst.SymbolTable()
    phone_table = fst.SymbolTable()
    word_table = fst.SymbolTable()
    
    # add empty <eps> symbol to all tables
    state_table.add_symbol('<eps>')
    phone_table.add_symbol('<eps>')
    word_table.add_symbol('<eps>')
    
    for word, phones  in lexicon.items():
        
        word_table.add_symbol(word)
        
        for p in phones: # for each phone
            
            phone_table.add_symbol(p)
            for i in range(1,n+1): # for each state 1 to n
                state_table.add_symbol('{}_{}'.format(p, i))
            
    return word_table, phone_table, state_table


# call these two functions
lex = parse_lexicon('lexicon.txt')
word_table, phone_table, state_table = generate_symbol_tables(lex)
def generate_phone_wfst(f, start_state, phone, n):
    """
    Generate a WFST representing an n-state left-to-right phone HMM.
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assumed to exist already
        phone (str): the phone label 
        n (int): number of states of the HMM excluding start and end
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
    
        in_label = state_table.find('{}_{}'.format(phone, i))
        
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, None, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        if i == n:
            out_label = phone_table.find(phone)
        else:
            out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        f.add_arc(current_state, fst.Arc(in_label, out_label, None, next_state))    
       
        current_state = next_state
    return current_state



def create_wfst(n):
    """ Generate a WFST for any word in the lexicon, composed of n-state phone WFSTs.
        This will currently output phone labels.  
    
    Args:
        
        start_state (int): the index of the first state, assumed to exist already
        word (str): the word to generate
        n (int): states per phone HMM
        
    Returns:
        the constructed WFST
    
    """
    f = fst.Fst()
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
    
    for word, phones in lex.items():
        current_state = f.add_state()
        f.add_arc(start_state, fst.Arc(0, 0, None, current_state))
        
        for phone in phones: 
            current_state = generate_phone_wfst(f, current_state, phone, n)
        # note: new current_state is now set to the final state of the previous phone WFST
        
        f.set_final(current_state)
        f.add_arc(current_state, fst.Arc(0, 0, None, start_state))
        f.set_input_symbols(state_table)
        f.set_output_symbols(phone_table)
    return f




    


def read_transcription(wav_file):
    """
    Get the transcription corresponding to wav_file.
    """
    
    transcription_file = os.path.splitext(wav_file)[0] + '.txt'
    
    with open(transcription_file, 'r') as f:
        transcription = f.readline().strip()
    
    return transcription


f = create_wfst(3)

print([x for x in lex.values()])

def num_states(f):
    counter = 0
    for x in f.states():
        counter += 1
    return counter

def total_num_arcs(f):
    return sum(f.num_arcs(s) for s in f.states())
# Out:
# [['ey'], ['ah', 'v'], ['p', 'eh', 'k'], ['p', 'eh', 'p', 'er', 'z'], ['p', 'iy', 't', 'er'], ['p', 'ih', 'k', 't'], ['p', 'ih', 'k', 'ah', 'l', 'd'], ['p', 'ay', 'p', 'er'], ['dh', 'iy'], ['w', 'eh', 'r', 'z']]

# %%
#lexicon transducer
import openfst_python as fst


lex = parse_lexicon('lexicon.txt')
word_table, phone_table, state_table = generate_symbol_tables(lex)  # we won't use state_table in this lab

def generate_L_wfst(lex):
    """ Express the lexicon in WFST form
    
    Args:
        lexicon (dict): lexicon to use, created from the parse_lexicon() function
    
    Returns:
        the constructed lexicon WFST
    
    """
    L = fst.Fst()
    
    # create a single start state
    start_state = L.add_state()
    L.set_start(start_state)
    
    for (word, pron) in lex.items():
        
        current_state = start_state
        for (i,phone) in enumerate(pron):
            next_state = L.add_state()
            
            if i == len(pron)-1:
                # add word output symbol on the final arc
                L.add_arc(current_state, fst.Arc(phone_table.find(phone), \
                                                 word_table.find(word), None, next_state))
            else:
                L.add_arc(current_state, fst.Arc(phone_table.find(phone),0, None, next_state))
            
            current_state = next_state
                          
        L.set_final(current_state)
        
    L.set_input_symbols(phone_table)
    L.set_output_symbols(word_table)  
    start_state = L.start()
    L.arcsort()
    for state in L.states():
        if float(L.final(state)) != math.inf:
            L.add_arc(state, fst.Arc(0, 0, None, start_state))
    
    return L

L = generate_L_wfst(lex)
Ldet = fst.determinize(L)

def transduce_sequence_det(f, seq):
    """Return transduced sequence given input sequence and determinized FST
    
        Args:
            f (fst.Fst()): a determinized FST
            in_seq (list[str]): the sequence of strings to transduce
            
        Returns:
            out_seq (list[str]): the sequence of transduced symbols
            """
    
    seq_len = len(seq)
    eps = f.input_symbols().find('<eps>')
    curr_state = f.start()
    output = []
    
    for i in range(seq_len):
        
        found = False
        label = f.input_symbols().find(seq[i])
        
        while found ==False:
            for arc in f.arcs(curr_state):
                
                if arc.ilabel == label:
                    if arc.olabel != 0:

                        output_symbol = f.output_symbols().find(arc.olabel)
                        output.append(output_symbol)
                        

                    curr_state = arc.nextstate
                    found = True
                    break
                if arc.ilabel == 0:
                    curr_state = arc.nextstate
                    

    final_weight = float(f.final(curr_state))
    if final_weight != math.inf: # if this is a final state
        return output
    else:  
        print("Can't transduce the sequence with provided FST")

# %%
# !pip install pandas
import pandas as pd
results_df=[]
import wer

print(num_states(f))
print(total_num_arcs(f))

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                           # audio files
    
    decoder = MyViterbiDecoder(f, wav_file, Ldet)
    
    forward_computations, decode_speed = decoder.decode()
    print(decode_speed)
    (state_path, words, backtrace_speed) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
    # to return the words along the best path
    print(backtrace_speed)
    
    transcription = read_transcription(wav_file)
    
    word_count = len(transcription.split())
    



    
    error_counts = wer.compute_alignment_errors(transcription, words)
    word_count = len(transcription.split())
    worderror = sum(error_counts)/word_count
         # you'll need to accumulate these to produce an overall Word Error Rate
    filename = wav_file.split('/')[-1]
    row = {
        'Filename': filename,
        'Insertions': error_counts[2],
        'Deletions': error_counts[1],
        'Substitutions': error_counts[0],
        'WER': worderror,
        'Word Count': word_count,
        'transcription':transcription,
        'Viterbi transcription':words,
        'Decode speed': decode_speed,
        'Backtrace speed': backtrace_speed,
        'Forward computations': forward_computations
    }
    print(row)
    
    # Append results to the DataFrame
    results_df.append(row)
    
results_df = pd.DataFrame(results_df)
# Save the DataFrame to a CSV file
results_df.to_csv('resulto.csv')
# Out:
# Requirement already satisfied: pandas in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /afs/inf.ed.ac.uk/user/s20/s2024004/.conda/envs/asr_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# 116
# 230
# 7.824498653411865
# 0.004067420959472656
# {'Filename': '0000.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.23529411764705882, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['pickled', 'the', 'peter', 'piper', 'picked', 'a', 'the', 'peck', 'of', 'pickled', 'peppers', "where's", 'the', 'peck', 'of', 'pickled', 'peppers', 'peter', 'piper', 'picked', 'the'], 'Decode speed': 7.824498653411865, 'Backtrace speed': 0.004067420959472656, 'Forward computations': 240318}
# 3.69754958152771
# 0.0018551349639892578
# {'Filename': '0001.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': ['pickled', 'the', 'picked', 'the', 'peter', 'picked', 'the', 'of', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 3.69754958152771, 'Backtrace speed': 0.0018551349639892578, 'Forward computations': 136368}
# 2.8266618251800537
# 0.0009567737579345703
# {'Filename': '0002.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 6, 'transcription': 'a peck of pickled peppers picked', 'Viterbi transcription': ['pickled', 'the', 'peck', 'of', 'pickled', 'peppers', 'picked', 'the'], 'Decode speed': 2.8266618251800537, 'Backtrace speed': 0.0009567737579345703, 'Forward computations': 102348}
# 2.0403590202331543
# 0.0009615421295166016
# {'Filename': '0003.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.75, 'Word Count': 4, 'transcription': 'peter piper peter piper', 'Viterbi transcription': ['pickled', 'the', 'peter', 'piper', 'peter', 'piper', 'the'], 'Decode speed': 2.0403590202331543, 'Backtrace speed': 0.0009615421295166016, 'Forward computations': 75468}
# 3.3841841220855713
# 0.0016524791717529297
# {'Filename': '0004.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': "where's the peck of pickled peppers picked", 'Viterbi transcription': ['pickled', 'the', "where's", 'the', 'pickled', 'pickled', 'peppers', 'picked', 'the'], 'Decode speed': 3.3841841220855713, 'Backtrace speed': 0.0016524791717529297, 'Forward computations': 98778}
# 1.483565330505371
# 0.0005078315734863281
# {'Filename': '0005.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'peter piper pickled peppers', 'Viterbi transcription': ['peter', 'piper', 'pickled', 'peppers', 'the'], 'Decode speed': 1.483565330505371, 'Backtrace speed': 0.0005078315734863281, 'Forward computations': 59298}
# 0.865750789642334
# 0.00039577484130859375
# {'Filename': '0006.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 2, 'transcription': "where's peter", 'Viterbi transcription': ["where's", 'peter', 'picked', 'the'], 'Decode speed': 0.865750789642334, 'Backtrace speed': 0.00039577484130859375, 'Forward computations': 35988}
# 1.4300854206085205
# 0.0004963874816894531
# {'Filename': '0007.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'piper picked peppers of peter', 'Viterbi transcription': ['piper', 'picked', 'peppers', 'of', 'peter', 'the'], 'Decode speed': 1.4300854206085205, 'Backtrace speed': 0.0004963874816894531, 'Forward computations': 59298}
# 1.6852915287017822
# 0.001010894775390625
# {'Filename': '0008.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.16666666666666666, 'Word Count': 6, 'transcription': 'peter peppers picked piper of peck', 'Viterbi transcription': ['peter', 'peppers', 'picked', 'piper', 'of', 'peck', 'the'], 'Decode speed': 1.6852915287017822, 'Backtrace speed': 0.001010894775390625, 'Forward computations': 66438}
# 2.9792776107788086
# 0.0019068717956542969
# {'Filename': '0009.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'a peck of pickled peppers peter piper pickled', 'Viterbi transcription': ['peck', 'the', 'peck', 'peck', 'of', 'picked', 'peppers', 'peter', 'piper', 'pickled', 'the'], 'Decode speed': 2.9792776107788086, 'Backtrace speed': 0.0019068717956542969, 'Forward computations': 84498}
# 0.9277565479278564
# 0.0002834796905517578
# {'Filename': '0010.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 1, 'transcription': 'picked', 'Viterbi transcription': ['the', 'picked'], 'Decode speed': 0.9277565479278564, 'Backtrace speed': 0.0002834796905517578, 'Forward computations': 37878}
# 0.8440830707550049
# 0.0003581047058105469
# {'Filename': '0011.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 2.0, 'Word Count': 1, 'transcription': 'pickled', 'Viterbi transcription': ['the', 'pickled', 'the'], 'Decode speed': 0.8440830707550049, 'Backtrace speed': 0.0003581047058105469, 'Forward computations': 32418}
# 1.4297187328338623
# 0.000492095947265625
# {'Filename': '0012.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 2.0, 'Word Count': 1, 'transcription': 'peppers', 'Viterbi transcription': ['the', 'peppers', 'the'], 'Decode speed': 1.4297187328338623, 'Backtrace speed': 0.000492095947265625, 'Forward computations': 55728}
# 1.2205922603607178
# 0.000385284423828125
# {'Filename': '0013.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 2.0, 'Word Count': 1, 'transcription': 'piper', 'Viterbi transcription': ['the', 'piper', 'the'], 'Decode speed': 1.2205922603607178, 'Backtrace speed': 0.000385284423828125, 'Forward computations': 50268}
# 1.2402088642120361
# 0.0007696151733398438
# {'Filename': '0014.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 2.0, 'Word Count': 1, 'transcription': 'peter', 'Viterbi transcription': ['the', 'peter', 'the'], 'Decode speed': 1.2402088642120361, 'Backtrace speed': 0.0007696151733398438, 'Forward computations': 45018}
# 2.05314564704895
# 0.001371145248413086
# {'Filename': '0015.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': ['the', "where's", 'the', 'peck', 'the', 'of', 'the', 'pickled', 'peppers', 'the'], 'Decode speed': 2.05314564704895, 'Backtrace speed': 0.001371145248413086, 'Forward computations': 82608}
# 1.2627925872802734
# 0.0004601478576660156
# {'Filename': '0016.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': ['the', 'peter', 'piper', 'the', 'picked', 'the'], 'Decode speed': 1.2627925872802734, 'Backtrace speed': 0.0004601478576660156, 'Forward computations': 52158}
# 2.865711212158203
# 0.0017905235290527344
# {'Filename': '0017.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['the', 'peter', 'of', 'piper', 'picked', 'picked', 'of', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 2.865711212158203, 'Backtrace speed': 0.0017905235290527344, 'Forward computations': 114948}
# 1.3990869522094727
# 0.0009586811065673828
# {'Filename': '0018.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8333333333333334, 'Word Count': 6, 'transcription': 'picked a peck of pickled peppers', 'Viterbi transcription': ['the', 'picked', 'the', 'peck', 'of', 'pickled', 'peck', "where's", 'the'], 'Decode speed': 1.3990869522094727, 'Backtrace speed': 0.0009586811065673828, 'Forward computations': 57618}
# 2.5699880123138428
# 0.0011479854583740234
# {'Filename': '0019.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.6666666666666667, 'Word Count': 3, 'transcription': 'peter piper picked', 'Viterbi transcription': ['the', 'peter', 'of', 'piper', 'the', 'a', 'picked', 'the'], 'Decode speed': 2.5699880123138428, 'Backtrace speed': 0.0011479854583740234, 'Forward computations': 104028}
# 3.5449979305267334
# 0.0022683143615722656
# {'Filename': '0020.wav', 'Insertions': 9, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.5714285714285714, 'Word Count': 7, 'transcription': "peppers picked peter piper where's the peck", 'Viterbi transcription': ['the', 'peppers', 'picked', 'the', 'picked', 'piper', 'the', 'a', 'peck', 'the', "where's", 'the', 'picked', 'the', 'picked', 'the'], 'Decode speed': 3.5449979305267334, 'Backtrace speed': 0.0022683143615722656, 'Forward computations': 141828}
# 5.117073059082031
# 0.0030236244201660156
# {'Filename': '0021.wav', 'Insertions': 8, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.9, 'Word Count': 10, 'transcription': 'peter picked a peck piper pickled peppers of pickled peppers', 'Viterbi transcription': ['the', 'peter', "where's", 'picked', 'of', 'peck', 'the', 'piper', 'the', 'of', 'pickled', 'the', 'peppers', 'of', 'the', 'pickled', 'peppers', 'the'], 'Decode speed': 5.117073059082031, 'Backtrace speed': 0.0030236244201660156, 'Forward computations': 200838}
# 3.6924405097961426
# 0.002167940139770508
# {'Filename': '0022.wav', 'Insertions': 11, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.5, 'Word Count': 8, 'transcription': 'peter piper piper peter peter peter piper piper', 'Viterbi transcription': ['the', 'picked', 'peck', 'piper', 'the', 'of', 'piper', 'the', 'peter', 'picked', 'peter', 'of', 'peter', 'of', 'piper', 'the', 'of', 'piper', 'the'], 'Decode speed': 3.6924405097961426, 'Backtrace speed': 0.002167940139770508, 'Forward computations': 150648}
# 2.815653085708618
# 0.0012011528015136719
# {'Filename': '0023.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 1.0, 'Word Count': 4, 'transcription': 'peter picked piper peppers', 'Viterbi transcription': ['the', 'peter', 'of', 'picked', 'piper', 'of', 'peppers', 'the'], 'Decode speed': 2.815653085708618, 'Backtrace speed': 0.0012011528015136719, 'Forward computations': 97938}
# 3.153947114944458
# 0.002230405807495117
# {'Filename': '0024.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.3333333333333333, 'Word Count': 6, 'transcription': 'peter peter peter peter peter peter', 'Viterbi transcription': ['the', 'peter', 'peck', 'peter', 'picked', 'peter', 'peck', 'peter', 'picked', 'pickled', 'picked', 'the'], 'Decode speed': 3.153947114944458, 'Backtrace speed': 0.002230405807495117, 'Forward computations': 109488}
# 2.7889297008514404
# 0.0019865036010742188
# {'Filename': '0025.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.8571428571428571, 'Word Count': 7, 'transcription': 'piper picked a peck of peter peppers', 'Viterbi transcription': ['peck', 'the', 'the', 'piper', 'picked', 'of', 'peck', 'of', 'peter', 'peppers', 'the', 'the'], 'Decode speed': 2.7889297008514404, 'Backtrace speed': 0.0019865036010742188, 'Forward computations': 113058}
# 2.754384756088257
# 0.0018885135650634766
# {'Filename': '0026.wav', 'Insertions': 7, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.125, 'Word Count': 8, 'transcription': 'pickled peppers peter piper picked a peck of', 'Viterbi transcription': ['peck', 'the', 'peck', 'pickled', 'of', "where's", 'peter', 'piper', 'the', 'picked', 'the', 'peck', 'of', 'the', 'the'], 'Decode speed': 2.754384756088257, 'Backtrace speed': 0.0018885135650634766, 'Forward computations': 109488}
# 3.574838876724243
# 0.001997232437133789
# {'Filename': '0027.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.875, 'Word Count': 8, 'transcription': 'of peppers of picked a peter piper of', 'Viterbi transcription': ['the', 'of', 'of', "where's", 'of', 'picked', 'of', 'peter', 'piper', 'of', 'the', 'picked', 'picked'], 'Decode speed': 3.574838876724243, 'Backtrace speed': 0.001997232437133789, 'Forward computations': 132798}
# 2.2691662311553955
# 0.00157928466796875
# {'Filename': '0028.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 5, 'transcription': 'pickled peppers peter piper picked', 'Viterbi transcription': ['the', 'pickled', 'peppers', 'picked', 'of', 'piper', 'of', 'picked', 'the'], 'Decode speed': 2.2691662311553955, 'Backtrace speed': 0.00157928466796875, 'Forward computations': 84498}
# 2.1302781105041504
# 0.0009732246398925781
# {'Filename': '0029.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8571428571428571, 'Word Count': 7, 'transcription': 'peter picked a peck of pickled peppers', 'Viterbi transcription': ['peck', 'the', 'a', 'picked', 'picked', 'of', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 2.1302781105041504, 'Backtrace speed': 0.0009732246398925781, 'Forward computations': 86178}
# 2.2373437881469727
# 0.001712799072265625
# {'Filename': '0030.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': "where's a peck of pickled peppers peter piper picked", 'Viterbi transcription': ['the', "where's", 'of', 'peck', 'pickled', 'peppers', 'peter', 'piper', 'picked', 'the'], 'Decode speed': 2.2373437881469727, 'Backtrace speed': 0.001712799072265625, 'Forward computations': 91638}
# 2.0014610290527344
# 0.0013332366943359375
# {'Filename': '0031.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peter piper picked the peppers', 'Viterbi transcription': ['picked', 'piper', 'of', 'picked', 'of', 'peppers', 'the'], 'Decode speed': 2.0014610290527344, 'Backtrace speed': 0.0013332366943359375, 'Forward computations': 54048}
# 2.3105974197387695
# 0.0014185905456542969
# {'Filename': '0032.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.2, 'Word Count': 5, 'transcription': 'pickled peppers picked peter piper', 'Viterbi transcription': ['the', 'pickled', 'peck', 'picked', 'a', 'picked', 'piper', 'of', 'the'], 'Decode speed': 2.3105974197387695, 'Backtrace speed': 0.0014185905456542969, 'Forward computations': 61188}
# 1.5895392894744873
# 0.0009515285491943359
# {'Filename': '0033.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4, 'Word Count': 5, 'transcription': 'a peck of pickled peppers', 'Viterbi transcription': ['the', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 1.5895392894744873, 'Backtrace speed': 0.0009515285491943359, 'Forward computations': 62868}
# 1.5770626068115234
# 0.0009872913360595703
# {'Filename': '0034.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': "where's the peck peter picked", 'Viterbi transcription': ['the', "where's", 'the', 'peck', 'peter', 'picked', 'the'], 'Decode speed': 1.5770626068115234, 'Backtrace speed': 0.0009872913360595703, 'Forward computations': 46698}
# 2.126075029373169
# 0.0015022754669189453
# {'Filename': '0035.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 4, 'transcription': 'pickled peppers piper picked', 'Viterbi transcription': ['the', 'pickled', 'peppers', 'piper', 'picked', "where's"], 'Decode speed': 2.126075029373169, 'Backtrace speed': 0.0015022754669189453, 'Forward computations': 86178}
# 1.165276288986206
# 0.00041675567626953125
# {'Filename': '0036.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': ['the', 'peter', 'picked', 'peppers', 'the'], 'Decode speed': 1.165276288986206, 'Backtrace speed': 0.00041675567626953125, 'Forward computations': 48588}
# 3.0412206649780273
# 0.001359701156616211
# {'Filename': '0037.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.375, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['the', 'peter', 'piper', 'picked', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 3.0412206649780273, 'Backtrace speed': 0.001359701156616211, 'Forward computations': 80928}
# 1.9375221729278564
# 0.0010592937469482422
# {'Filename': '0038.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.875, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['peck', 'the', 'peter', 'picked', 'a', 'picked', 'picked', 'picked', 'pickled', 'peppers', 'the'], 'Decode speed': 1.9375221729278564, 'Backtrace speed': 0.0010592937469482422, 'Forward computations': 79038}
# 1.7384936809539795
# 0.0009546279907226562
# {'Filename': '0039.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.14285714285714285, 'Word Count': 7, 'transcription': 'peppers pickled peter of the piper peck', 'Viterbi transcription': ['peppers', 'pickled', 'peter', 'of', 'the', 'piper', 'peck', 'the'], 'Decode speed': 1.7384936809539795, 'Backtrace speed': 0.0009546279907226562, 'Forward computations': 70008}
# 2.3205060958862305
# 0.001203298568725586
# {'Filename': '0040.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.625, 'Word Count': 8, 'transcription': "piper peter picked where's the pickled peppers peter", 'Viterbi transcription': ['picked', 'the', 'peck', 'peter', 'picked', "where's", 'the', 'pickled', 'peppers', 'peter', 'a', 'the'], 'Decode speed': 2.3205060958862305, 'Backtrace speed': 0.001203298568725586, 'Forward computations': 96888}
# 1.8294665813446045
# 0.0008194446563720703
# {'Filename': '0041.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': 'peck pickled piper of the peter peppers', 'Viterbi transcription': ['the', 'peck', 'pickled', 'picked', 'of', 'the', 'peter', 'peppers', 'the'], 'Decode speed': 1.8294665813446045, 'Backtrace speed': 0.0008194446563720703, 'Forward computations': 75468}
# 2.4618191719055176
# 0.0014667510986328125
# {'Filename': '0042.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.36363636363636365, 'Word Count': 11, 'transcription': 'a peck of pickled peter picked the peppers of the peck', 'Viterbi transcription': ['peck', 'the', 'peck', 'of', 'pickled', 'peter', 'peck', 'the', 'peppers', 'of', 'the', 'peck', 'the'], 'Decode speed': 2.4618191719055176, 'Backtrace speed': 0.0014667510986328125, 'Forward computations': 93318}
# 2.224602460861206
# 0.0009436607360839844
# {'Filename': '0043.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.7142857142857143, 'Word Count': 7, 'transcription': "where's the peck of peppers piper pickled", 'Viterbi transcription': ['the', "where's", 'of', 'a', 'of', 'peppers', 'piper', 'of', 'pickled', 'the'], 'Decode speed': 2.224602460861206, 'Backtrace speed': 0.0009436607360839844, 'Forward computations': 79038}
# 2.2953484058380127
# 0.0015540122985839844
# {'Filename': '0044.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'piper pickled peppers of the peck peter picked', 'Viterbi transcription': ['the', 'piper', 'of', 'pickled', 'peppers', 'of', 'the', 'piper', 'peter', 'peck', 'the'], 'Decode speed': 2.2953484058380127, 'Backtrace speed': 0.0015540122985839844, 'Forward computations': 91638}
# 2.1604108810424805
# 0.0007450580596923828
# {'Filename': '0045.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.0, 'Word Count': 6, 'transcription': 'piper peter picked pickled piper peppers', 'Viterbi transcription': ['pickled', 'the', "where's", 'peck', 'pickled', 'picked', 'peppers', 'the'], 'Decode speed': 2.1604108810424805, 'Backtrace speed': 0.0007450580596923828, 'Forward computations': 89748}
# 2.439107894897461
# 0.0015478134155273438
# {'Filename': '0046.wav', 'Insertions': 8, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.0909090909090908, 'Word Count': 11, 'transcription': 'peter picked peppers of the pickled peck of peppers of piper', 'Viterbi transcription': ['a', 'the', 'the', 'picked', 'the', 'the', "where's", 'of', 'the', 'of', 'pickled', 'pickled', 'peck', "where's", 'of', 'of', 'the', 'of', 'the'], 'Decode speed': 2.439107894897461, 'Backtrace speed': 0.0015478134155273438, 'Forward computations': 96888}
# 4.191169261932373
# 0.002674102783203125
# {'Filename': '0047.wav', 'Insertions': 5, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.5294117647058824, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['a', 'the', 'pickled', 'piper', 'picked', 'peck', 'of', 'picked', 'of', 'peppers', 'the', "where's", 'the', 'peck', 'of', 'picked', 'peppers', 'peter', 'piper', 'picked', 'the'], 'Decode speed': 4.191169261932373, 'Backtrace speed': 0.002674102783203125, 'Forward computations': 168708}
# 2.3243980407714844
# 0.001077413558959961
# {'Filename': '0048.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['a', 'the', 'of', 'peter', 'piper', 'picked', 'the', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 2.3243980407714844, 'Backtrace speed': 0.001077413558959961, 'Forward computations': 93318}
# 1.8920514583587646
# 0.0015044212341308594
# {'Filename': '0049.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ["where's", 'the', 'peck', 'of', 'picked', 'of', 'peppers', 'peter', 'piper', 'picked', 'the'], 'Decode speed': 1.8920514583587646, 'Backtrace speed': 0.0015044212341308594, 'Forward computations': 77148}
# 1.8090031147003174
# 0.0006654262542724609
# {'Filename': '0050.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 5, 'transcription': 'pickled peppers pickled peter piper', 'Viterbi transcription': ['the', 'pickled', 'of', "where's", 'pickled', 'picked', 'piper', 'the'], 'Decode speed': 1.8090031147003174, 'Backtrace speed': 0.0006654262542724609, 'Forward computations': 73578}
# 2.707139253616333
# 0.0011684894561767578
# {'Filename': '0051.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.5454545454545454, 'Word Count': 11, 'transcription': 'peter piper picked a peck of pickled peppers peter piper pickled', 'Viterbi transcription': ['the', 'peck', 'peter', 'piper', 'picked', 'of', 'picked', 'of', 'pickled', "where's", 'peter', 'piper', 'pickled', "where's"], 'Decode speed': 2.707139253616333, 'Backtrace speed': 0.0011684894561767578, 'Forward computations': 111378}
# 1.8073344230651855
# 0.001184225082397461
# {'Filename': '0052.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 1, 'WER': 0.625, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['the', 'peter', 'of', 'piper', 'picked', 'peck', 'of', 'pickled', "where's", 'the'], 'Decode speed': 1.8073344230651855, 'Backtrace speed': 0.001184225082397461, 'Forward computations': 73578}
# 2.3141424655914307
# 0.0008540153503417969
# {'Filename': '0053.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 6, 'transcription': "where's the peck of pickled peppers", 'Viterbi transcription': ['the', "where's", 'of', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 2.3141424655914307, 'Backtrace speed': 0.0008540153503417969, 'Forward computations': 66438}
# 1.6005206108093262
# 0.0006244182586669922
# {'Filename': '0054.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 4, 'transcription': 'piper peter peppers pickled', 'Viterbi transcription': ['the', 'piper', 'of', 'peter', "where's", 'pickled', 'the'], 'Decode speed': 1.6005206108093262, 'Backtrace speed': 0.0006244182586669922, 'Forward computations': 59298}
# 1.8494386672973633
# 0.0009698867797851562
# {'Filename': '0055.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.7777777777777778, 'Word Count': 9, 'transcription': 'peter piper picked peter piper picked peter piper picked', 'Viterbi transcription': ['the', 'peter', 'of', 'piper', 'of', 'picked', 'peter', 'of', 'of', 'of', 'picked', 'peter', 'piper', 'of', 'picked'], 'Decode speed': 1.8494386672973633, 'Backtrace speed': 0.0009698867797851562, 'Forward computations': 75468}
# 1.8523743152618408
# 0.0007109642028808594
# {'Filename': '0056.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': "where's the peck of peter piper peppers", 'Viterbi transcription': ['the', "where's", 'the', 'peck', 'of', 'peter', 'piper', "where's", 'the'], 'Decode speed': 1.8523743152618408, 'Backtrace speed': 0.0007109642028808594, 'Forward computations': 62868}
# 2.568577527999878
# 0.0010058879852294922
# {'Filename': '0057.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.75, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['picked', 'the', 'picked', 'piper', 'pickled', 'peck', 'the', 'pickled', 'peppers', 'the'], 'Decode speed': 2.568577527999878, 'Backtrace speed': 0.0010058879852294922, 'Forward computations': 104028}
# 1.8495309352874756
# 0.0006759166717529297
# {'Filename': '0058.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'the peck of pickled peppers picked peter piper', 'Viterbi transcription': ['the', 'peck', 'of', 'the', 'pickled', 'of', "where's", 'peck', 'peter', 'piper', 'the'], 'Decode speed': 1.8495309352874756, 'Backtrace speed': 0.0006759166717529297, 'Forward computations': 77148}
# 2.230121374130249
# 0.0007574558258056641
# {'Filename': '0059.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 6, 'transcription': 'piper picked peter the pickled peppers', 'Viterbi transcription': ['peck', 'the', 'piper', 'of', 'picked', 'peter', 'the', 'pickled', 'picked', "where's", 'the'], 'Decode speed': 2.230121374130249, 'Backtrace speed': 0.0007574558258056641, 'Forward computations': 93318}
# 1.6013829708099365
# 0.0006771087646484375
# {'Filename': '0060.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peck piper peter pickled picked', 'Viterbi transcription': ['peck', 'the', 'peck', 'piper', 'peter', 'of', 'pickled', 'picked', 'the'], 'Decode speed': 1.6013829708099365, 'Backtrace speed': 0.0006771087646484375, 'Forward computations': 66438}
# 1.813098430633545
# 0.0010633468627929688
# {'Filename': '0061.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6, 'Word Count': 5, 'transcription': 'peck peppers pickled peter piper', 'Viterbi transcription': ['the', 'peck', 'peppers', 'pickled', 'peter', 'piper', 'picked', 'the'], 'Decode speed': 1.813098430633545, 'Backtrace speed': 0.0010633468627929688, 'Forward computations': 75468}
# 4.7013678550720215
# 0.0018508434295654297
# {'Filename': '0062.wav', 'Insertions': 5, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.5294117647058824, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['the', 'peter', 'of', 'piper', 'a', 'picked', 'of', 'picked', 'of', 'pickled', 'peppers', "where's", 'peck', 'of', 'pickled', 'peppers', 'the', 'picked', 'of', 'piper', 'picked'], 'Decode speed': 4.7013678550720215, 'Backtrace speed': 0.0018508434295654297, 'Forward computations': 189498}
# 2.692237138748169
# 0.0010247230529785156
# {'Filename': '0063.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8571428571428571, 'Word Count': 7, 'transcription': "peter piper picked where's the peck of", 'Viterbi transcription': ['the', 'picked', 'of', 'piper', 'picked', "where's", 'of', 'peck', 'pickled', 'of', 'the'], 'Decode speed': 2.692237138748169, 'Backtrace speed': 0.0010247230529785156, 'Forward computations': 107598}
# 3.8909497261047363
# 0.002393484115600586
# {'Filename': '0064.wav', 'Insertions': 8, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.9166666666666666, 'Word Count': 12, 'transcription': 'pickled peppers pickled peppers peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['a', 'the', 'of', 'of', "where's", 'pickled', 'peppers', 'picked', 'of', 'piper', 'a', 'picked', 'the', 'of', 'a', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 3.8909497261047363, 'Backtrace speed': 0.002393484115600586, 'Forward computations': 156318}
# 3.004002332687378
# 0.0010128021240234375
# {'Filename': '0065.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.625, 'Word Count': 8, 'transcription': 'the peck of pickled peppers peter piper picked', 'Viterbi transcription': ['the', 'of', 'a', 'of', 'pickled', 'peppers', 'peter', 'of', 'piper', 'a', 'picked', 'the'], 'Decode speed': 3.004002332687378, 'Backtrace speed': 0.0010128021240234375, 'Forward computations': 113478}
# 2.558242082595825
# 0.0009541511535644531
# {'Filename': '0066.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.75, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['the', 'the', 'of', 'piper', 'picked', 'of', 'picked', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 2.558242082595825, 'Backtrace speed': 0.0009541511535644531, 'Forward computations': 105708}
# 5.0568437576293945
# 0.0013117790222167969
# {'Filename': '0067.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.75, 'Word Count': 8, 'transcription': 'pickled peter peppers pickled peppers piper of piper', 'Viterbi transcription': ['the', 'picked', 'of', 'peter', 'the', 'peppers', 'pickled', 'peppers', 'piper', 'of', 'piper', 'picked', 'the'], 'Decode speed': 5.0568437576293945, 'Backtrace speed': 0.0013117790222167969, 'Forward computations': 157788}
# 2.3909966945648193
# 0.0012624263763427734
# {'Filename': '0068.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6, 'Word Count': 5, 'transcription': "pickled where's peck peck peppers", 'Viterbi transcription': ['the', 'pickled', "where's", 'peck', 'picked', 'peppers', 'the'], 'Decode speed': 2.3909966945648193, 'Backtrace speed': 0.0012624263763427734, 'Forward computations': 96888}
# 3.3633346557617188
# 0.0013170242309570312
# {'Filename': '0069.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 9, 'transcription': 'picked pickled a pickled peter of peppers peppers piper', 'Viterbi transcription': ['the', 'pickled', 'pickled', 'of', 'pickled', 'peter', 'of', 'of', 'peppers', 'peppers', 'piper', 'picked', 'the'], 'Decode speed': 3.3633346557617188, 'Backtrace speed': 0.0013170242309570312, 'Forward computations': 138258}
# 1.8841290473937988
# 0.0006210803985595703
# {'Filename': '0070.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.75, 'Word Count': 4, 'transcription': 'peck peppers picked piper', 'Viterbi transcription': ['the', 'peck', 'peppers', 'picked', 'piper', 'a', 'the'], 'Decode speed': 1.8841290473937988, 'Backtrace speed': 0.0006210803985595703, 'Forward computations': 79038}
# 2.134218692779541
# 0.0008575916290283203
# {'Filename': '0071.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.8, 'Word Count': 5, 'transcription': 'a peter pickled pickled picked', 'Viterbi transcription': ['the', 'of', 'peter', 'of', 'pickled', 'pickled', 'picked', 'the'], 'Decode speed': 2.134218692779541, 'Backtrace speed': 0.0008575916290283203, 'Forward computations': 88068}
# 3.622474431991577
# 0.001271963119506836
# {'Filename': '0072.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 6, 'WER': 1.3333333333333333, 'Word Count': 9, 'transcription': 'peck peppers picked a picked peter a picked peppers', 'Viterbi transcription': ['the', 'piper', 'peck', "where's", 'picked', 'of', 'picked', 'peck', 'the', 'the', 'of', 'of', 'pickled', "where's", 'the'], 'Decode speed': 3.622474431991577, 'Backtrace speed': 0.001271963119506836, 'Forward computations': 144768}
# 4.277177095413208
# 0.0022292137145996094
# {'Filename': '0073.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.375, 'Word Count': 8, 'transcription': "peck picked peppers peck picked where's of pickled", 'Viterbi transcription': ['the', 'peck', 'picked', "where's", 'peck', 'picked', "where's", 'of', 'pickled', 'the'], 'Decode speed': 4.277177095413208, 'Backtrace speed': 0.0022292137145996094, 'Forward computations': 117468}
# 3.453861713409424
# 0.001798391342163086
# {'Filename': '0074.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.5, 'Word Count': 8, 'transcription': "a peter where's piper the picked picked peppers", 'Viterbi transcription': ['the', 'of', 'peter', "where's", 'piper', 'the', 'pickled', 'picked', 'peppers', 'the'], 'Decode speed': 3.453861713409424, 'Backtrace speed': 0.001798391342163086, 'Forward computations': 95838}
# 2.840505599975586
# 0.001247406005859375
# {'Filename': '0075.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5555555555555556, 'Word Count': 9, 'transcription': 'piper peck of peck pickled picked pickled of peter', 'Viterbi transcription': ['the', 'piper', 'of', 'piper', 'of', 'peck', 'pickled', 'picked', 'peck', 'pickled', 'of', 'peter', 'the'], 'Decode speed': 2.840505599975586, 'Backtrace speed': 0.001247406005859375, 'Forward computations': 115368}
# 3.199652910232544
# 0.00127410888671875
# {'Filename': '0076.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': 'peck of peter peppers pickled peppers of picked peter', 'Viterbi transcription': ['the', 'peck', 'of', 'the', 'the', 'of', 'peck', "where's", 'pickled', "where's", 'of', 'picked', 'the'], 'Decode speed': 3.199652910232544, 'Backtrace speed': 0.00127410888671875, 'Forward computations': 129018}
# 3.6853442192077637
# 0.0013599395751953125
# {'Filename': '0077.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 9, 'transcription': 'peppers peck of peck peter picked a of peppers', 'Viterbi transcription': ['the', 'picked', 'of', "where's", 'peck', 'of', 'peck', 'peck', 'peter', 'picked', 'a', 'of', 'peppers', 'the'], 'Decode speed': 3.6853442192077637, 'Backtrace speed': 0.0013599395751953125, 'Forward computations': 150648}
# 2.9367570877075195
# 0.0014009475708007812
# {'Filename': '0078.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.3333333333333333, 'Word Count': 9, 'transcription': 'a peck of the pickled peppers peter piper picked', 'Viterbi transcription': ['the', 'of', 'peck', 'of', 'the', 'pickled', 'peppers', 'peter', 'piper', 'picked', 'the'], 'Decode speed': 2.9367570877075195, 'Backtrace speed': 0.0014009475708007812, 'Forward computations': 120198}
# 2.7041687965393066
# 0.001638650894165039
# {'Filename': '0079.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.3333333333333333, 'Word Count': 6, 'transcription': 'piper picked peter of the peck', 'Viterbi transcription': ['the', 'piper', 'picked', 'peter', 'of', 'the', 'peck', 'the'], 'Decode speed': 2.7041687965393066, 'Backtrace speed': 0.001638650894165039, 'Forward computations': 88068}
# 2.717149257659912
# 0.0008704662322998047
# {'Filename': '0080.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'a peter picked peck of picked pickled piper', 'Viterbi transcription': ['picked', 'the', 'peck', 'peter', 'picked', 'peck', 'of', 'picked', 'pickled', 'piper', 'the'], 'Decode speed': 2.717149257659912, 'Backtrace speed': 0.0008704662322998047, 'Forward computations': 113058}
# 2.138601064682007
# 0.0007023811340332031
# {'Filename': '0081.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6, 'Word Count': 5, 'transcription': "where's peck peppers of piper", 'Viterbi transcription': ['the', "where's", 'peck', 'peppers', 'of', 'piper', 'picked', 'the'], 'Decode speed': 2.138601064682007, 'Backtrace speed': 0.0007023811340332031, 'Forward computations': 86178}
# 2.5874826908111572
# 0.001092672348022461
# {'Filename': '0082.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': 'piper of peppers', 'Viterbi transcription': ['picked', 'piper', 'picked', "where's", 'the'], 'Decode speed': 2.5874826908111572, 'Backtrace speed': 0.001092672348022461, 'Forward computations': 104028}
# 1.943091630935669
# 0.0006451606750488281
# {'Filename': '0083.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': 'peter picked piper', 'Viterbi transcription': ['picked', 'picked', 'picked', 'piper', 'picked', 'the'], 'Decode speed': 1.943091630935669, 'Backtrace speed': 0.0006451606750488281, 'Forward computations': 77148}
# 1.9691052436828613
# 0.0008990764617919922
# {'Filename': '0084.wav', 'Insertions': 3, 'Deletions': 4, 'Substitutions': 0, 'WER': 0.7777777777777778, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['pickled', 'peppers', 'peter', 'of', 'piper', 'picked', 'the', 'peck'], 'Decode speed': 1.9691052436828613, 'Backtrace speed': 0.0008990764617919922, 'Forward computations': 52158}
# 2.8275630474090576
# 0.0017325878143310547
# {'Filename': '0085.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 3, 'WER': 0.6363636363636364, 'Word Count': 11, 'transcription': 'the peck of pickled peppers picked a peck of pickled peppers', 'Viterbi transcription': ['peck', 'of', 'pickled', 'peppers', 'picked', 'of', 'peck', 'of', 'peck', 'of', 'peck', "where's", 'the'], 'Decode speed': 2.8275630474090576, 'Backtrace speed': 0.0017325878143310547, 'Forward computations': 71898}
# 3.027615547180176
# 0.0010628700256347656
# {'Filename': '0086.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.875, 'Word Count': 8, 'transcription': "peter piper where's the peck of pickled peppers", 'Viterbi transcription': ['peter', 'of', 'piper', 'the', "where's", 'of', 'peck', 'of', 'pickled', 'peppers', 'the', 'peter', 'piper', 'picked'], 'Decode speed': 3.027615547180176, 'Backtrace speed': 0.0010628700256347656, 'Forward computations': 89748}
# 2.5596001148223877
# 0.0010881423950195312
# {'Filename': '0087.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 3, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': 'peter piper peter piper a peck of pickled peppers', 'Viterbi transcription': ['peter', 'piper', 'of', 'the', 'peter', 'piper', 'the', 'of', 'picked', 'of', 'pickled', 'peck', "where's", 'picked'], 'Decode speed': 2.5596001148223877, 'Backtrace speed': 0.0010881423950195312, 'Forward computations': 102348}
# 2.644676446914673
# 0.0018019676208496094
# {'Filename': '0088.wav', 'Insertions': 1, 'Deletions': 4, 'Substitutions': 2, 'WER': 0.4117647058823529, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['piper', 'picked', 'peck', 'pickled', 'peppers', "where's", 'the', 'peck', 'pickled', "where's", 'peter', 'picked', 'picked', 'picked'], 'Decode speed': 2.644676446914673, 'Backtrace speed': 0.0018019676208496094, 'Forward computations': 105918}
# 3.5184922218322754
# 0.0014853477478027344
# {'Filename': '0089.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 5, 'WER': 0.5294117647058824, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['peck', 'the', 'of', 'of', 'the', 'picked', 'peck', 'of', 'pickled', 'peppers', "where's", 'the', 'peck', 'of', 'picked', 'a', 'peppers', 'peter', 'piper', 'picked', 'the'], 'Decode speed': 3.5184922218322754, 'Backtrace speed': 0.0014853477478027344, 'Forward computations': 125658}
# 4.975330114364624
# 0.003816366195678711
# {'Filename': '0090.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.35294117647058826, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['peck', 'the', 'peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers', "where's", 'the', 'peck', 'of', 'pickled', 'picked', "where's", 'peter', 'piper', 'peck', 'picked', 'the'], 'Decode speed': 4.975330114364624, 'Backtrace speed': 0.003816366195678711, 'Forward computations': 184668}
# 1.1845109462738037
# 0.0005545616149902344
# {'Filename': '0091.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 4, 'transcription': "where's the peck of", 'Viterbi transcription': ['peck', 'the', "where's", 'of', 'peck', 'of', 'the'], 'Decode speed': 1.1845109462738037, 'Backtrace speed': 0.0005545616149902344, 'Forward computations': 45018}
# 1.2255351543426514
# 0.0008759498596191406
# {'Filename': '0092.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'picked a peck of pickled', 'Viterbi transcription': ['peck', 'the', 'picked', 'peck', 'of', 'pickled', 'the'], 'Decode speed': 1.2255351543426514, 'Backtrace speed': 0.0008759498596191406, 'Forward computations': 50268}
# 1.486327886581421
# 0.0010211467742919922
# {'Filename': '0093.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6, 'Word Count': 5, 'transcription': "pickled peppers where's the peck", 'Viterbi transcription': ['peck', 'the', 'pickled', 'peppers', "where's", 'the', 'peck', 'the'], 'Decode speed': 1.486327886581421, 'Backtrace speed': 0.0010211467742919922, 'Forward computations': 59298}
# 1.1725025177001953
# 0.0008208751678466797
# {'Filename': '0094.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 3, 'transcription': 'peter picked peppers', 'Viterbi transcription': ['the', 'peter', 'picked', 'peck', "where's"], 'Decode speed': 1.1725025177001953, 'Backtrace speed': 0.0008208751678466797, 'Forward computations': 48588}
# 1.562551736831665
# 0.0010342597961425781
# {'Filename': '0095.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peter pickled a picked peck', 'Viterbi transcription': ['the', 'peter', 'pickled', 'picked', 'peck', 'picked', 'the'], 'Decode speed': 1.562551736831665, 'Backtrace speed': 0.0010342597961425781, 'Forward computations': 64758}
# 1.5879461765289307
# 0.0005857944488525391
# {'Filename': '0096.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'peter picked the peck of peppers', 'Viterbi transcription': ['the', 'picked', 'picked', 'the', 'peck', 'peck', 'of', 'peppers', 'the'], 'Decode speed': 1.5879461765289307, 'Backtrace speed': 0.0005857944488525391, 'Forward computations': 64758}
# 2.1766340732574463
# 0.001168966293334961
# {'Filename': '0097.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.5, 'Word Count': 8, 'transcription': 'peter picked a peck of the pickled peppers', 'Viterbi transcription': ['the', 'peter', 'piper', 'picked', 'the', 'peck', 'of', 'the', 'pickled', 'peppers', 'the'], 'Decode speed': 2.1766340732574463, 'Backtrace speed': 0.001168966293334961, 'Forward computations': 86178}
# 1.5786280632019043
# 0.001115560531616211
# {'Filename': '0098.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': 'the peck of peppers peter piper pickled', 'Viterbi transcription': ['the', 'peck', 'of', 'peck', "where's", 'peter', 'piper', 'pickled', 'the'], 'Decode speed': 1.5786280632019043, 'Backtrace speed': 0.001115560531616211, 'Forward computations': 62868}
# 4.038663864135742
# 0.0024373531341552734
# {'Filename': '0099.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.45454545454545453, 'Word Count': 11, 'transcription': "the peck pickled peppers picked pickled peter of piper a where's", 'Viterbi transcription': ['picked', 'the', 'picked', 'picked', 'pickled', 'peppers', 'picked', 'peck', 'pickled', 'peter', 'of', 'piper', 'a', "where's", 'the'], 'Decode speed': 4.038663864135742, 'Backtrace speed': 0.0024373531341552734, 'Forward computations': 165138}
# 3.272753953933716
# 0.0019845962524414062
# {'Filename': '0100.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 10, 'transcription': 'the picked of piper picked of pickled a peter piper', 'Viterbi transcription': ['the', 'picked', 'of', 'piper', 'picked', 'of', 'pickled', 'a', 'the', 'peter', 'piper', 'the'], 'Decode speed': 3.272753953933716, 'Backtrace speed': 0.0019845962524414062, 'Forward computations': 118518}
# 4.6092774868011475
# 0.0027153491973876953
# {'Filename': '0101.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.42857142857142855, 'Word Count': 14, 'transcription': "peck piper picked of picked pickled of where's a peppers peter peppers peter pickled", 'Viterbi transcription': ['the', 'picked', 'piper', 'picked', 'of', 'peter', 'pickled', 'of', "where's", 'a', 'the', 'peppers', 'peter', 'peppers', 'peck', 'peter', 'pickled', 'the'], 'Decode speed': 4.6092774868011475, 'Backtrace speed': 0.0027153491973876953, 'Forward computations': 188448}
# 2.461057424545288
# 0.0006401538848876953
# {'Filename': '0102.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 4, 'transcription': 'peppers peck peter pickled', 'Viterbi transcription': ['the', 'peppers', 'peck', 'peter', 'pickled', 'the'], 'Decode speed': 2.461057424545288, 'Backtrace speed': 0.0006401538848876953, 'Forward computations': 73578}
# 3.1745662689208984
# 0.0017147064208984375
# {'Filename': '0103.wav', 'Insertions': 2, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.42857142857142855, 'Word Count': 7, 'transcription': "where's piper picked piper a pickled peppers", 'Viterbi transcription': ['the', "where's", 'piper', 'picked', 'piper', 'pickled', 'peppers', 'the'], 'Decode speed': 3.1745662689208984, 'Backtrace speed': 0.0017147064208984375, 'Forward computations': 98778}
# 2.578974485397339
# 0.0010287761688232422
# {'Filename': '0104.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.3333333333333333, 'Word Count': 6, 'transcription': 'peter picked peppers of pickled peppers', 'Viterbi transcription': ['the', 'picked', 'a', 'picked', 'the', 'peppers', 'of', 'pickled', 'picked', 'picked', "where's", 'the'], 'Decode speed': 2.578974485397339, 'Backtrace speed': 0.0010287761688232422, 'Forward computations': 99828}
# 4.140630006790161
# 0.001748800277709961
# {'Filename': '0105.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.4444444444444444, 'Word Count': 9, 'transcription': 'peter peppers picked piper a peck of pickled peppers', 'Viterbi transcription': ['the', 'peter', 'peppers', 'picked', 'piper', 'picked', 'peck', 'peck', 'of', 'pickled', 'peppers', 'the'], 'Decode speed': 4.140630006790161, 'Backtrace speed': 0.001748800277709961, 'Forward computations': 123138}
# 4.204661130905151
# 0.0011441707611083984
# {'Filename': '0106.wav', 'Insertions': 4, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.875, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['the', 'picked', 'piper', 'peck', 'picked', 'peck', 'of', 'pickled', 'picked', "where's", 'the'], 'Decode speed': 4.204661130905151, 'Backtrace speed': 0.0011441707611083984, 'Forward computations': 109488}
# ...
# 1.6394226551055908
# 0.0010378360748291016
# {'Filename': '0292.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.25, 'Word Count': 4, 'transcription': 'pickled peck of peppers', 'Viterbi transcription': ['pickled', 'peck', 'of', 'peppers', 'the'], 'Decode speed': 1.6394226551055908, 'Backtrace speed': 0.0010378360748291016, 'Forward computations': 66438}
# 1.7238144874572754
# 0.0008859634399414062
# {'Filename': '0293.wav', 'Insertions': 4, 'Deletions': 1, 'Substitutions': 1, 'WER': 1.2, 'Word Count': 5, 'transcription': 'peter piper picked a peck', 'Viterbi transcription': ['picked', "where's", 'piper', 'a', 'the', 'peck', 'peck', 'the'], 'Decode speed': 1.7238144874572754, 'Backtrace speed': 0.0008859634399414062, 'Forward computations': 70008}
# 3.1681253910064697
# 0.0014078617095947266
# {'Filename': '0294.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.8, 'Word Count': 5, 'transcription': 'peppers of piper peck peter', 'Viterbi transcription': ['the', "where's", 'of', 'piper', 'peck', 'peter', "where's", 'the'], 'Decode speed': 3.1681253910064697, 'Backtrace speed': 0.0014078617095947266, 'Forward computations': 130908}
# 1.860877275466919
# 0.0009870529174804688
# {'Filename': '0295.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 6, 'transcription': 'peter a piper of a peck', 'Viterbi transcription': ["where's", 'the', 'peter', 'of', 'piper', 'of', 'picked', 'a', 'peck', 'the', 'the'], 'Decode speed': 1.860877275466919, 'Backtrace speed': 0.0009870529174804688, 'Forward computations': 77148}
# 2.561030149459839
# 0.0015175342559814453
# {'Filename': '0296.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 4, 'transcription': 'peck pickled peter peck', 'Viterbi transcription': ['the', 'peck', 'pickled', 'picked', 'of', 'peck', 'the'], 'Decode speed': 2.561030149459839, 'Backtrace speed': 0.0015175342559814453, 'Forward computations': 82608}
# 3.135734796524048
# 0.001982450485229492
# {'Filename': '0297.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 9, 'transcription': 'a piper of peter picked peppers of pickled peter', 'Viterbi transcription': ['pickled', 'a', 'piper', 'the', 'of', 'peter', 'picked', 'picked', 'of', "where's", 'of', 'pickled', 'peter', 'the'], 'Decode speed': 3.135734796524048, 'Backtrace speed': 0.001982450485229492, 'Forward computations': 123768}
# 2.3401851654052734
# 0.0006988048553466797
# {'Filename': '0298.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.8, 'Word Count': 5, 'transcription': 'of peck a peter pickled', 'Viterbi transcription': ['the', 'of', 'peck', 'picked', 'of', 'pickled', 'the'], 'Decode speed': 2.3401851654052734, 'Backtrace speed': 0.0006988048553466797, 'Forward computations': 93318}
# 1.2604320049285889
# 0.0008475780487060547
# {'Filename': '0299.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': 'piper picked a peck of the peppers', 'Viterbi transcription': ['piper', 'picked', 'picked', 'peck', 'of', 'the', 'peppers', 'the'], 'Decode speed': 1.2604320049285889, 'Backtrace speed': 0.0008475780487060547, 'Forward computations': 50268}
# 1.3476262092590332
# 0.0007452964782714844
# {'Filename': '0300.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': "where's peter piper", 'Viterbi transcription': ['the', "where's", 'peter', 'piper', 'the'], 'Decode speed': 1.3476262092590332, 'Backtrace speed': 0.0007452964782714844, 'Forward computations': 55728}
# 1.0327229499816895
# 0.0004394054412841797
# {'Filename': '0301.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.5, 'Word Count': 4, 'transcription': 'pickled peppers of peter', 'Viterbi transcription': ['pickled', 'peppers', 'of', 'peter', 'picked', 'the'], 'Decode speed': 1.0327229499816895, 'Backtrace speed': 0.0004394054412841797, 'Forward computations': 43128}
# 1.552640438079834
# 0.0008094310760498047
# {'Filename': '0302.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.625, 'Word Count': 8, 'transcription': 'a peck of pickled peppers of peter piper', 'Viterbi transcription': ['the', 'of', 'peck', 'of', 'pickled', "where's", 'of', 'peter', 'piper', 'picked', 'the'], 'Decode speed': 1.552640438079834, 'Backtrace speed': 0.0008094310760498047, 'Forward computations': 61188}
# 1.4687185287475586
# 0.0008397102355957031
# {'Filename': '0303.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.0, 'Word Count': 5, 'transcription': 'peppers peppers peppers peppers peppers', 'Viterbi transcription': ['peppers', 'of', "where's", 'peppers', 'peppers', 'of', "where's", 'the'], 'Decode speed': 1.4687185287475586, 'Backtrace speed': 0.0008397102355957031, 'Forward computations': 59298}
# 1.3119659423828125
# 0.0008111000061035156
# {'Filename': '0304.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 0, 'WER': 0.2, 'Word Count': 5, 'transcription': 'peter peck the pickled peppers', 'Viterbi transcription': ['the', 'peter', 'peck', 'the', 'pickled', 'peppers'], 'Decode speed': 1.3119659423828125, 'Backtrace speed': 0.0008111000061035156, 'Forward computations': 54048}
# 1.2188706398010254
# 0.000469207763671875
# {'Filename': '0305.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.4, 'Word Count': 5, 'transcription': 'pickled peter picked the piper', 'Viterbi transcription': ['pickled', 'peter', 'picked', 'piper', 'peck'], 'Decode speed': 1.2188706398010254, 'Backtrace speed': 0.000469207763671875, 'Forward computations': 48588}
# 1.493690013885498
# 0.0008590221405029297
# {'Filename': '0306.wav', 'Insertions': 1, 'Deletions': 1, 'Substitutions': 0, 'WER': 0.2857142857142857, 'Word Count': 7, 'transcription': "where's the peck of peppers peter picked", 'Viterbi transcription': ['the', "where's", 'peck', 'of', 'peppers', 'peter', 'picked'], 'Decode speed': 1.493690013885498, 'Backtrace speed': 0.0008590221405029297, 'Forward computations': 61188}
# 1.5677869319915771
# 0.0006282329559326172
# {'Filename': '0307.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 2, 'WER': 0.6666666666666666, 'Word Count': 6, 'transcription': 'the peppers pickled peter peppers piper', 'Viterbi transcription': ['picked', 'peppers', 'pickled', 'peter', 'peppers', 'a', 'picked', 'the'], 'Decode speed': 1.5677869319915771, 'Backtrace speed': 0.0006282329559326172, 'Forward computations': 64758}
# 1.6667706966400146
# 0.0009124279022216797
# {'Filename': '0308.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.1666666666666667, 'Word Count': 6, 'transcription': 'peppers peck peppers picked peppers peter', 'Viterbi transcription': ['peck', 'of', "where's", 'peck', 'peppers', 'picked', 'of', "where's", 'peter', 'the', 'the'], 'Decode speed': 1.6667706966400146, 'Backtrace speed': 0.0009124279022216797, 'Forward computations': 68328}
# 8.663563966751099
# 0.004795074462890625
# {'Filename': '0309.wav', 'Insertions': 14, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.125, 'Word Count': 16, 'transcription': 'peter piper picked a peck of pickled peppers the peck of pickled peppers peter piper picked', 'Viterbi transcription': ['the', 'picked', 'the', 'picked', 'piper', 'of', 'pickled', 'of', 'peck', 'of', 'pickled', 'peppers', "where's", 'the', 'peck', 'of', 'picked', 'picked', 'peppers', 'peter', 'of', 'piper', 'picked', 'the', 'of', 'peck', 'the', 'of', 'pickled', 'of'], 'Decode speed': 8.663563966751099, 'Backtrace speed': 0.004795074462890625, 'Forward computations': 303108}
# 5.5447163581848145
# 0.003365755081176758
# {'Filename': '0310.wav', 'Insertions': 12, 'Deletions': 0, 'Substitutions': 8, 'WER': 1.1764705882352942, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['the', 'the', 'of', 'peter', 'a', 'the', 'of', 'piper', 'the', 'a', 'pickled', "where's", 'peck', 'picked', "where's", "where's", 'peck', 'of', 'of', 'peppers', 'peppers', 'peter', 'a', 'the', 'of', 'peck', "where's", 'picked', 'the'], 'Decode speed': 5.5447163581848145, 'Backtrace speed': 0.003365755081176758, 'Forward computations': 213438}
# 2.7381718158721924
# 0.00141143798828125
# {'Filename': '0311.wav', 'Insertions': 9, 'Deletions': 0, 'Substitutions': 1, 'WER': 2.0, 'Word Count': 5, 'transcription': 'a peck of pickled peppers', 'Viterbi transcription': ['of', 'a', "where's", 'the', 'the', 'of', 'peck', 'of', 'pickled', 'of', "where's", 'piper', 'the', 'the'], 'Decode speed': 2.7381718158721924, 'Backtrace speed': 0.00141143798828125, 'Forward computations': 111378}
# 1.3850691318511963
# 0.0008442401885986328
# {'Filename': '0312.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.6666666666666667, 'Word Count': 3, 'transcription': "where's peter piper", 'Viterbi transcription': ['picked', "where's", 'peter', 'the', 'the', 'a', 'the'], 'Decode speed': 1.3850691318511963, 'Backtrace speed': 0.0008442401885986328, 'Forward computations': 57618}
# 1.666273832321167
# 0.0007944107055664062
# {'Filename': '0313.wav', 'Insertions': 9, 'Deletions': 1, 'Substitutions': 1, 'WER': 2.75, 'Word Count': 4, 'transcription': 'peter picked pickled peppers', 'Viterbi transcription': ['picked', 'the', 'the', 'a', 'the', 'pickled', 'picked', 'the', 'picked', "where's", 'piper', 'the'], 'Decode speed': 1.666273832321167, 'Backtrace speed': 0.0007944107055664062, 'Forward computations': 68328}
# 1.6608660221099854
# 0.0011315345764160156
# {'Filename': '0314.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.5, 'Word Count': 6, 'transcription': "where's the pickled peppers peter picked", 'Viterbi transcription': ['the', "where's", "where's", 'of', 'peck', 'of', 'the', 'peppers', 'picked', 'of', 'the'], 'Decode speed': 1.6608660221099854, 'Backtrace speed': 0.0011315345764160156, 'Forward computations': 68328}
# 1.1421608924865723
# 0.0004093647003173828
# {'Filename': '0315.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 2, 'WER': 1.6666666666666667, 'Word Count': 3, 'transcription': 'picked a peter', 'Viterbi transcription': ['peck', 'the', 'of', 'peter', 'peter', 'the'], 'Decode speed': 1.1421608924865723, 'Backtrace speed': 0.0004093647003173828, 'Forward computations': 45228}
# 1.6113362312316895
# 0.00054931640625
# {'Filename': '0316.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 4, 'WER': 1.2, 'Word Count': 5, 'transcription': 'picked a peppers peck peter', 'Viterbi transcription': ['peck', 'the', "where's", 'the', 'peppers', 'picked', 'the'], 'Decode speed': 1.6113362312316895, 'Backtrace speed': 0.00054931640625, 'Forward computations': 66648}
# 1.1061241626739502
# 0.0008122920989990234
# {'Filename': '0317.wav', 'Insertions': 5, 'Deletions': 0, 'Substitutions': 2, 'WER': 2.3333333333333335, 'Word Count': 3, 'transcription': 'pickled peppers piper', 'Viterbi transcription': ['peck', 'the', 'of', 'pickled', 'of', "where's", "where's", 'the'], 'Decode speed': 1.1061241626739502, 'Backtrace speed': 0.0008122920989990234, 'Forward computations': 45228}
# 0.9063205718994141
# 0.00041413307189941406
# {'Filename': '0318.wav', 'Insertions': 1, 'Deletions': 0, 'Substitutions': 1, 'WER': 0.6666666666666666, 'Word Count': 3, 'transcription': 'pickled the pickled', 'Viterbi transcription': ['peck', "where's", 'the', 'pickled'], 'Decode speed': 0.9063205718994141, 'Backtrace speed': 0.00041413307189941406, 'Forward computations': 37458}
# 0.958827018737793
# 0.0006136894226074219
# {'Filename': '0319.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.0, 'Word Count': 4, 'transcription': "of peter where's pickled", 'Viterbi transcription': ['peck', 'of', 'peter', 'picked', "where's", 'picked', "where's"], 'Decode speed': 0.958827018737793, 'Backtrace speed': 0.0006136894226074219, 'Forward computations': 39348}
# 2.468130111694336
# 0.0015096664428710938
# {'Filename': '0320.wav', 'Insertions': 6, 'Deletions': 0, 'Substitutions': 1, 'WER': 2.3333333333333335, 'Word Count': 3, 'transcription': "where's peter piper", 'Viterbi transcription': ['the', "where's", 'pickled', "where's", 'picked', 'of', 'piper', 'picked', 'the'], 'Decode speed': 2.468130111694336, 'Backtrace speed': 0.0015096664428710938, 'Forward computations': 73578}
# 2.0739529132843018
# 0.0004990100860595703
# {'Filename': '0321.wav', 'Insertions': 2, 'Deletions': 0, 'Substitutions': 3, 'WER': 1.25, 'Word Count': 4, 'transcription': 'a peck of peppers', 'Viterbi transcription': ['the', 'pickled', 'of', 'of', "where's", 'the'], 'Decode speed': 2.0739529132843018, 'Backtrace speed': 0.0004990100860595703, 'Forward computations': 62868}
# 1.831080675125122
# 0.0006048679351806641
# {'Filename': '0322.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.3333333333333333, 'Word Count': 3, 'transcription': 'pickled peter piper', 'Viterbi transcription': ['the', 'pickled', 'peter', 'peter', 'picked', 'the'], 'Decode speed': 1.831080675125122, 'Backtrace speed': 0.0006048679351806641, 'Forward computations': 59298}
# 2.2510838508605957
# 0.0010592937469482422
# {'Filename': '0323.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 1, 'WER': 1.6666666666666667, 'Word Count': 3, 'transcription': 'pickled peter piper', 'Viterbi transcription': ['the', 'pickled', 'picked', 'picked', 'piper', 'picked', 'the'], 'Decode speed': 2.2510838508605957, 'Backtrace speed': 0.0010592937469482422, 'Forward computations': 77148}
# 4.283127307891846
# 0.0017311573028564453
# {'Filename': '0324.wav', 'Insertions': 6, 'Deletions': 1, 'Substitutions': 5, 'WER': 0.7058823529411765, 'Word Count': 17, 'transcription': "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['peppers', 'the', 'of', 'of', 'of', 'picked', 'of', 'peck', 'of', 'pickled', "where's", "where's", 'peck', 'of', 'pickled', "where's", 'peter', 'piper', 'of', 'a', 'picked', 'the'], 'Decode speed': 4.283127307891846, 'Backtrace speed': 0.0017311573028564453, 'Forward computations': 173958}
# 2.200831890106201
# 0.0010900497436523438
# {'Filename': '0325.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 2, 'WER': 0.75, 'Word Count': 8, 'transcription': 'peter piper picked a peck of pickled peppers', 'Viterbi transcription': ['the', 'of', 'piper', 'picked', 'of', 'a', 'of', 'pickled', "where's", 'the'], 'Decode speed': 2.200831890106201, 'Backtrace speed': 0.0010900497436523438, 'Forward computations': 88068}
# 3.5420022010803223
# 0.0012848377227783203
# {'Filename': '0326.wav', 'Insertions': 3, 'Deletions': 0, 'Substitutions': 8, 'WER': 0.9166666666666666, 'Word Count': 12, 'transcription': "peter piper picked pickled peppers where's the pickled peppers peter piper picked", 'Viterbi transcription': ['the', 'of', 'piper', 'of', 'a', 'picked', "where's", "where's", 'pickled', "where's", "where's", 'of', 'peter', 'picked', 'the'], 'Decode speed': 3.5420022010803223, 'Backtrace speed': 0.0012848377227783203, 'Forward computations': 132798}
# 2.0883612632751465
# 0.0018513202667236328
# {'Filename': '0327.wav', 'Insertions': 3, 'Deletions': 1, 'Substitutions': 4, 'WER': 1.0, 'Word Count': 8, 'transcription': 'a peck of pickled peppers peter piper picked', 'Viterbi transcription': ['the', 'of', 'pickled', 'pickled', "where's", "where's", 'of', "where's", 'picked', 'the'], 'Decode speed': 2.0883612632751465, 'Backtrace speed': 0.0018513202667236328, 'Forward computations': 86178}
# 1.8347671031951904
# 0.0022644996643066406
# {'Filename': '0328.wav', 'Insertions': 4, 'Deletions': 0, 'Substitutions': 4, 'WER': 0.8888888888888888, 'Word Count': 9, 'transcription': "where's the peck of pickled peppers peter piper picked", 'Viterbi transcription': ['peck', 'the', "where's", 'of', 'peck', 'of', 'picked', 'of', "where's", 'peter', "where's", 'a', 'picked'], 'Decode speed': 1.8347671031951904, 'Backtrace speed': 0.0022644996643066406, 'Forward computations': 75468}
